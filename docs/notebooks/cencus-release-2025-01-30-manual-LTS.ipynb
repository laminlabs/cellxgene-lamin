# %% [markdown]
# # Census release 2025-01-30 (LTS)

# %%
# !lamin init --storage run-tests --modules bionty
# Out:
# → initialized lamindb: zethson/run-tests

# %%
import lamindb as ln
import bionty as bt
from cellxgene_lamin.dev import get_datasets_from_cxg, get_collections_from_cxg

ln.settings.verbosity = "hint"
# Out:
# → connected lamindb: zethson/run-tests

# %%
census_version = "2025-01-30"
previous_release = "2024-07-01"

# %%
s3path = f"s3://cellxgene-data-public/cell-census/{census_version}/h5ads"
ln.UPath(s3path)
# Out:
# S3QueryPath('s3://cellxgene-data-public/cell-census/2025-01-30/h5ads')

# %%
ln.UPath(s3path).view_tree()
# Out:
# 0 sub-directories & 1573 files with suffixes '.h5ad'
# s3://cellxgene-data-public/cell-census/2025-01-30/h5ads
# ├── 00099d5e-154f-4a7a-aa8d-fa30c8c0c43c.h5ad
# ├── 001b01fe-5c70-4bda-a3aa-ee09b7899b14.h5ad
# ├── 0041b9c3-6a49-4bf7-8514-9bc7190067a7.h5ad
# ├── 00476f9f-ebc1-4b72-b541-32f912ce36ea.h5ad
# ├── 00593d17-0693-4646-acad-89dbefba11bb.h5ad
# ├── 0087cde2-967d-4f7c-8e6e-40e4c9ad1891.h5ad
# ├── 00ba8341-48ec-4e4e-bb56-be0dd2dd7913.h5ad
# ├── 00e5dedd-b9b7-43be-8c28-b0e5c6414a62.h5ad
# ├── 00ff600e-6e2e-4d76-846f-0eec4f0ae417.h5ad
# ├── 01209dce-3575-4bed-b1df-129f57fbc031.h5ad
# ├── 0129dbd9-a7d3-4f6b-96b9-1da155a93748.h5ad
# ├── 015c230d-650c-4527-870d-8a805849a382.h5ad
# ├── 019c7af2-c827-4454-9970-44d5e39ce068.h5ad
# ├── 01ad3cd7-3929-4654-84c0-6db05bd5fd59.h5ad
# ├── 01c93cf6-b695-4e30-a26e-121ae8b16a9e.h5ad
# ├── 023ce5da-0dbe-4ad0-a290-b6c21824b101.h5ad
# ├── 023d4d04-4671-4433-af8d-158a05c81d8b.h5ad
# ├── 02419ebc-fd75-4629-ba13-9b26e3be851c.h5ad
# ├── 024593dd-d237-4eaa-aff2-9c9d87be595e.h5ad
# ├── 02792605-4760-4023-82ad-40fc4458a5db.h5ad
# ├── 02aa7750-ed05-4eca-8061-766c68a81a22.h5ad
# ├── 02f8bb42-0322-4906-b9ad-b92a5ce73a2d.h5ad
# ├── 02faf712-92d4-4589-bec7-13105059cf86.h5ad
# ├── 03181d87-4769-41e7-8c39-d9a81835f0d2.h5ad
# ├── 0325478a-9b52-45b5-b40a-2e2ab0d72eb1.h5ad
# ├── 0374f03c-62e2-4859-8a14-acb00b0627d5.h5ad
# ├── 0380ddce-c31b-422a-88fe-34a1945bd949.h5ad
# ├── 03ad88c2-2faa-470f-9426-1c793fc5efed.h5ad
# ├── 03b3e7b1-1d38-4b39-b996-28ace9c65492.h5ad
# ├── 03c0e874-f984-4e6c-9d2a-26ef8507dbbc.h5ad
# ├── 03c544fb-a103-4d18-9230-eae9cfee3af2.h5ad
# ├── 03d38670-1444-4001-bc53-9936e61d9b20.h5ad
# ├── 03d5794d-cde9-4769-a1a9-b3899d2b1d87.h5ad
# ├── 0436a180-cb44-47ba-8ffa-807b7a468469.h5ad
# ├── 0456ae85-6f27-4e36-8c62-4c97370baa68.h5ad
# ├── 047d57f2-4d14-45de-aa98-336c6f583750.h5ad
# ├── 0491b0c6-4d09-45bf-b5ca-42088632c15c.h5ad
# ├── 04a0a043-1d65-489a-b203-7908780cc922.h5ad
# ├── 04a23820-ffa8-4be5-9f65-64db15631d1e.h5ad
# ├── 04b0eb97-d816-44bb-93a5-8b2968791aa0.h5ad
# ├── 04c0bdd8-840f-488e-b72d-2a1229bc65db.h5ad
# ├── 04c94a7d-1133-42c9-bb48-c697bd302a8d.h5ad
# ├── 04d87de6-c20a-4186-8884-f47dba20b0a4.h5ad
# ├── 04ea2093-332f-4684-99f1-c353cd62c35b.h5ad
# ├── 055ca631-6ffb-40de-815e-b931e10718c0.h5ad
# ├── 059022cf-885a-4ef8-944b-d9e5381aa1c6.h5ad
# ├── 05a49baa-d326-42ae-86d2-94de3a659901.h5ad
# ├── 05d4a216-5384-4724-bd2a-2ea38f02e7cc.h5ad
# ├── 05e6f6e3-0473-4b85-9f94-bcc5f1b5e04b.h5ad
# ├── 05f813a4-fc9e-4143-bba9-de93bdd8eece.h5ad
# ├── 06379c09-d4cf-4c6f-8299-e0bc8879dbdf.h5ad
# ├── 066943a2-fdac-4b29-b348-40cede398e4e.h5ad
# ├── 0671c0d4-f233-4cd3-a0d6-9a6b747bdd98.h5ad
# ├── 06b91002-4d3d-4d2e-8484-20c3b31e232c.h5ad
# ├── 06ef6b36-6c9b-4e10-8a94-d0baf274276e.h5ad
# ├── 0737011b-45a6-49f6-8b5a-b85c35160bac.h5ad
# ├── 0738f538-ff2f-4346-b2eb-72704c291188.h5ad
# ├── 07428d73-fdea-4bd4-a801-94b00c4d961c.h5ad
# ├── 07760522-707a-4a1c-8891-dbd1226d6b27.h5ad
# ├── 07854d9c-5375-4a9b-ac34-fa919d3c3686.h5ad
# ├── 07a4e406-3a76-47a3-a21c-a28d7ce7984a.h5ad
# ├── 07b1d7c8-5c2e-42f7-9246-26f746cd6013.h5ad
# ├── 07efa1c3-7649-43d8-b798-e26a0145ee65.h5ad
# ├── 07f14e26-ff0d-43c4-bfe3-bf1a94dc73c3.h5ad
# ├── 08073b32-d389-41f4-a4fd-616de76915ab.h5ad
# ├── 0819e386-e7fd-4212-b732-60e468689f89.h5ad
# ├── 0895c838-e550-48a3-a777-dbcd35d30272.h5ad
# ├── 08e94873-c2a6-4f7d-ab72-aeaff3e3f929.h5ad
# ├── 090da8ea-46e8-40df-bffc-1f78e1538d27.h5ad
# ├── 090fede8-fac6-4bea-b6c4-6dedea5cca1c.h5ad
# ├── 0920bcb8-4b3a-4e9d-a353-56f529fd3b32.h5ad
# ├── 09286690-98b5-4095-b0b1-3ded23a9dd3a.h5ad
# ├── 093d3bfe-6f0f-4ac0-a7a1-829f94d0a49f.h5ad
# ├── 095940cb-7422-4510-96e2-cbafd961eb88.h5ad
# ├── 0a1ad9d5-c9e1-4253-8883-9a99593eaa0c.h5ad
# ├── 0a1b0fc9-2167-4cd3-85c6-379f0fdab8be.h5ad
# ├── 0a21f80c-e7a3-465b-8aba-fdda2b4c36bc.h5ad
# ├── 0a2d7e87-c3c0-4ed2-86df-ae18811fcc16.h5ad
# ├── 0ae96eac-ff08-4870-9bc3-cd12418af7e4.h5ad
# ├── 0b4a15a7-4e9e-4555-9733-2423e5c66469.h5ad
# ├── 0b75c598-0893-4216-afe8-5414cab7739d.h5ad
# ├── 0ba16f4b-cb87-4fa3-9363-19fc51eec6e7.h5ad
# ├── 0ba636a1-4754-4786-a8be-7ab3cf760fd6.h5ad
# ├── 0bae7ebf-eb54-46a6-be9a-3461cecefa4c.h5ad
# ├── 0bc7235a-ae5a-479d-a487-510435377e55.h5ad
# ├── 0bcda669-c2ab-484f-a87f-4e21f7a5bcab.h5ad
# ├── 0bce33ed-455c-4e12-93f8-b7b04a2de4a1.h5ad
# ├── 0bd1a1de-3aee-40e0-b2ec-86c7a30c7149.h5ad
# ├── 0bd1ce9e-c423-4721-8ccf-91d9858342c2.h5ad
# ├── 0c3901c3-2ef7-44e4-80cb-b281ea2b0de9.h5ad
# ├── 0c86f0de-ddcb-454c-b00b-37feb69e7da1.h5ad
# ├── 0c9a8cfb-6649-4d52-b418-6d8e56bd7afe.h5ad
# ├── 0caedec7-1c7d-4e79-aba2-50f6916e643f.h5ad
# ├── 0ced5e76-6040-47ff-8a72-93847965afc0.h5ad
# ├── 0d049f5a-19b1-4055-a377-011a9570032c.h5ad
# ├── 0d2ee4ac-05ee-40b2-afb6-ebb584caa867.h5ad
# ├── 0d49001d-cc88-4b70-8f0c-f1ca385d0199.h5ad
# ├── 0d7f4c06-a6bd-47d2-a42b-3a7196704f77.h5ad
# ├── 0de831e0-a525-4ec5-b717-df56f2de2bf0.h5ad
# ...

# %%
ln.track("VzV8Ty89eQdK")
# Out:
# • tracked pip freeze > /home/lukas/.cache/lamindb/environments/run_xkjTYBy2Vsc82WJw/run_env_pip.txt
# → created Transform('VzV8Ty89eQdK0000'), started new Run('xkjTYBy2...') at 2025-07-23 09:25:03 UTC
# → notebook imports: bionty==1.6.1 cellxgene_lamin==0.3.2 lamindb==1.9.0

# %% [markdown]
# Get all datasets and associated metadata using cellxgene REST API:

# %%
cxg_datasets = get_datasets_from_cxg()
len(cxg_datasets)
# Out:
# 1844

# %%
cxg_datasets[0].keys()
# Out:
# dict_keys(['assay', 'assets', 'cell_count', 'cell_type', 'citation', 'collection_doi', 'collection_doi_label', 'collection_id', 'collection_name', 'collection_version_id', 'dataset_id', 'dataset_version_id', 'development_stage', 'disease', 'donor_id', 'explorer_url', 'is_primary_data', 'mean_genes_per_cell', 'organism', 'primary_cell_count', 'processing_status', 'published_at', 'revised_at', 'revision_of_collection', 'revision_of_dataset', 'schema_version', 'self_reported_ethnicity', 'sex', 'spatial', 'suspension_type', 'tissue', 'title', 'tombstone', 'visibility', 'x_approximate_distribution'])

# %% [markdown]
# ## Register artifacts

# %%
artifacts = ln.Artifact.from_dir(s3path)
ln.save(artifacts)
# Out:
# → due to lack of write access, LaminDB won't manage this storage location: s3://cellxgene-data-public
# → referenced read-only storage location at s3://cellxgene-data-public
# ✓ created 1573 artifacts from directory using storage s3://cellxgene-data-public and key = cell-census/2025-01-30/h5ads/

# %%
artifacts = ln.Artifact.filter(key__contains=census_version).all()
len(artifacts)
# Out:
# 1573

# %%
artifacts.update(version=census_version)
# Out:
# 1573

# %%
for cxg_dataset in cxg_datasets:
    artifact = artifacts.filter(key__contains=cxg_dataset["dataset_id"]).one_or_none()
    if artifact is not None:
        artifact.n_observations = cxg_dataset["cell_count"]
        artifact.description = cxg_dataset["title"]
        artifact.save()

# %%
artifacts_previous = ln.Artifact.filter(version=previous_release).all()
artifacts_previous.count()
# Out:
# 0

# %%
for artifact in artifacts:
    dataset_id = artifact.key.split("/")[-1]
    artifact_previous = artifacts_previous.filter(
        key__endswith=dataset_id
    ).one_or_none()
    if artifact_previous is not None:
        artifact.add_to_version_family(artifact_previous, version=census_version)

# %% [markdown]
# ## Register metadata

# %% [markdown]
# ### Register new features and parent labels

# %%
artifacts = ln.Artifact.filter(key__contains=census_version).all()

# %%
from cellxgene_lamin.dev._features import register_obs_schema

# %%
if not artifacts[0].feature_sets.filter(name="obs metadata").exists():
    obs_feature_set = register_obs_schema(artifacts)

# %%
features = ln.Feature.lookup()

# %% [markdown]
# ## organisms

# %%
from cellxgene_lamin.dev._organism import register_organisms, curate_organisms

# %%
register_organisms(cxg_datasets)
# Out:
# ✓ created 7 Organism records from Bionty matching ontology_id: 'NCBITaxon:9825', 'NCBITaxon:7955', 'NCBITaxon:9598', 'NCBITaxon:9483', 'NCBITaxon:9544', 'NCBITaxon:9606', 'NCBITaxon:10090'

# %% [markdown]
# Link collections and organisms to artifacts:

# %%
curate_organisms(artifacts, cxg_datasets)

# %% [markdown]
# ## ontologies

# %% [markdown]
# Register all ontology ids:

# %%
from cellxgene_lamin.dev._ontology import register_ontology_ids

# %%
register_ontology_ids(cxg_datasets)
# Out:
# registering organism
# registering assay
# ✓ created 43 ExperimentalFactor records from Bionty matching ontology_id: 'EFO:0008919', 'EFO:0030007', 'EFO:0700016', 'EFO:0008780', 'EFO:0030074', 'EFO:0030060', 'EFO:0030027', 'EFO:0011025', 'EFO:0010891', 'EFO:0009919', 'EFO:0700003', 'EFO:0030003', 'EFO:0030002', 'EFO:0008877', 'EFO:0030028', 'EFO:0008953', 'EFO:0700004', 'EFO:0009922', 'EFO:0700010', 'EFO:0008931', ...
# • did not create ExperimentalFactor records for 2 non-validated ontology_ids: 'EFO:0022845', 'EFO:0022857'
# registered 2 records: [ExperimentalFactor(uid='6pMVJ6Yh', name='modified STRT-seq', ontology_id='EFO:0022845',
# branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object
# at 0x75e4f4759100>), ExperimentalFactor(uid='40SRG66e', name='Visium Spatial Gene Expression V1',
# ontology_id='EFO:0022857', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e416f2f5c0>)]
# registering cell_type
# ✓ created 1019 CellType records from Bionty matching ontology_id: 'CL:1000497', 'CL:0008036', 'CL:4023111', 'CL:0000221', 'CL:0002488', 'CL:0000216', 'CL:0001072', 'CL:0000586', 'CL:0002543', 'CL:0002280', 'CL:1000398', 'CL:4033057', 'CL:0002677', 'CL:0000017', 'CL:0002131', 'CL:1000349', 'CL:0000650', 'CL:0000038', 'CL:4023018', 'CL:4030064', ...
# • did not create CellType records for 13 non-validated ontology_ids: 'CL:4033085', 'CL:4033095', 'CL:4033096', 'CL:4042021', 'CL:4052001', 'CL:4052010', 'CL:4052024', 'CL:4052025', 'CL:4052026', 'CL:4052030', 'CL:4052048', 'CL:4052049', 'unknown'
# registered 13 records: [CellType(uid='6OWLOd3F', name='pre-theca cell', ontology_id='CL:4052010', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4ee9c7290>), CellType(uid='7fgr3Y0o', name='type IIx muscle cell', ontology_id='CL:4052026', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e3f7cc7680>), CellType(uid='5Tzidq34', name='myotendinous junction nucleus', ontology_id='CL:4052024',
# branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object
# at 0x75e3f7cc7ce0>), CellType(uid='1PhIACXG', name='intercalated cell of salivary gland', ontology_id='CL:4052048',
# branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object
# at 0x75e3f86e8260>), CellType(uid='3pjBT8T0', name='diffuse bipolar 5 cell', ontology_id='CL:4033085', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e3f86eac90>), CellType(uid='3vbjn26v', name='adventitial fibroblast', ontology_id='CL:4052030', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4f5b30bf0>), CellType(uid='1SzWp2DE', name='neuromuscular junction nucleus', ontology_id='CL:4052025',
# branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object
# at 0x75e4f5b31550>), CellType(uid='5HWRj1OD', name='unknown', ontology_id='unknown', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4f5b322d0>),
# CellType(uid='3sDJllGL', name='striated cell of salivary gland', ontology_id='CL:4052049', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4f5b30530>),
# CellType(uid='19EpXFep', name='diffuse bipolar 4b cell', ontology_id='CL:4033096', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4f5b31580>),
# CellType(uid='1DwAMipO', name='diffuse bipolar 4a cell', ontology_id='CL:4033095', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4f5b30830>),
# CellType(uid='4L12MdXX', name='multiciliated ependymal cell', ontology_id='CL:4052001', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4f5b336e0>),
# CellType(uid='1c2lQgER', name='neuronal-restricted precursor', ontology_id='CL:4042021', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4f5b30650>)]
# registering development_stage
# ✓ created 189 DevelopmentalStage records from Bionty matching ontology_id: 'HsapDv:0000024', 'HsapDv:0000214', 'HsapDv:0000057', 'HsapDv:0000192', 'HsapDv:0000183', 'HsapDv:0000152', 'HsapDv:0000058', 'HsapDv:0000071', 'HsapDv:0000163', 'HsapDv:0000244', 'HsapDv:0000030', 'HsapDv:0000108', 'HsapDv:0000063', 'HsapDv:0000154', 'HsapDv:0000201', 'HsapDv:0000050', 'HsapDv:0000229', 'HsapDv:0000262', 'HsapDv:0000208', 'HsapDv:0000101', ...
# • did not create DevelopmentalStage records for 88 non-validated ontology_ids: 'HsapDv:0000274', 'MmusDv:0000019', 'MmusDv:0000020', 'MmusDv:0000021', 'MmusDv:0000022', 'MmusDv:0000023', 'MmusDv:0000024', 'MmusDv:0000025', 'MmusDv:0000026', 'MmusDv:0000027', 'MmusDv:0000028', 'MmusDv:0000029', 'MmusDv:0000032', 'MmusDv:0000033', 'MmusDv:0000034', 'MmusDv:0000035', 'MmusDv:0000036', 'MmusDv:0000062', 'MmusDv:0000063', 'MmusDv:0000064', ...
# ✓ created 71 DevelopmentalStage records from Bionty matching ontology_id: 'MmusDv:0000150', 'MmusDv:0000033', 'MmusDv:0000166', 'MmusDv:0000083', 'MmusDv:0000019', 'MmusDv:0000035', 'MmusDv:0000115', 'MmusDv:0000079', 'MmusDv:0000154', 'MmusDv:0000125', 'MmusDv:0000164', 'MmusDv:0000158', 'MmusDv:0000032', 'MmusDv:0000117', 'MmusDv:0000128', 'MmusDv:0000110', 'MmusDv:0000169', 'MmusDv:0000141', 'MmusDv:0000143', 'MmusDv:0000137', ...
# • did not create DevelopmentalStage records for 17 non-validated ontology_ids: 'HsapDv:0000274', 'UBERON:0000113', 'UBERON:0007220', 'UBERON:0007222', 'UBERON:0018241', 'UBERON:0034919', 'ZFS:0000026', 'ZFS:0000027', 'ZFS:0000028', 'ZFS:0000029', 'ZFS:0000030', 'ZFS:0000031', 'ZFS:0000032', 'ZFS:0000033', 'ZFS:0000034', 'ZFS:0000035', 'unknown'
# ✓ created 1 Tissue record from Bionty matching ontology_id: 'UBERON:0007222'
# ✓ created 1 Tissue record from Bionty matching ontology_id: 'UBERON:0000113'
# ✓ created 1 Tissue record from Bionty matching ontology_id: 'UBERON:0007220'
# ✓ created 1 Tissue record from Bionty matching ontology_id: 'UBERON:0034919'
# ✓ created 1 Tissue record from Bionty matching ontology_id: 'UBERON:0018241'
# registered 72 records: [DevelopmentalStage(uid='7hWGfdlB', name='5-week-old stage', ontology_id='MmusDv:0000150',
# description='Immature Stage That Refers To A Mouse Which Is Over 35 Days And Under 42 Days Old.', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault
# object at 0x75e4ed03b800>), DevelopmentalStage(uid='2Jfheea8', name='Theiler stage 24',
# ontology_id='MmusDv:0000033', synonyms='TS24|E16', description='Fetal Stage During Which The Umbilical Hernia
# Disappears And There Is A Corresponding Increase In The Size Of The Peritoneal Sac.', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4ed9d4b00>), DevelopmentalStage(uid='58qbCvXj', name='20-week-old stage', ontology_id='MmusDv:0000166',
# description='Mouse Stage That Refers To A Mouse Which Is Over 140 Days And Under 147 Days Old.', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault
# object at 0x75e4ecfdacf0>), DevelopmentalStage(uid='3zllIZQN', name='12-month-old stage',
# ontology_id='MmusDv:0000083', description='Mouse Stage That Refers To A Mouse Which Is Over 12 And Under 13 Months
# Old.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdaa20>),
# DevelopmentalStage(uid='5ARageM1', name='Theiler stage 12', ontology_id='MmusDv:0000019',
# synonyms='TS12|E7.5-8.75', description='Organogenesis Stage During Which First Somites Become Visible.',
# branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdacc0>),
# DevelopmentalStage(uid='1LAvrse2', name='Theiler stage 26', ontology_id='MmusDv:0000035', synonyms='E18|TS26',
# description='Fetal Stage Defined By Long Whiskers And During Which The Eyes Are Barely Visible Through The Closed
# Eyelids.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdaf60>),
# DevelopmentalStage(uid='1G2cYN3E', name='5-day-old stage', ontology_id='MmusDv:0000115', description='Immature
# Stage That Refers To A Mouse Which Is Over 5 And Under 6 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdb140>),
# DevelopmentalStage(uid='7bknTrNT', name='8-month-old stage', ontology_id='MmusDv:0000079', description='Mouse Stage
# That Refers To A Mouse Which Is Over 8 And Under 9 Months Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdb320>),
# DevelopmentalStage(uid='HpQf6Ku1', name='8-week-old stage', ontology_id='MmusDv:0000154', description='Mouse Stage
# That Refers To A Mouse Which Is Over 56 Days And Under 63 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdb500>),
# DevelopmentalStage(uid='7KPBl5fq', name='21-month-old stage', ontology_id='MmusDv:0000125', description='Mouse
# Stage That Refers To A Mouse Which Is Over 21 And Under 22 Months Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdb6e0>),
# DevelopmentalStage(uid='5U1pWWne', name='18-week-old stage', ontology_id='MmusDv:0000164', description='Mouse Stage
# That Refers To A Mouse Which Is Over 126 Days And Under 133 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdb8c0>),
# DevelopmentalStage(uid='1nfBXh51', name='12-week-old stage', ontology_id='MmusDv:0000158', description='Mouse Stage
# That Refers To A Mouse Which Is Over 84 Days And Under 91 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdbaa0>),
# DevelopmentalStage(uid='Pqb1f4t4', name='Theiler stage 23', ontology_id='MmusDv:0000032', synonyms='E15|TS23',
# description='Fetal Stage During Which The Toes Separate And Hair Follicles Are Present In The Cephalic Region But
# Not At The Periphery Of The Vibrissae.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdbc80>),
# DevelopmentalStage(uid='49Pg7JZU', name='7-day-old stage', ontology_id='MmusDv:0000117', description='Immature
# Stage That Refers To A Mouse Which Is Over 7 And Under 8 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdbe30>),
# DevelopmentalStage(uid='63CjP7vl', name='24-month-old stage', ontology_id='MmusDv:0000128', description='Mouse
# Stage That Refers To A Mouse Which Is Over 24 And Under 25 Months Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdbf20>),
# DevelopmentalStage(uid='7Mpm6lfa', name='mature stage', ontology_id='MmusDv:0000110', synonyms='mature',
# description='Mouse Developmental Stage That Refers To A Sexually Mature Adult Mouse Which Is Over 6 Weeks Old.',
# branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdbc50>),
# DevelopmentalStage(uid='5YSSHEQ8', name='23-week-old stage', ontology_id='MmusDv:0000169', description='Mouse Stage
# That Refers To A Mouse Which Is Over 161 Days And Under 168 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfdbe00>),
# DevelopmentalStage(uid='6f8pruzF', name='2-week-old stage', ontology_id='MmusDv:0000141', description='Immature
# Stage That Refers To A Mouse Which Is Over 14 Days And Under 21 Days Old.', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4ecfdbfe0>), DevelopmentalStage(uid='61YeUQXo', name='22-day-old stage', ontology_id='MmusDv:0000143',
# description='Immature Stage That Refers To A Mouse Which Is Over 22 And Under 23 Days Old.', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault
# object at 0x75e4ecfdbd40>), DevelopmentalStage(uid='7Yuy1yVn', name='3-6 month-old mature stage',
# ontology_id='MmusDv:0000137', description='Mature Stage That Refers To A Mouse Which Is Over 3 And Under 7 Months
# Old.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1c980>),
# DevelopmentalStage(uid='4bOIfHwZ', name='17-week-old stage', ontology_id='MmusDv:0000163', description='Mouse Stage
# That Refers To A Mouse Which Is Over 119 Days And Under 126 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1cb60>),
# DevelopmentalStage(uid='2dIcRMOg', name='2-month-old stage', ontology_id='MmusDv:0000062', description='Early Adult
# Stage That Refers To A Mouse Which Is Over 2 And Under 3 Months Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1cd10>),
# DevelopmentalStage(uid='3mTmuF1r', name='15-week-old stage', ontology_id='MmusDv:0000161', description='Mouse Stage
# That Refers To A Mouse Which Is Over 105 Days And Under 112 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1cef0>),
# DevelopmentalStage(uid='4MDkCaoA', name='21-day-old stage', ontology_id='MmusDv:0000142', description='Immature
# Stage That Refers To A Mouse Which Is Over 21 And Under 22 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1d0a0>),
# DevelopmentalStage(uid='4qgAXaE8', name='16-month-old stage', ontology_id='MmusDv:0000087', description='Mouse
# Stage That Refers To A Mouse Which Is Over 16 And Under 17 Months Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1d250>),
# DevelopmentalStage(uid='01DkEhr2', name='prime adult stage', ontology_id='MmusDv:0000136', description='Mature
# Stage That Refers To A Adult Mouse Which Is Over 6 Weeks And Under 18 Months Old.', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4ece1d430>), DevelopmentalStage(uid='2hKkI9Jd', name='Theiler stage 25', ontology_id='MmusDv:0000034',
# synonyms='TS25|E17', description='Fetal Stage During Which The Thickened Skin Forms Wrinkles And The Subcutaneous
# Veins Are Less Visible.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1d610>),
# DevelopmentalStage(uid='4sYylzCH', name='Theiler stage 19', ontology_id='MmusDv:0000026',
# synonyms='E11-12.25|TS19', description='Organogenesis Stage During Which The Lens Vesicle Becomes Completely Closed
# And Detached From The Ectoderm, And Peripheral Margins Of The Eye Become Well Defined.', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4ece1d7f0>), DevelopmentalStage(uid='32DUFVQO', name='Theiler stage 21', ontology_id='MmusDv:0000028',
# synonyms='TS21|E12.5-14', description='Organogenesis Stage During Which The Digit Widths And Locations Can Be
# Discerned, And The Pinna Rapidly Develops And Forms A Crest At Right Angles To The Head.', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4ece1d9d0>), DevelopmentalStage(uid='2pX53Jc6', name='9-week-old stage', ontology_id='MmusDv:0000155',
# description='Mouse Stage That Refers To A Mouse Which Is Over 63 Days And Under 70 Days Old.', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault
# object at 0x75e4ece1dbb0>), DevelopmentalStage(uid='3omNfrfT', name='6-month-old stage',
# ontology_id='MmusDv:0000077', description='Mouse Stage That Refers To A Mouse Which Is Over 6 And Under 7 Months
# Old.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1dd90>),
# DevelopmentalStage(uid='7Fww1Vz6', name='4-week-old stage', ontology_id='MmusDv:0000149', description='Immature
# Stage That Refers To A Mouse Which Is Over 28 Days And Under 35 Days Old.', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4ece1df70>), DevelopmentalStage(uid='1BvdbKGo', name='1-week-old stage', ontology_id='MmusDv:0000140',
# description='Immature Stage That Refers To A Mouse Which Is Over 7 Days And Under 14 Days Old.', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault
# object at 0x75e4ece1dfd0>), DevelopmentalStage(uid='1MrvbhZk', name='19-week-old stage',
# ontology_id='MmusDv:0000165', description='Mouse Stage That Refers To A Mouse Which Is Over 133 Days And Under 140
# Days Old.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1e1e0>),
# DevelopmentalStage(uid='3L0H6wXj', name='29-week-old stage', ontology_id='MmusDv:0000175', description='Mouse Stage
# That Refers To A Mouse Which Is Over 203 Days And Under 210 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1e480>),
# DevelopmentalStage(uid='1tVg0V84', name='16-week-old stage', ontology_id='MmusDv:0000162', description='Mouse Stage
# That Refers To A Mouse Which Is Over 112 Days And Under 119 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1e630>),
# DevelopmentalStage(uid='1klmcp0M', name='6-week-old stage', ontology_id='MmusDv:0000151', description='Prime Adult
# Stage That Refers To A Mouse Which Is Over 42 Days And Under 49 Days Old.', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4ece1e810>), DevelopmentalStage(uid='1r5BWRvz', name='Theiler stage 27', ontology_id='MmusDv:0000036',
# synonyms='newborn stage', description='Stage That Refers To The Newborn Mouse, Aged E19-20, P0. Description Of
# Anatomical Structures Related To This Stage Corresponds To The First Days Of The Mouse Life. Used For Postnatal
# Days 0 Through 3.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfd99d0>),
# DevelopmentalStage(uid='2pJEX16R', name='Theiler stage 16', ontology_id='MmusDv:0000023',
# synonyms='E9.5-10.75|TS16', description='Organogenesis Stage During Which The Posterior Neuropore Closes And The
# Hind Limb Bud Becomes Visible At The Level Of The 23Rd-28Th Somites.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfda060>),
# DevelopmentalStage(uid='579u5n8c', name='11-week-old stage', ontology_id='MmusDv:0000157', description='Mouse Stage
# That Refers To A Mouse Which Is Over 77 Days And Under 84 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfda030>),
# DevelopmentalStage(uid='6e2puOaf', name='10-week-old stage', ontology_id='MmusDv:0000156', description='Mouse Stage
# That Refers To A Mouse Which Is Over 70 Days And Under 77 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfd9250>),
# DevelopmentalStage(uid='51yjBKkm', name='15-month-old stage', ontology_id='MmusDv:0000086', description='Mouse
# Stage That Refers To A Mouse Which Is Over 15 And Under 16 Months Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecfd99a0>),
# DevelopmentalStage(uid='6eHaCRoE', name='24-week-old stage', ontology_id='MmusDv:0000170', description='Mouse Stage
# That Refers To A Mouse Which Is Over 168 Days And Under 175 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1ee10>),
# DevelopmentalStage(uid='4APBGk8B', name='26-week-old stage', ontology_id='MmusDv:0000172', description='Mouse Stage
# That Refers To A Mouse Which Is Over 182 Days And Under 189 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1eff0>),
# DevelopmentalStage(uid='2AnlRnpO', name='4-day-old stage', ontology_id='MmusDv:0000114', description='Immature
# Stage That Refers To A Mouse Which Is Over 4 And Under 5 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1f1d0>),
# DevelopmentalStage(uid='2KwxDig7', name='7-week-old stage', ontology_id='MmusDv:0000152', description='Prime Adult
# Stage That Refers To A Mouse Which Is Over 49 Days And Under 56 Days Old.', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4ece1f3b0>), DevelopmentalStage(uid='isuVqi01', name='Theiler stage 22', ontology_id='MmusDv:0000029',
# synonyms='TS22|E13.5-15', description='Organogenesis Stage During Which The Fingers Are Clearly Visible And The
# Long Bones Of The Limbs Are Present.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1f590>),
# DevelopmentalStage(uid='1eYj3JvF', name='Theiler stage 15', ontology_id='MmusDv:0000022', synonyms='TS15|E9-10.25',
# description='Organogenesis Stage During Which The Posterior Neuropore Forms And The Condensation Of The Forelimb
# Bud Becomes Apparent Near The 8Th-12Th Somite Pairs.', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1f740>),
# DevelopmentalStage(uid='2uKiNrC1', name='20-month-old stage and over', ontology_id='MmusDv:0000091',
# description='Mouse Stage That Refers To A Mouse Which Is Over 20 Months Old.', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4ece1f920>), DevelopmentalStage(uid='2qMr4FYE', name='22-week-old stage', ontology_id='MmusDv:0000168',
# description='Mouse Stage That Refers To A Mouse Which Is Over 154 Days And Under 161 Days Old.', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault
# object at 0x75e4ece1fb00>), DevelopmentalStage(uid='3iWIOJxB', name='25-week-old stage',
# ontology_id='MmusDv:0000171', description='Mouse Stage That Refers To A Mouse Which Is Over 175 Days And Under 182
# Days Old.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1fbf0>),
# DevelopmentalStage(uid='4oDq81f6', name='Theiler stage 17', ontology_id='MmusDv:0000024',
# synonyms='E10-11.25|TS17', description='Organogenesis Stage Defined By The Deepening Of The Lens Pit And The First
# Appearance Of The Physiological Umbilical Hernia.', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1fe90>),
# DevelopmentalStage(uid='3wDLorw8', name='postnatal stage', ontology_id='MmusDv:0000092', description='Mouse
# Developmental Stage That Covers The Period From Birth Until Late Adulthood.', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4ece1ff80>), DevelopmentalStage(uid='4Ne2xatT', name='3-month-old stage', ontology_id='MmusDv:0000063',
# description='Early Adult Stage That Refers To A Mouse Which Is Over 3 And Under 4 Months Old.', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault
# object at 0x75e4ece1f950>), DevelopmentalStage(uid='7lTEHsRA', name='23-day-old stage',
# ontology_id='MmusDv:0000144', description='Immature Stage That Refers To A Mouse Which Is Over 23 And Under 24 Days
# Old.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1fef0>),
# DevelopmentalStage(uid='29miS5O0', name='juvenile stage', ontology_id='MmusDv:0000178', description='Mouse Stage
# That Refers To A Weaned Mouse Which Is Over 23 Days Old, While Still Being An Sexually Immature Mouse.',
# branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1fc80>),
# DevelopmentalStage(uid='3zLPAVe1', name='4-month-old stage', ontology_id='MmusDv:0000064', description='Early Adult
# Stage That Refers To A Mouse Which Is Over 4 And Under 5 Months Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece1fe00>),
# DevelopmentalStage(uid='6hon5R7L', name='14-month-old stage', ontology_id='MmusDv:0000085', description='Mouse
# Stage That Refers To A Mouse Which Is Over 14 And Under 15 Months Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece289b0>),
# DevelopmentalStage(uid='738nU1dc', name='21-week-old stage', ontology_id='MmusDv:0000167', description='Mouse Stage
# That Refers To A Mouse Which Is Over 147 Days And Under 154 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece28b90>),
# DevelopmentalStage(uid='5ombV1q8', name='Theiler stage 14', ontology_id='MmusDv:0000021',
# synonyms='TS14|E8.5-9.75', description='Organogenesis Stage During Which The Rostral Extremity Of The Neural Tube
# Closes In Embryos With Usually About 15-18 Somite Pairs. Late In The Stage The 3Rd Branchial Arch Becomes
# Visible.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece28d70>),
# DevelopmentalStage(uid='5jF1wDfT', name='13-week-old stage', ontology_id='MmusDv:0000159', description='Mouse Stage
# That Refers To A Mouse Which Is Over 91 Days And Under 98 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece28f50>),
# DevelopmentalStage(uid='4vN31Q5K', name='Theiler stage 18', ontology_id='MmusDv:0000025',
# synonyms='E10.5-11.25|TS18', description='Organogenesis Stage During Which The Lens Vesicle Gradually Closes And
# The Nasal Pits Start To Form. The Rapid Growth Of The Brain Is Striking.', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4ece29130>), DevelopmentalStage(uid='52jMWCgh', name='Theiler stage 13', ontology_id='MmusDv:0000020',
# synonyms='TS13|E8-9.25', description='Organogenesis Stage Defined By The Turning Of The Embryo; Initiated In
# Embryos With 6-8 Pairs Of Somites And Usually Completed In Embryos With 14-16 Pairs Of Somites.', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault
# object at 0x75e4ece29310>), DevelopmentalStage(uid='1cuR7uGe', name='14-week-old stage',
# ontology_id='MmusDv:0000160', description='Mouse Stage That Refers To A Mouse Which Is Over 98 Days And Under 105
# Days Old.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece294f0>),
# DevelopmentalStage(uid='2dlyP4YN', name='26-day-old stage', ontology_id='MmusDv:0000147', description='Immature
# Stage That Refers To A Mouse Which Is Over 26 And Under 27 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece296d0>),
# DevelopmentalStage(uid='6w6AM2mg', name='19-month-old stage', ontology_id='MmusDv:0000090', description='Mouse
# Stage That Refers To A Mouse Which Is Over 19 And Under 20 Months Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece298b0>),
# DevelopmentalStage(uid='AvCk12L1', name='Theiler stage 20', ontology_id='MmusDv:0000027', synonyms='TS20|E11.5-13',
# description='Organogenesis Stage During Which The Handplate Develops Angles Corresponding To The Future Digits, And
# Tongue And Brain Vesicles Are Clearly Visible.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=31,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece29a90>),
# DevelopmentalStage(uid='5z7PeStS', name='9-month-old stage', ontology_id='MmusDv:0000080', description='Mouse Stage
# That Refers To A Mouse Which Is Over 9 And Under 10 Months Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece29c70>),
# DevelopmentalStage(uid='2MUm7ISN', name='18-month-old stage', ontology_id='MmusDv:0000089', description='Mouse
# Stage That Refers To A Mouse Which Is Over 18 And Under 19 Months Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece29e50>),
# DevelopmentalStage(uid='5mtgTM7U', name='5-month-old stage', ontology_id='MmusDv:0000069', description='Mouse Stage
# That Refers To A Mouse Which Is Over 5 And Under 6 Months Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece29f40>),
# DevelopmentalStage(uid='2GXZp7hY', name='24-day-old stage', ontology_id='MmusDv:0000145', description='Immature
# Stage That Refers To A Mouse Which Is Over 24 And Under 25 Days Old.', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, source_id=31, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ece2a1e0>),
# DevelopmentalStage(uid='5HWRj1OD', name='unknown', ontology_id='unknown', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ee992600>)]
# registering disease
# ✓ created 168 Disease records from Bionty matching ontology_id: 'MONDO:0005109', 'MONDO:0009831', 'MONDO:0005005', 'MONDO:0000265', 'MONDO:0016468', 'MONDO:0005087', 'MONDO:0600025', 'MONDO:0003050', 'MONDO:0004781', 'MONDO:0003573', 'MONDO:0003004', 'MONDO:0001150', 'MONDO:0005180', 'MONDO:0005828', 'MONDO:0005565', 'MONDO:0005453', 'MONDO:0018874', 'MONDO:0004970', 'MONDO:0007763', 'MONDO:0011705', ...
# • did not create Disease records for 4 non-validated ontology_ids: 'MONDO:0004981 || MONDO:1030008', 'MONDO:0005109 || MONDO:0005445', 'MONDO:0005109 || MONDO:0011989', 'PATO:0000461'
# ✓ created 1 Phenotype record from Bionty matching ontology_id: 'PATO:0000461'
# registered 3 records: [Disease(uid='6QZ1MMrT', name='HIV infectious disease || leishmaniasis',
# ontology_id='MONDO:0005109 || MONDO:0011989', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4c87d12e0>), Disease(uid='3oV6UwXt',
# name='atrial fibrillation || mitral valve insufficiency', ontology_id='MONDO:0004981 || MONDO:1030008',
# branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object
# at 0x75e4f5b23350>), Disease(uid='3g4NA6wn', name='HIV infectious disease || visceral leishmaniasis',
# ontology_id='MONDO:0005109 || MONDO:0005445', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4ecf33050>)]
# registering self_reported_ethnicity
# ✓ created 35 Ethnicity records from Bionty matching ontology_id: 'HANCESTRO:0005', 'HANCESTRO:0025', 'HANCESTRO:0016', 'HANCESTRO:0598', 'HANCESTRO:0009', 'HANCESTRO:0027', 'HANCESTRO:0364', 'HANCESTRO:0500', 'HANCESTRO:0463', 'HANCESTRO:0014', 'HANCESTRO:0485', 'HANCESTRO:0352', 'HANCESTRO:0597', 'HANCESTRO:0487', 'HANCESTRO:0595', 'HANCESTRO:0439', 'HANCESTRO:0021', 'HANCESTRO:0019', 'HANCESTRO:0022', 'HANCESTRO:0007', ...
# • did not create Ethnicity records for 5 non-validated ontology_ids: 'HANCESTRO:0005 || HANCESTRO:0008', 'HANCESTRO:0013 || HANCESTRO:0014', 'HANCESTRO:0014 || HANCESTRO:0590', 'na', 'unknown'
# registered 5 records: [Ethnicity(uid='27sL2Xlf', name='Hispanic or Latin American || European American',
# ontology_id='HANCESTRO:0014 || HANCESTRO:0590', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b3ba84a0>), Ethnicity(uid='3N1q01iC',
# name='na', ontology_id='na', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4f566fda0>), Ethnicity(uid='6UZltq3T',
# name='European || Asian', ontology_id='HANCESTRO:0005 || HANCESTRO:0008', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4f566c3e0>),
# Ethnicity(uid='5HWRj1OD', name='unknown', ontology_id='unknown', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4e1c9d040>),
# Ethnicity(uid='6W1N178x', name='Native American || Hispanic or Latin American', ontology_id='HANCESTRO:0013 ||
# HANCESTRO:0014', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4e1c9d640>)]
# registering sex
# ✓ created 2 Phenotype records from Bionty matching ontology_id: 'PATO:0000383', 'PATO:0000384'
# • did not create Phenotype record for 1 non-validated ontology_id: 'unknown'
# registered 1 records: [Phenotype(uid='5HWRj1OD', name='unknown', ontology_id='unknown', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b1848d70>)]
# registering tissue
# ✓ created 592 Tissue records from Bionty matching ontology_id: 'UBERON:0004167', 'UBERON:0003017', 'UBERON:0002113', 'UBERON:0002116', 'UBERON:0002550', 'UBERON:0005406', 'UBERON:0001809', 'UBERON:0001985', 'UBERON:0002060', 'UBERON:0002657', 'UBERON:0001238', 'UBERON:0001295', 'UBERON:0004262', 'UBERON:0003059', 'UBERON:0013706', 'UBERON:0002351', 'UBERON:0035886', 'UBERON:0004499', 'UBERON:0002328', 'UBERON:0001830', ...
# • did not create Tissue records for 14 non-validated ontology_ids: 'CL:0000010', 'CL:0000082', 'CL:0000084', 'CL:0000115', 'CL:0000307', 'CL:0000322', 'CL:0000351', 'CL:0002322', 'CL:0002327', 'CL:0002328', 'CL:0002334', 'CL:0002335', 'CL:0002633', 'CL:4052001'
# registered 14 records: [Tissue(uid='2mqTx1qQ', name='epithelial cell of lung', ontology_id='CL:0000082',
# branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object
# at 0x75e4b18c54f0>), Tissue(uid='1LzSyCsJ', name='respiratory basal cell', ontology_id='CL:0002633', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4b2347e30>), Tissue(uid='XS6m3PvU', name='cultured cell', ontology_id='CL:0000010', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b233be30>),
# Tissue(uid='1ERsVqRf', name='embryonic stem cell', ontology_id='CL:0002322', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b25f01d0>),
# Tissue(uid='wxc6eyuU', name='pulmonary alveolar epithelial cell', ontology_id='CL:0000322', branch_id=1,
# space_id=1, created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at
# 0x75e4b0c38ce0>), Tissue(uid='4IRoehoY', name='preadipocyte', ontology_id='CL:0002334', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b0c387a0>),
# Tissue(uid='5F4YNEUS', name='mammary gland epithelial cell', ontology_id='CL:0002327', branch_id=1, space_id=1,
# created_by_id=1, run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b0c38920>),
# Tissue(uid='1J6s4gSi', name='endothelial cell', ontology_id='CL:0000115', branch_id=1, space_id=1, created_by_id=1,
# run_id=1, created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b0c39490>),
# Tissue(uid='22LvKd01', name='T cell', ontology_id='CL:0000084', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b0c39610>), Tissue(uid='MJYdRbdq',
# name='bronchial epithelial cell', ontology_id='CL:0002328', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b0c39880>), Tissue(uid='7MscrSDl',
# name='trophoblast cell', ontology_id='CL:0000351', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b0c39a00>), Tissue(uid='4L12MdXX',
# name='multiciliated ependymal cell', ontology_id='CL:4052001', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b0c39be0>), Tissue(uid='3bgY2Yz8',
# name='tracheal epithelial cell', ontology_id='CL:0000307', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b0c38bf0>), Tissue(uid='8dEt6lpw',
# name='brown preadipocyte', ontology_id='CL:0002335', branch_id=1, space_id=1, created_by_id=1, run_id=1,
# created_at=<django.db.models.expressions.DatabaseDefault object at 0x75e4b0c39dc0>)]

# %%
# clean up the celltype in Tissue

bt.Tissue.filter(ontology_id="CL:0000307").delete()
bt.CellType.from_source(ontology_id="CL:0000307").save()
# Out:
# CellType(uid='3bgY2Yz8', name='tracheal epithelial cell', ontology_id='CL:0000307', synonyms='tracheocyte', description='An Epithelial Cell Found In The Trachea.', branch_id=1, space_id=1, created_by_id=1, run_id=1, source_id=16, created_at=2025-07-23 09:26:55 UTC)

# %% [markdown]
# ## donors and suspension_types

# %%
from cellxgene_lamin.dev._labels import register_ulabels

# %%
ln.settings.creation.search_names = False
register_ulabels(cxg_datasets, "donor_id")
ln.settings.creation.search_names = True
# Out:
# registered 13075 donor_ids

# %%
ln.settings.creation.search_names = False
register_ulabels(cxg_datasets, "suspension_type")
ln.settings.creation.search_names = True
# Out:
# registered 3 suspension_types

# %% [markdown]
# ## Annotate artifacts with obs metadata

# %%
from cellxgene_lamin.dev._features import FEATURE_TO_ACCESSOR

# %%
import bionty as bt

features = ln.Feature.lookup()

for idx, cxg_dataset in enumerate(cxg_datasets):
    if idx % 100 == 0:
        print(f"annotating dataset {idx} of {len(cxg_datasets)}")
    artifact = artifacts.filter(key__contains=cxg_dataset["dataset_id"]).one_or_none()
    if artifact is None:
        continue
    for field, terms in cxg_dataset.items():
        if field not in FEATURE_TO_ACCESSOR:
            continue
        accessor, orm = FEATURE_TO_ACCESSOR.get(field)
        if field in ["donor_id", "suspension_type", "tissue_type"]:
            records = orm.from_values(terms, field="name")
            if len(records) > 0:
                # stratify by feature so that link tables records are written
                getattr(artifact, accessor).add(*records)
        else:
            if field == "tissue":
                records = []
                celltypes = [
                    term["ontology_term_id"]
                    for term in terms
                    if term["tissue_type"] == "cell culture"
                ]
                if len(celltypes) > 0:
                    # records += bt.CellType.from_values(
                    #     [i["ontology_term_id"] for i in terms], field="ontology_id"
                    # )
                    print(f"These tissues are not yet linked: {celltypes}")
                tissues = [
                    term["ontology_term_id"]
                    for term in terms
                    if term["tissue_type"] != "cell culture"
                ]
                if len(tissues) > 0:
                    records += bt.Tissue.from_values(
                        [term["ontology_term_id"] for term in terms],
                        field="ontology_id",
                    )
            else:
                records = orm.from_values(
                    [term["ontology_term_id"] for term in terms], field="ontology_id"
                )
            if len(records) > 0:
                getattr(artifact, accessor).add(*records)

# clean up the 2 "unknowns" in DevelopmentalStage
bt.DevelopmentalStage.filter(name="unknown").exclude(ontology_id="unknown").delete()
# Out:
# annotating dataset 0 of 1844
# annotating dataset 100 of 1844
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004981 || MONDO:1030008'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 3 Disease records matching ontology_id: 'MONDO:0005570', 'MONDO:0018881', 'MONDO:0020077'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 3 Disease records matching ontology_id: 'MONDO:0005570', 'MONDO:0018881', 'MONDO:0020077'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005002'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# These tissues are not yet linked: ['CL:0000082']
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0044704'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005180'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005068'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 3 Disease records matching ontology_id: 'MONDO:0005010', 'MONDO:0002869', 'MONDO:0005068'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 3 Disease records matching ontology_id: 'MONDO:0005252', 'MONDO:0002869', 'MONDO:0024644'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# annotating dataset 200 of 1844
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005002'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0004975', 'MONDO:0800027'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0004975', 'MONDO:0800027'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0004975', 'MONDO:0800027'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0004975', 'MONDO:0800027'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0004975', 'MONDO:0800027'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0002233', 'MONDO:0006937'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# annotating dataset 300 of 1844
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005046'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0010030'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0010030'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005046'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005046'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 3 Disease records matching ontology_id: 'MONDO:0004975', 'MONDO:0008243', 'MONDO:0019037'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005045'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0008383'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# annotating dataset 400 of 1844
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# These tissues are not yet linked: ['CL:0000084']
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005244'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:1010239'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:1010239'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005244'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005244'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:1010239'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 3 Disease records matching ontology_id: 'MONDO:0005109', 'MONDO:0005109 || MONDO:0011989', 'MONDO:0005109 || MONDO:0005445'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# annotating dataset 500 of 1844
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0008054'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0002492', 'MONDO:0005300'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0002492', 'MONDO:0005300'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 3 Disease records matching ontology_id: 'MONDO:0001943', 'MONDO:0005828', 'MONDO:0005989'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0021178'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 3 Disease records matching ontology_id: 'MONDO:0021178', 'MONDO:0005348', 'MONDO:0019562'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0020804'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0020804'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100542'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0003004'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# annotating dataset 600 of 1844
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005530'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0005388', 'MONDO:0013433'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0005388', 'MONDO:0013433'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0006541'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0006541'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0006541'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0006541'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0006541'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0017276'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0004976', 'MONDO:0030885'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0017276'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0004976', 'MONDO:0030885'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# annotating dataset 700 of 1844
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 3 Disease records matching ontology_id: 'MONDO:0004781', 'MONDO:0005453', 'MONDO:0005252'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005301'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 49 DevelopmentalStage records matching ontology_id: 'HsapDv:0000104', 'HsapDv:0000105', 'HsapDv:0000109', 'HsapDv:0000110', 'HsapDv:0000111', 'HsapDv:0000112', 'HsapDv:0000115', 'HsapDv:0000118', 'HsapDv:0000119', 'HsapDv:0000121', 'HsapDv:0000097', 'HsapDv:0000124', 'HsapDv:0000126', 'HsapDv:0000128', 'HsapDv:0000135', 'HsapDv:0000137', 'HsapDv:0000140', 'HsapDv:0000141', 'HsapDv:0000144', 'HsapDv:0000146', ...
# • did not create DevelopmentalStage record for 1 non-validated ontology_id: 'HsapDv:0000274'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 49 DevelopmentalStage records matching ontology_id: 'HsapDv:0000104', 'HsapDv:0000105', 'HsapDv:0000109', 'HsapDv:0000110', 'HsapDv:0000111', 'HsapDv:0000112', 'HsapDv:0000115', 'HsapDv:0000118', 'HsapDv:0000119', 'HsapDv:0000121', 'HsapDv:0000097', 'HsapDv:0000124', 'HsapDv:0000126', 'HsapDv:0000128', 'HsapDv:0000135', 'HsapDv:0000137', 'HsapDv:0000140', 'HsapDv:0000141', 'HsapDv:0000144', 'HsapDv:0000146', ...
# • did not create DevelopmentalStage record for 1 non-validated ontology_id: 'HsapDv:0000274'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 49 DevelopmentalStage records matching ontology_id: 'HsapDv:0000104', 'HsapDv:0000105', 'HsapDv:0000109', 'HsapDv:0000110', 'HsapDv:0000111', 'HsapDv:0000112', 'HsapDv:0000115', 'HsapDv:0000118', 'HsapDv:0000119', 'HsapDv:0000121', 'HsapDv:0000097', 'HsapDv:0000124', 'HsapDv:0000126', 'HsapDv:0000128', 'HsapDv:0000135', 'HsapDv:0000137', 'HsapDv:0000140', 'HsapDv:0000141', 'HsapDv:0000144', 'HsapDv:0000146', ...
# • did not create DevelopmentalStage record for 1 non-validated ontology_id: 'HsapDv:0000274'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 49 DevelopmentalStage records matching ontology_id: 'HsapDv:0000104', 'HsapDv:0000105', 'HsapDv:0000109', 'HsapDv:0000110', 'HsapDv:0000111', 'HsapDv:0000112', 'HsapDv:0000115', 'HsapDv:0000118', 'HsapDv:0000119', 'HsapDv:0000121', 'HsapDv:0000097', 'HsapDv:0000124', 'HsapDv:0000126', 'HsapDv:0000128', 'HsapDv:0000135', 'HsapDv:0000137', 'HsapDv:0000140', 'HsapDv:0000141', 'HsapDv:0000144', 'HsapDv:0000146', ...
# • did not create DevelopmentalStage record for 1 non-validated ontology_id: 'HsapDv:0000274'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# annotating dataset 800 of 1844
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0007488', 'MONDO:0005180'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0007488', 'MONDO:0005180'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0007488', 'MONDO:0005180'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0007488', 'MONDO:0005180'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ...
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0007915'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 2 Disease records matching ontology_id: 'MONDO:0100096', 'MONDO:0005087'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0010811'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0010811'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0010811'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0010811'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0010811'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0010811'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0010811'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# annotating dataset 1700 of 1844
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0018071'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0018071'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005148'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0002052'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0005147'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# annotating dataset 1800 of 1844
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0004975'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# ✓ loaded 1 Disease record matching ontology_id: 'MONDO:0100096'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# These tissues are not yet linked: ['CL:0002322']
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'
# • did not create Disease record for 1 non-validated ontology_id: 'PATO:0000461'

# %% [markdown]
# ## Validate and register genes

# %%
from cellxgene_lamin.dev._gene import register_genes

# %% [markdown]
# Register all genes for each organism:

# %%
register_genes()
# Out:
# ✓ created 1 Organism record from Bionty matching name: 'synthetic construct'
# ✓ created 1 Organism record from Bionty matching ontology_id: 'NCBITaxon:81077'
# ✓ created 1 Organism record from Bionty matching name: 'sars-2'
# ✓ created 1 Organism record from Bionty matching ontology_id: 'NCBITaxon:694009'
# • key has more than one suffix (path.suffixes), using only last suffix: '.parquet' - if you want your composite suffix to be recognized add it to lamindb.core.storage.VALID_SIMPLE_SUFFIXES.add()
# • path content will be copied to default storage upon `save()` with key 'df_synthetic construct__gencode_ercc__1.0.0__Gene.parquet'
# ✓ storing artifact 'e5fnB0arQ8P1q0Bp0000' at '/home/lukas/code/cellxgene-lamin/docs/notebooks/run-tests/.lamindb/e5fnB0arQ8P1q0Bp0000.parquet'
# → source added!
# • key has more than one suffix (path.suffixes), using only last suffix: '.parquet' - if you want your composite suffix to be recognized add it to lamindb.core.storage.VALID_SIMPLE_SUFFIXES.add()
# • path content will be copied to default storage upon `save()` with key 'df_sars-2__sars_cov_2__1.0.0__Gene.parquet'
# ✓ storing artifact 'isDdHxoPoxJZLUKb0000' at '/home/lukas/code/cellxgene-lamin/docs/notebooks/run-tests/.lamindb/isDdHxoPoxJZLUKb0000.parquet'
# → source added!
# registering homo_sapiens genes
# ✓ created 62595 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000290825', 'ENSG00000223972', 'ENSG00000227232', 'ENSG00000278267', 'ENSG00000243485', 'ENSG00000284332', 'ENSG00000237613', 'ENSG00000268020', 'ENSG00000290826', 'ENSG00000240361', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000233750', 'ENSG00000268903', 'ENSG00000269981', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000222623', 'ENSG00000241599', ...
# • did not create Gene records for 159 non-validated ensembl_gene_ids: 'ENSG00000203441', 'ENSG00000214783', 'ENSG00000214970', 'ENSG00000215067', 'ENSG00000223458', 'ENSG00000223797', 'ENSG00000224167', 'ENSG00000224247', 'ENSG00000225205', 'ENSG00000226032', 'ENSG00000226277', 'ENSG00000226362', 'ENSG00000226747', 'ENSG00000226822', 'ENSG00000226849', 'ENSG00000227925', 'ENSG00000228135', 'ENSG00000228434', 'ENSG00000228890', 'ENSG00000229611', ...
# ✓ 62595 unique terms (99.70%) are validated for ensembl_gene_id
# ! 159 unique terms (0.30%) are not validated for ensembl_gene_id: 'ENSG00000230699', 'ENSG00000241180', 'ENSG00000226849', 'ENSG00000272482', 'ENSG00000264443', 'ENSG00000281133', 'ENSG00000280836', 'ENSG00000281112', 'ENSG00000281825', 'ENSG00000279049', ...
# → returning existing Gene record with same symbol: 'NCMAP-DT'
# ! updated ensembl_gene_id from ENSG00000286061 to ENSG00000264443
# ! ignoring tentative value 5epqKbkXe2L4 for uid, keeping 2GTXQqv2dSpK
# ! you are trying to create a record with name='LINC01358' but records with similar symbols exist: 'LINC01342', 'LINC01346', 'LINC01345'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC02797' but records with similar symbols exist: 'LINC02780', 'LINC02781', 'LINC02782'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC02785' but records with similar symbols exist: 'LINC02780', 'LINC02781', 'LINC02782'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC01357' but records with similar symbols exist: 'LINC01342', 'LINC01346', 'LINC01345'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC01731' but records with similar symbols exist: 'LINC01786', 'LINC01770', 'LINC01777'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC01655' but records with similar symbols exist: 'LINC01646', 'LINC01672', 'LINC01647'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC02257' but records with similar symbols exist: 'LINC02238', 'LINC02245', 'LINC02270'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC03081' but records with similar symbols exist: 'LINC03037', 'LINC03063', 'LINC03050'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC01799' but records with similar symbols exist: 'LINC01786', 'LINC01770', 'LINC01777'. Did you mean to load one of them?
# ! you are trying to create a record with name='FSIP2-AS2' but a record with similar symbol exists: 'FSIP2-AS1'. Did you mean to load it?
# ! you are trying to create a record with name='LINC01494' but records with similar symbols exist: 'LINC01409', 'LINC01460', 'LINC01412'. Did you mean to load one of them?
# → returning existing Gene record with same symbol: 'ECEL1P2'
# ! updated ensembl_gene_id from ENSG00000224516 to ENSG00000290681
# ! ignoring tentative value 7VsfVOH1g9xD for uid, keeping 4wTKk7wp4nxq
# ! you are trying to create a record with name='LINC01238' but records with similar symbols exist: 'LINC01226', 'LINC01222', 'LINC01221'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC00500' but records with similar symbols exist: 'LINC00538', 'LINC00582', 'LINC00570'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC02056' but records with similar symbols exist: 'LINC02022', 'LINC02011', 'LINC02084'. Did you mean to load one of them?
# → returning existing Gene record with same symbol: 'Vault'
# ! updated ensembl_gene_id from ENSG00000252485 to ENSG00000278815
# ! ignoring tentative value 3z83kZCpnnrC for uid, keeping 5siNfg4N8kRA
# → returning existing Gene record with same symbol: 'POLR2J4'
# ! updated ensembl_gene_id from ENSG00000272655 to ENSG00000214783
# ! ignoring tentative value 4smSEXwJNay0 for uid, keeping 67ybqpJu47hA
# → returning existing Gene record with same symbol: 'LINC02851'
# ! updated ensembl_gene_id from ENSG00000225489 to ENSG00000229611
# ! ignoring tentative value 1wkMFOQjySDs for uid, keeping 6mA3nqP54fBI
# → returning existing Gene record with same symbol: 'ALG1L9P'
# ! updated ensembl_gene_id from ENSG00000254978 to ENSG00000248671
# ! ignoring tentative value 598AjyY8Xd1u for uid, keeping 7Q19sNj7j61t
# → returning existing Gene record with same symbol: 'LINC00941'
# ! updated ensembl_gene_id from ENSG00000285517 to ENSG00000235884
# ! ignoring tentative value 7E8prJzZ9jMh for uid, keeping 4FfSa8RHuBOC
# ! you are trying to create a record with name='USP12-DT' but a record with similar symbol exists: 'USP12-AS1'. Did you mean to load it?
# ! you are trying to create a record with name='LINC02340' but records with similar symbols exist: 'LINC02360', 'LINC02357', 'LINC02364'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC00545' but records with similar symbols exist: 'LINC00538', 'LINC00582', 'LINC00570'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC00407' but records with similar symbols exist: 'LINC00466', 'LINC00467', 'LINC00487'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC00560' but records with similar symbols exist: 'LINC00538', 'LINC00582', 'LINC00570'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC00449' but records with similar symbols exist: 'LINC00466', 'LINC00467', 'LINC00487'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC00443' but records with similar symbols exist: 'LINC00466', 'LINC00467', 'LINC00487'. Did you mean to load one of them?
# ! you are trying to create a record with name='LINC03061' but records with similar symbols exist: 'LINC03037', 'LINC03063', 'LINC03050'. Did you mean to load one of them?
# ! you are trying to create a record with name='HIF1A-AS1' but a record with similar symbol exists: 'HIF1A-AS3'. Did you mean to load it?
# ! you are trying to create a record with name='LINC02254' but records with similar symbols exist: 'LINC02238', 'LINC02245', 'LINC02270'. Did you mean to load one of them?
# → returning existing Gene record with same symbol: 'PKD1P6-NPIPP1'
# ! updated ensembl_gene_id from ENSG00000290394 to ENSG00000270580
# ! ignoring tentative value 30ur2TZPVGv7 for uid, keeping GNA2PKfL1QAa
# ! you are trying to create a record with name='LINC02193' but records with similar symbols exist: 'LINC02171', 'LINC02173', 'LINC02172'. Did you mean to load one of them?
# ! you are trying to create a record with name='GRAPLDR' but a record with similar symbol exists: 'GRAPL'. Did you mean to load it?
# ! you are trying to create a record with name='LINC02595' but records with similar symbols exist: 'LINC02593', 'LINC02596', 'LINC02574'. Did you mean to load one of them?
# ! you are trying to create a record with name='TTTY21B' but records with similar symbols exist: 'TTTY2', 'TTTY23B', 'TTTY23B'. Did you mean to load one of them?
# ! you are trying to create a record with name='TTTY21' but records with similar symbols exist: 'TTTY23B', 'TTTY23B', 'TTTY1B'. Did you mean to load one of them?
# → returning existing Gene record with same symbol: 'FAM41AY2'
# ! updated ensembl_gene_id from ENSG00000290726 to ENSG00000226362
# ! ignoring tentative value jSbGkFLgp6LA for uid, keeping 4o5MCnCbldQ8
# registering mus_musculus genes
# ✓ created 56867 Gene records from Bionty matching ensembl_gene_id: 'ENSMUSG00000102693', 'ENSMUSG00000064842', 'ENSMUSG00000051951', 'ENSMUSG00000102851', 'ENSMUSG00000103377', 'ENSMUSG00000104017', 'ENSMUSG00000103025', 'ENSMUSG00000089699', 'ENSMUSG00000103201', 'ENSMUSG00000103147', 'ENSMUSG00000103161', 'ENSMUSG00000102331', 'ENSMUSG00000102348', 'ENSMUSG00000102592', 'ENSMUSG00000088333', 'ENSMUSG00000102343', 'ENSMUSG00000025900', 'ENSMUSG00000102948', 'ENSMUSG00000104123', 'ENSMUSG00000025902', ...
# • did not create Gene records for 74 non-validated ensembl_gene_ids: 'ENSMUSG00000043623', 'ENSMUSG00000046145', 'ENSMUSG00000046388', 'ENSMUSG00000046747', 'ENSMUSG00000047189', 'ENSMUSG00000048316', 'ENSMUSG00000048406', 'ENSMUSG00000049202', 'ENSMUSG00000052005', 'ENSMUSG00000052241', 'ENSMUSG00000052426', 'ENSMUSG00000052779', 'ENSMUSG00000054304', 'ENSMUSG00000054379', 'ENSMUSG00000054957', 'ENSMUSG00000055216', 'ENSMUSG00000055872', 'ENSMUSG00000055958', 'ENSMUSG00000055968', 'ENSMUSG00000056682', ...
# ✓ 56867 unique terms (99.90%) are validated for ensembl_gene_id
# ! 74 unique terms (0.10%) are not validated for ensembl_gene_id: 'ENSMUSG00000067017', 'ENSMUSG00000102817', 'ENSMUSG00000075525', 'ENSMUSG00000069136', 'ENSMUSG00000048316', 'ENSMUSG00000091037', 'ENSMUSG00000075036', 'ENSMUSG00000058281', 'ENSMUSG00000052005', 'ENSMUSG00000074970', ...
# ! you are trying to create a record with name='Gm6185' but records with similar symbols exist: 'Gm6101', 'Gm6119', 'Gm6123'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10849' but records with similar symbols exist: 'Gm10862', 'Gm10857', 'Gm10855'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm9823' but records with similar symbols exist: 'Gm9826', 'Gm9884', 'Gm9898'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm17661' but records with similar symbols exist: 'Gm17644', 'Gm17634', 'Gm17619'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10805' but records with similar symbols exist: 'Gm10862', 'Gm10857', 'Gm10855'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10038' but records with similar symbols exist: 'Gm10075', 'Gm10062', 'Gm10059'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm9864' but records with similar symbols exist: 'Gm9826', 'Gm9884', 'Gm9898'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10794' but records with similar symbols exist: 'Gm10774', 'Gm10766', 'Gm10762'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm17258' but records with similar symbols exist: 'Gm17234', 'Gm17224', 'Gm17214'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10040' but records with similar symbols exist: 'Gm10075', 'Gm10062', 'Gm10059'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10702' but records with similar symbols exist: 'Gm10774', 'Gm10766', 'Gm10762'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10042' but records with similar symbols exist: 'Gm10075', 'Gm10062', 'Gm10059'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10583' but records with similar symbols exist: 'Gm10568', 'Gm10566', 'Gm10561'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10582' but records with similar symbols exist: 'Gm10568', 'Gm10566', 'Gm10561'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10581' but records with similar symbols exist: 'Gm10568', 'Gm10566', 'Gm10561'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10580' but records with similar symbols exist: 'Gm10568', 'Gm10566', 'Gm10561'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm17376' but records with similar symbols exist: 'Gm17308', 'Gm17354', 'Gm17300'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10571' but records with similar symbols exist: 'Gm10568', 'Gm10566', 'Gm10561'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10205' but records with similar symbols exist: 'Gm10222', 'Gm10259', 'Gm10258'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10025' but records with similar symbols exist: 'Gm10075', 'Gm10062', 'Gm10059'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm17420' but records with similar symbols exist: 'Gm17415', 'Gm17409', 'Gm17416'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm21839' but records with similar symbols exist: 'Gm21850', 'Gm21847', 'Gm21846'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm17472' but records with similar symbols exist: 'Gm17415', 'Gm17409', 'Gm17416'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm55062' but records with similar symbols exist: 'Gm550', 'Gm55039', 'Gm55090'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm11065' but records with similar symbols exist: 'Gm11007', 'Gm11008', 'Gm11009'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm45783' but records with similar symbols exist: 'Gm45784', 'Gm45790', 'Gm45738'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10974' but records with similar symbols exist: 'Gm10985', 'Gm10972', 'Gm10961'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10172' but records with similar symbols exist: 'Gm10193', 'Gm10138', 'Gm10176'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm9988' but records with similar symbols exist: 'Gm9947', 'Gm9915', 'Gm9991'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10620' but records with similar symbols exist: 'Gm10685', 'Gm10652', 'Gm10650'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10617' but records with similar symbols exist: 'Gm10685', 'Gm10652', 'Gm10650'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm17571' but records with similar symbols exist: 'Gm17501', 'Gm17590', 'Gm17511'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm17711' but records with similar symbols exist: 'Gm17767', 'Gm17751', 'Gm17764'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10812' but records with similar symbols exist: 'Gm10862', 'Gm10857', 'Gm10855'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm9987' but records with similar symbols exist: 'Gm9947', 'Gm9915', 'Gm9991'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm9877' but records with similar symbols exist: 'Gm9826', 'Gm9884', 'Gm9898'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm9985' but records with similar symbols exist: 'Gm9947', 'Gm9915', 'Gm9991'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10434' but records with similar symbols exist: 'Gm10484', 'Gm10482', 'Gm10481'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10418' but records with similar symbols exist: 'Gm10484', 'Gm10482', 'Gm10481'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm16487' but records with similar symbols exist: 'Gm16418', 'Gm1647', 'Gm16401'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm48693' but records with similar symbols exist: 'Gm48628', 'Gm4860', 'Gm4861'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10478' but records with similar symbols exist: 'Gm10484', 'Gm10482', 'Gm10481'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm9812' but records with similar symbols exist: 'Gm9826', 'Gm9884', 'Gm9898'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm17528' but records with similar symbols exist: 'Gm17501', 'Gm17590', 'Gm17511'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm49800' but records with similar symbols exist: 'Gm4982', 'Gm49884', 'Gm49890'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm41414' but records with similar symbols exist: 'Gm4149', 'Gm41409', 'Gm41434'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm6467' but records with similar symbols exist: 'Gm6420', 'Gm6462', 'Gm6473'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm37419' but records with similar symbols exist: 'Gm37483', 'Gm37429', 'Gm37489'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm10813' but records with similar symbols exist: 'Gm10862', 'Gm10857', 'Gm10855'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm37825' but records with similar symbols exist: 'Gm378', 'Gm37862', 'Gm37880'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm56610' but records with similar symbols exist: 'Gm56675', 'Gm5660', 'Gm56617'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm1604b' but records with similar symbols exist: 'Gm16041', 'Gm16070', 'Gm16076'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm9818' but records with similar symbols exist: 'Gm9826', 'Gm9884', 'Gm9898'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm9959' but records with similar symbols exist: 'Gm9947', 'Gm9915', 'Gm9991'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm2531' but records with similar symbols exist: 'Gm25253', 'Gm25227', 'Gm25168'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm6960' but records with similar symbols exist: 'Gm6947', 'Gm6900', 'Gm6909'. Did you mean to load one of them?
# ! you are trying to create a record with name='Gm9806' but records with similar symbols exist: 'Gm9826', 'Gm9884', 'Gm9898'. Did you mean to load one of them?
# registering synthetic_construct genes
# ✓ created 92 Gene records from Bionty matching ensembl_gene_id: 'ERCC-00002', 'ERCC-00003', 'ERCC-00004', 'ERCC-00009', 'ERCC-00012', 'ERCC-00013', 'ERCC-00014', 'ERCC-00016', 'ERCC-00017', 'ERCC-00019', 'ERCC-00022', 'ERCC-00024', 'ERCC-00025', 'ERCC-00028', 'ERCC-00031', 'ERCC-00033', 'ERCC-00034', 'ERCC-00035', 'ERCC-00039', 'ERCC-00040', ...
# ✓ 92 unique terms (100.00%) are validated for ensembl_gene_id
# registering severe_acute_respiratory_syndrome_coronavirus_2 genes
# ✓ created 12 Gene records from Bionty matching ensembl_gene_id: 'ENSSASG00005000002', 'ENSSASG00005000003', 'ENSSASG00005000004', 'ENSSASG00005000006', 'ENSSASG00005000010', 'ENSSASG00005000007', 'ENSSASG00005000011', 'ENSSASG00005000009', 'ENSSASG00005000012', 'ENSSASG00005000008', 'ENSSASG00005000005', 'ENSSASG00005000013'
# ✓ 12 unique terms (100.00%) are validated for ensembl_gene_id

# %% [markdown]
# ## Link metadata to individual artifacts

# %% [markdown]
# annotate with genes measured in each artifact:

# %%
organisms = bt.Organism.lookup(field=bt.Organism.scientific_name)

# %%
# TODO discuss whether we even want to keep doing this
for idx, artifact in enumerate(artifacts):
    if idx % 100 == 0:
        print(f"annotating dataset {idx} of {len(artifacts)}")

    adata = artifact.open()
    var_names = adata.var_names
    organism_record = artifact.organisms.first()
    if organism_record is None:
        print(f"No organism found for artifact: {artifact}")
        continue

    genes = bt.Gene.from_values(
        var_names, field=bt.Gene.ensembl_gene_id, organism=organism_record
    )

    if len(genes) == 0 and var_names[0].startswith("ENSG"):
        genes = bt.Gene.from_values(
            var_names, field=bt.Gene.ensembl_gene_id, organism="human"
        )

    if len(var_names[var_names.str.startswith("ERCC")]) > 0:
        genes = bt.Gene.from_values(
            var_names,
            field=bt.Gene.ensembl_gene_id,
            organism=organisms.synthetic_construct,
        )
    if len(var_names[var_names.str.startswith("ENSSASG")]) > 0:
        genes = bt.Gene.from_values(
            var_names,
            field=bt.Gene.ensembl_gene_id,
            organism=organisms.severe_acute_respiratory_syndrome_coronavirus_2,
        )

    if genes:
        genes = [g for g in genes if not g._state.adding]
        var_schema = ln.Schema(genes, dtype="number").save()
        artifact.feature_sets.add(var_schema, through_defaults={"slot": "var"})
# Out:
# annotating dataset 0 of 1573
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# ✓ loaded 61752 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 7 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000252485', 'ENSG00000254978', 'ENSG00000272655', 'ENSG00000285517', 'ENSG00000286061'
# ✓ loaded 59230 Gene records matching ensembl_gene_id: 'ENSG00000110169', 'ENSG00000224458', 'ENSG00000227392', 'ENSG00000287870', 'ENSG00000259895', 'ENSG00000253675', 'ENSG00000259334', 'ENSG00000287878', 'ENSG00000151577', 'ENSG00000235743', 'ENSG00000253608', 'ENSG00000165621', 'ENSG00000170820', 'ENSG00000282890', 'ENSG00000279658', 'ENSG00000263146', 'ENSG00000224750', 'ENSG00000229240', 'ENSG00000276778', 'ENSG00000283453', ...
# ✓ created 6 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000252485', 'ENSG00000254978', 'ENSG00000285517', 'ENSG00000286061'
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='ExX57jVEGKYC1Cqa', n=36402, is_type=False, itype='bionty.Gene', dtype='number', hash='yJ9V1Ky61Nej0Lty9rNA9w', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:47:04 UTC)
# ✓ loaded 18784 Gene records matching ensembl_gene_id: 'ENSG00000227232', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000228794', 'ENSG00000230368', 'ENSG00000187634', 'ENSG00000188976', 'ENSG00000187961', 'ENSG00000187583', 'ENSG00000187642', 'ENSG00000188290', 'ENSG00000187608', 'ENSG00000188157', 'ENSG00000131591', 'ENSG00000223823', 'ENSG00000162571', 'ENSG00000186891', 'ENSG00000186827', 'ENSG00000078808', 'ENSG00000176022', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000254978', 'ENSG00000286061'
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='ExX57jVEGKYC1Cqa', n=36402, is_type=False, itype='bionty.Gene', dtype='number', hash='yJ9V1Ky61Nej0Lty9rNA9w', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:47:04 UTC)
# ✓ loaded 30865 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000228463', 'ENSG00000237094', 'ENSG00000236601', 'ENSG00000235146', 'ENSG00000230021', 'ENSG00000229905', 'ENSG00000228327', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# ✓ loaded 19742 Gene records matching ensembl_gene_id: 'ENSG00000238009', 'ENSG00000237491', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000188976', 'ENSG00000187961', 'ENSG00000188290', 'ENSG00000187608', 'ENSG00000188157', 'ENSG00000131591', 'ENSG00000186891', 'ENSG00000186827', 'ENSG00000078808', 'ENSG00000176022', 'ENSG00000184163', 'ENSG00000160087', 'ENSG00000162572', 'ENSG00000131584', 'ENSG00000169972', 'ENSG00000127054', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# ✓ loaded 54647 Gene records matching ensembl_gene_id: 'ENSG00000249311', 'ENSG00000168454', 'ENSG00000254720', 'ENSG00000197852', 'ENSG00000256540', 'ENSG00000139180', 'ENSG00000259284', 'ENSG00000201382', 'ENSG00000204564', 'ENSG00000267414', 'ENSG00000250715', 'ENSG00000116717', 'ENSG00000114654', 'ENSG00000198398', 'ENSG00000252487', 'ENSG00000273489', 'ENSG00000256627', 'ENSG00000235996', 'ENSG00000085117', 'ENSG00000092140', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# ✓ loaded 30865 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000228463', 'ENSG00000237094', 'ENSG00000236601', 'ENSG00000235146', 'ENSG00000230021', 'ENSG00000229905', 'ENSG00000228327', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='qsESXl9JAv13Aif7', n=30865, is_type=False, itype='bionty.Gene', dtype='number', hash='3TuJKNjWAvJ5G_lz-jdoeA', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:52:27 UTC)
# ✓ loaded 30262 Gene records matching ensembl_gene_id: 'ENSG00000233576', 'ENSG00000121410', 'ENSG00000268895', 'ENSG00000148584', 'ENSG00000175899', 'ENSG00000245105', 'ENSG00000166535', 'ENSG00000256069', 'ENSG00000184389', 'ENSG00000128274', 'ENSG00000118017', 'ENSG00000265544', 'ENSG00000094914', 'ENSG00000081760', 'ENSG00000250420', 'ENSG00000114771', 'ENSG00000197953', 'ENSG00000242908', 'ENSG00000188984', 'ENSG00000204518', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000286061'
# ✓ loaded 22981 Gene records matching ensembl_gene_id: 'ENSG00000121410', 'ENSG00000268895', 'ENSG00000148584', 'ENSG00000245105', 'ENSG00000166535', 'ENSG00000128274', 'ENSG00000094914', 'ENSG00000081760', 'ENSG00000114771', 'ENSG00000109576', 'ENSG00000158122', 'ENSG00000103591', 'ENSG00000115977', 'ENSG00000087884', 'ENSG00000127837', 'ENSG00000129673', 'ENSG00000131043', 'ENSG00000205002', 'ENSG00000090861', 'ENSG00000124608', ...
# ✓ created 3 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# ✓ loaded 18174 Gene records matching ensembl_gene_id: 'ENSG00000100568', 'ENSG00000101440', 'ENSG00000136630', 'ENSG00000061936', 'ENSG00000155330', 'ENSG00000257303', 'ENSG00000119917', 'ENSG00000147421', 'ENSG00000108469', 'ENSG00000104522', 'ENSG00000214367', 'ENSG00000106780', 'ENSG00000129472', 'ENSG00000270096', 'ENSG00000138722', 'ENSG00000154025', 'ENSG00000104960', 'ENSG00000128000', 'ENSG00000249790', 'ENSG00000266208', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000225489'
# ✓ loaded 33143 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# • did not create Gene records for 10 non-validated ensembl_gene_ids: 'ENSSASG00005000004', 'ENSSASG00005000005', 'ENSSASG00005000006', 'ENSSASG00005000007', 'ENSSASG00005000008', 'ENSSASG00005000009', 'ENSSASG00005000010', 'ENSSASG00005000011', 'ENSSASG00005000012', 'ENSSASG00005000013'
# ✓ loaded 10 Gene records matching ensembl_gene_id: 'ENSSASG00005000010', 'ENSSASG00005000007', 'ENSSASG00005000005', 'ENSSASG00005000013', 'ENSSASG00005000006', 'ENSSASG00005000011', 'ENSSASG00005000009', 'ENSSASG00005000012', 'ENSSASG00005000008', 'ENSSASG00005000004'
# • did not create Gene records for 33145 non-validated ensembl_gene_ids: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# → returning existing schema with same hash: Schema(uid='Rvr1R9C4W7tNFZZt', n=27554, is_type=False, itype='bionty.Gene', dtype='number', hash='Shmky8o4lqU3LbC-iJlDdw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:02:45 UTC)
# → returning existing schema with same hash: Schema(uid='Rvr1R9C4W7tNFZZt', n=27554, is_type=False, itype='bionty.Gene', dtype='number', hash='Shmky8o4lqU3LbC-iJlDdw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:02:45 UTC)
# ✓ loaded 33361 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# ✓ loaded 17661 Gene records matching ensembl_gene_id: 'ENSG00000268895', 'ENSG00000175899', 'ENSG00000245105', 'ENSG00000166535', 'ENSG00000256661', 'ENSG00000184389', 'ENSG00000128274', 'ENSG00000094914', 'ENSG00000081760', 'ENSG00000109576', 'ENSG00000158122', 'ENSG00000103591', 'ENSG00000115977', 'ENSG00000087884', 'ENSG00000127837', 'ENSG00000131043', 'ENSG00000205002', 'ENSG00000090861', 'ENSG00000124608', 'ENSG00000266967', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000225489'
# ✓ loaded 25999 Gene records matching ensembl_gene_id: 'ENSG00000121410', 'ENSG00000268895', 'ENSG00000148584', 'ENSG00000175899', 'ENSG00000245105', 'ENSG00000166535', 'ENSG00000256661', 'ENSG00000184389', 'ENSG00000128274', 'ENSG00000094914', 'ENSG00000081760', 'ENSG00000204518', 'ENSG00000109576', 'ENSG00000158122', 'ENSG00000103591', 'ENSG00000115977', 'ENSG00000087884', 'ENSG00000127837', 'ENSG00000129673', 'ENSG00000131043', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000225489'
# ✓ loaded 23200 Gene records matching ensembl_gene_id: 'ENSG00000272896', 'ENSG00000113048', 'ENSG00000224383', 'ENSG00000143801', 'ENSG00000099822', 'ENSG00000116191', 'ENSG00000249693', 'ENSG00000265778', 'ENSG00000102057', 'ENSG00000182070', 'ENSG00000078589', 'ENSG00000121879', 'ENSG00000250091', 'ENSG00000172403', 'ENSG00000108784', 'ENSG00000250748', 'ENSG00000249293', 'ENSG00000104221', 'ENSG00000231521', 'ENSG00000122882', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000225489'
# ✓ loaded 36408 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# ✓ loaded 59230 Gene records matching ensembl_gene_id: 'ENSG00000250954', 'ENSG00000275232', 'ENSG00000107593', 'ENSG00000163285', 'ENSG00000249618', 'ENSG00000287989', 'ENSG00000150556', 'ENSG00000254587', 'ENSG00000189108', 'ENSG00000250723', 'ENSG00000169436', 'ENSG00000231538', 'ENSG00000258131', 'ENSG00000196549', 'ENSG00000286328', 'ENSG00000265485', 'ENSG00000251165', 'ENSG00000205442', 'ENSG00000144824', 'ENSG00000269957', ...
# ✓ created 6 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000252485', 'ENSG00000254978', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='l91tOomQUXFdof4j', n=59230, is_type=False, itype='bionty.Gene', dtype='number', hash='vlL0r40ekWvwkv-RGBR8vQ', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:49:13 UTC)
# ✓ loaded 36408 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='2zLLApFMwpc7EXNU', n=36408, is_type=False, itype='bionty.Gene', dtype='number', hash='f09VnSoXdK2xym4j8vnO8Q', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:07:59 UTC)
# ✓ loaded 33157 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', 'ENSG00000241180', 'ENSG00000223764', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# ✓ loaded 36956 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# ✓ loaded 59230 Gene records matching ensembl_gene_id: 'ENSG00000258454', 'ENSG00000261723', 'ENSG00000005102', 'ENSG00000260342', 'ENSG00000180739', 'ENSG00000267919', 'ENSG00000268093', 'ENSG00000274227', 'ENSG00000286154', 'ENSG00000283010', 'ENSG00000236758', 'ENSG00000213076', 'ENSG00000224825', 'ENSG00000206187', 'ENSG00000257522', 'ENSG00000275582', 'ENSG00000175697', 'ENSG00000172460', 'ENSG00000249481', 'ENSG00000143340', ...
# ✓ created 6 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000252485', 'ENSG00000254978', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='l91tOomQUXFdof4j', n=59230, is_type=False, itype='bionty.Gene', dtype='number', hash='vlL0r40ekWvwkv-RGBR8vQ', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:49:13 UTC)
# ✓ loaded 33143 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', 'ENSG00000241180', 'ENSG00000223764', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# ✓ loaded 60047 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 7 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000252485', 'ENSG00000254978', 'ENSG00000272655', 'ENSG00000285517', 'ENSG00000286061'
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='ExX57jVEGKYC1Cqa', n=36402, is_type=False, itype='bionty.Gene', dtype='number', hash='yJ9V1Ky61Nej0Lty9rNA9w', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:47:04 UTC)
# ✓ loaded 33157 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', 'ENSG00000241180', 'ENSG00000223764', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='YL0DLqcDpZMRcUv3', n=33157, is_type=False, itype='bionty.Gene', dtype='number', hash='Mdwd9U01qvLAQ7ik8s71Uw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:10:41 UTC)
# ✓ loaded 33157 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', 'ENSG00000241180', 'ENSG00000223764', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='YL0DLqcDpZMRcUv3', n=33157, is_type=False, itype='bionty.Gene', dtype='number', hash='Mdwd9U01qvLAQ7ik8s71Uw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:10:41 UTC)
# ✓ loaded 59230 Gene records matching ensembl_gene_id: 'ENSG00000081148', 'ENSG00000278254', 'ENSG00000237928', 'ENSG00000139915', 'ENSG00000265203', 'ENSG00000176771', 'ENSG00000185652', 'ENSG00000129167', 'ENSG00000248550', 'ENSG00000132386', 'ENSG00000110195', 'ENSG00000183098', 'ENSG00000164796', 'ENSG00000261873', 'ENSG00000183960', 'ENSG00000047617', 'ENSG00000241743', 'ENSG00000286862', 'ENSG00000287226', 'ENSG00000237515', ...
# ✓ created 6 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000252485', 'ENSG00000254978', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='l91tOomQUXFdof4j', n=59230, is_type=False, itype='bionty.Gene', dtype='number', hash='vlL0r40ekWvwkv-RGBR8vQ', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:49:13 UTC)
# ✓ loaded 33089 Gene records matching ensembl_gene_id: 'ENSG00000100568', 'ENSG00000256695', 'ENSG00000101440', 'ENSG00000136630', 'ENSG00000248676', 'ENSG00000272789', 'ENSG00000284484', 'ENSG00000235575', 'ENSG00000279983', 'ENSG00000155330', 'ENSG00000147421', 'ENSG00000108469', 'ENSG00000226798', 'ENSG00000224222', 'ENSG00000122584', 'ENSG00000261368', 'ENSG00000154025', 'ENSG00000196131', 'ENSG00000104960', 'ENSG00000266208', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# ✓ loaded 32837 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# ✓ loaded 36408 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='2zLLApFMwpc7EXNU', n=36408, is_type=False, itype='bionty.Gene', dtype='number', hash='f09VnSoXdK2xym4j8vnO8Q', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:07:59 UTC)
# ✓ loaded 29065 Gene records matching ensembl_gene_id: 'ENSG00000238009', 'ENSG00000279928', 'ENSG00000279457', 'ENSG00000228463', 'ENSG00000237094', 'ENSG00000230021', 'ENSG00000237491', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000223764', 'ENSG00000187634', 'ENSG00000188976', 'ENSG00000187961', 'ENSG00000187583', 'ENSG00000187642', 'ENSG00000272512', 'ENSG00000188290', 'ENSG00000187608', 'ENSG00000188157', 'ENSG00000273443', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='ExX57jVEGKYC1Cqa', n=36402, is_type=False, itype='bionty.Gene', dtype='number', hash='yJ9V1Ky61Nej0Lty9rNA9w', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:47:04 UTC)
# ✓ loaded 24899 Gene records matching ensembl_gene_id: 'ENSG00000235399', 'ENSG00000183260', 'ENSG00000151338', 'ENSG00000182173', 'ENSG00000148297', 'ENSG00000269997', 'ENSG00000164929', 'ENSG00000181788', 'ENSG00000232342', 'ENSG00000145687', 'ENSG00000250387', 'ENSG00000243847', 'ENSG00000213380', 'ENSG00000153563', 'ENSG00000008226', 'ENSG00000173915', 'ENSG00000179213', 'ENSG00000196778', 'ENSG00000164715', 'ENSG00000184481', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000225489'
# ✓ loaded 59223 Gene records matching ensembl_gene_id: 'ENSG00000223972', 'ENSG00000227232', 'ENSG00000278267', 'ENSG00000284332', 'ENSG00000268020', 'ENSG00000240361', 'ENSG00000233750', 'ENSG00000268903', 'ENSG00000269981', 'ENSG00000241860', 'ENSG00000222623', 'ENSG00000241599', 'ENSG00000279928', 'ENSG00000279457', 'ENSG00000273874', 'ENSG00000228463', 'ENSG00000286448', 'ENSG00000236679', 'ENSG00000237094', 'ENSG00000269732', ...
# ✓ created 6 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000252485', 'ENSG00000254978', 'ENSG00000285517', 'ENSG00000286061'
# ✓ loaded 17744 Gene records matching ensembl_gene_id: 'ENSG00000238009', 'ENSG00000237491', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', 'ENSG00000223764', 'ENSG00000187634', 'ENSG00000188976', 'ENSG00000187961', 'ENSG00000187583', 'ENSG00000187642', 'ENSG00000272512', 'ENSG00000188290', 'ENSG00000187608', 'ENSG00000188157', 'ENSG00000237330', 'ENSG00000131591', 'ENSG00000272141', 'ENSG00000205231', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000225489'
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='ExX57jVEGKYC1Cqa', n=36402, is_type=False, itype='bionty.Gene', dtype='number', hash='yJ9V1Ky61Nej0Lty9rNA9w', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:47:04 UTC)
# → returning existing schema with same hash: Schema(uid='7CySzmsruRL58wfl', n=21069, is_type=False, itype='bionty.Gene', dtype='number', hash='qeHGFaT8n96OWz85MQVfXw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:10:09 UTC)
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='ExX57jVEGKYC1Cqa', n=36402, is_type=False, itype='bionty.Gene', dtype='number', hash='yJ9V1Ky61Nej0Lty9rNA9w', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:47:04 UTC)
# ✓ loaded 33157 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', 'ENSG00000241180', 'ENSG00000223764', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='YL0DLqcDpZMRcUv3', n=33157, is_type=False, itype='bionty.Gene', dtype='number', hash='Mdwd9U01qvLAQ7ik8s71Uw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:10:41 UTC)
# ✓ loaded 27955 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='ExX57jVEGKYC1Cqa', n=36402, is_type=False, itype='bionty.Gene', dtype='number', hash='yJ9V1Ky61Nej0Lty9rNA9w', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:47:04 UTC)
# ✓ loaded 32741 Gene records matching ensembl_gene_id: 'ENSG00000100568', 'ENSG00000101440', 'ENSG00000249847', 'ENSG00000136630', 'ENSG00000231731', 'ENSG00000155330', 'ENSG00000237015', 'ENSG00000147421', 'ENSG00000108469', 'ENSG00000270124', 'ENSG00000272123', 'ENSG00000122584', 'ENSG00000271737', 'ENSG00000154025', 'ENSG00000196131', 'ENSG00000104960', 'ENSG00000018869', 'ENSG00000151005', 'ENSG00000233070', 'ENSG00000251170', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# ✓ loaded 23269 Gene records matching ensembl_gene_id: 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000010072', 'ENSG00000009780', 'ENSG00000048707', 'ENSG00000034971', 'ENSG00000059588', 'ENSG00000041988', 'ENSG00000049245', 'ENSG00000049247', 'ENSG00000052723', 'ENSG00000058799', 'ENSG00000060642', 'ENSG00000069424', 'ENSG00000070886', 'ENSG00000074964', 'ENSG00000081870', 'ENSG00000083444', 'ENSG00000092607', 'ENSG00000076321', ...
# ✓ created 3 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000272655', 'ENSG00000285517', 'ENSG00000286061'
# ✓ loaded 25325 Gene records matching ensembl_gene_id: 'ENSG00000121410', 'ENSG00000268895', 'ENSG00000148584', 'ENSG00000175899', 'ENSG00000245105', 'ENSG00000256661', 'ENSG00000184389', 'ENSG00000128274', 'ENSG00000118017', 'ENSG00000094914', 'ENSG00000081760', 'ENSG00000204518', 'ENSG00000109576', 'ENSG00000158122', 'ENSG00000103591', 'ENSG00000115977', 'ENSG00000087884', 'ENSG00000127837', 'ENSG00000131043', 'ENSG00000205002', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000225489'
# ✓ loaded 23673 Gene records matching ensembl_gene_id: 'ENSG00000268895', 'ENSG00000148584', 'ENSG00000175899', 'ENSG00000245105', 'ENSG00000166535', 'ENSG00000256661', 'ENSG00000184389', 'ENSG00000128274', 'ENSG00000094914', 'ENSG00000081760', 'ENSG00000204518', 'ENSG00000109576', 'ENSG00000158122', 'ENSG00000103591', 'ENSG00000115977', 'ENSG00000087884', 'ENSG00000127837', 'ENSG00000129673', 'ENSG00000131043', 'ENSG00000205002', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000225489'
# ✓ loaded 36408 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='2zLLApFMwpc7EXNU', n=36408, is_type=False, itype='bionty.Gene', dtype='number', hash='f09VnSoXdK2xym4j8vnO8Q', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:07:59 UTC)
# ✓ loaded 34008 Gene records matching ensembl_gene_id: 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000228463', 'ENSG00000236601', 'ENSG00000237094', 'ENSG00000230021', 'ENSG00000235146', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', 'ENSG00000241180', 'ENSG00000223764', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# ✓ loaded 29393 Gene records matching ensembl_gene_id: 'ENSG00000121410', 'ENSG00000268895', 'ENSG00000148584', 'ENSG00000175899', 'ENSG00000245105', 'ENSG00000166535', 'ENSG00000256661', 'ENSG00000184389', 'ENSG00000128274', 'ENSG00000118017', 'ENSG00000094914', 'ENSG00000081760', 'ENSG00000114771', 'ENSG00000197953', 'ENSG00000242908', 'ENSG00000188984', 'ENSG00000204518', 'ENSG00000109576', 'ENSG00000158122', 'ENSG00000103591', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000225489'
# ✓ loaded 59230 Gene records matching ensembl_gene_id: 'ENSG00000256021', 'ENSG00000213809', 'ENSG00000283755', 'ENSG00000233009', 'ENSG00000231628', 'ENSG00000277290', 'ENSG00000120318', 'ENSG00000143369', 'ENSG00000129538', 'ENSG00000126860', 'ENSG00000203797', 'ENSG00000273507', 'ENSG00000177212', 'ENSG00000226317', 'ENSG00000255109', 'ENSG00000271862', 'ENSG00000227723', 'ENSG00000185522', 'ENSG00000254707', 'ENSG00000286279', ...
# ✓ created 6 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000252485', 'ENSG00000254978', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='l91tOomQUXFdof4j', n=59230, is_type=False, itype='bionty.Gene', dtype='number', hash='vlL0r40ekWvwkv-RGBR8vQ', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:49:13 UTC)
# ✓ loaded 30163 Gene records matching ensembl_gene_id: 'ENSG00000272896', 'ENSG00000113048', 'ENSG00000224383', 'ENSG00000143801', 'ENSG00000283355', 'ENSG00000273123', 'ENSG00000234162', 'ENSG00000099822', 'ENSG00000256980', 'ENSG00000261817', 'ENSG00000116191', 'ENSG00000249693', 'ENSG00000258464', 'ENSG00000286749', 'ENSG00000265778', 'ENSG00000258662', 'ENSG00000171217', 'ENSG00000102057', 'ENSG00000287968', 'ENSG00000182070', ...
# ✓ created 3 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# ✓ loaded 32837 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000279928', 'ENSG00000279457', 'ENSG00000228463', 'ENSG00000236601', 'ENSG00000237094', 'ENSG00000230021', 'ENSG00000235146', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='D40rAYIinOnNRLDD', n=32837, is_type=False, itype='bionty.Gene', dtype='number', hash='Tirm5G8Uza4WByn0HJ69aw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:19:52 UTC)
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='ExX57jVEGKYC1Cqa', n=36402, is_type=False, itype='bionty.Gene', dtype='number', hash='yJ9V1Ky61Nej0Lty9rNA9w', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:47:04 UTC)
# ✓ loaded 33361 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='IZXnQRVpoGIeFfZW', n=33361, is_type=False, itype='bionty.Gene', dtype='number', hash='EoVJY6MKpg0hjJSRawQlIQ', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:05:51 UTC)
# ✓ loaded 33157 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', 'ENSG00000241180', 'ENSG00000223764', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='YL0DLqcDpZMRcUv3', n=33157, is_type=False, itype='bionty.Gene', dtype='number', hash='Mdwd9U01qvLAQ7ik8s71Uw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:10:41 UTC)
# ✓ loaded 59230 Gene records matching ensembl_gene_id: 'ENSG00000287383', 'ENSG00000100097', 'ENSG00000271850', 'ENSG00000156049', 'ENSG00000231373', 'ENSG00000232560', 'ENSG00000233359', 'ENSG00000172197', 'ENSG00000286271', 'ENSG00000150656', 'ENSG00000249061', 'ENSG00000251138', 'ENSG00000233828', 'ENSG00000134160', 'ENSG00000253877', 'ENSG00000237166', 'ENSG00000273507', 'ENSG00000231171', 'ENSG00000288035', 'ENSG00000167772', ...
# ✓ created 6 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000252485', 'ENSG00000254978', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='l91tOomQUXFdof4j', n=59230, is_type=False, itype='bionty.Gene', dtype='number', hash='vlL0r40ekWvwkv-RGBR8vQ', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:49:13 UTC)
# ✓ loaded 33157 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', 'ENSG00000241180', 'ENSG00000223764', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='YL0DLqcDpZMRcUv3', n=33157, is_type=False, itype='bionty.Gene', dtype='number', hash='Mdwd9U01qvLAQ7ik8s71Uw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:10:41 UTC)
# ✓ loaded 32538 Gene records matching ensembl_gene_id: 'ENSG00000121410', 'ENSG00000268895', 'ENSG00000148584', 'ENSG00000175899', 'ENSG00000245105', 'ENSG00000166535', 'ENSG00000256661', 'ENSG00000256904', 'ENSG00000184389', 'ENSG00000128274', 'ENSG00000118017', 'ENSG00000094914', 'ENSG00000081760', 'ENSG00000114771', 'ENSG00000188984', 'ENSG00000204518', 'ENSG00000109576', 'ENSG00000158122', 'ENSG00000103591', 'ENSG00000115977', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='Rvr1R9C4W7tNFZZt', n=27554, is_type=False, itype='bionty.Gene', dtype='number', hash='Shmky8o4lqU3LbC-iJlDdw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:02:45 UTC)
# ✓ loaded 33143 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', 'ENSG00000241180', 'ENSG00000223764', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='zYFjxkw1NHZIjtFt', n=33143, is_type=False, itype='bionty.Gene', dtype='number', hash='Ad-8r84bjGD_sO0bdmxrCA', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:13:32 UTC)
# ✓ loaded 59230 Gene records matching ensembl_gene_id: 'ENSG00000136235', 'ENSG00000107014', 'ENSG00000258912', 'ENSG00000231535', 'ENSG00000248810', 'ENSG00000112149', 'ENSG00000141371', 'ENSG00000134802', 'ENSG00000166928', 'ENSG00000236120', 'ENSG00000136732', 'ENSG00000103522', 'ENSG00000251139', 'ENSG00000121966', 'ENSG00000196126', 'ENSG00000231131', 'ENSG00000006747', 'ENSG00000090104', 'ENSG00000169508', 'ENSG00000019582', ...
# ✓ created 6 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000252485', 'ENSG00000254978', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='l91tOomQUXFdof4j', n=59230, is_type=False, itype='bionty.Gene', dtype='number', hash='vlL0r40ekWvwkv-RGBR8vQ', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:49:13 UTC)
# ✓ loaded 32837 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='D40rAYIinOnNRLDD', n=32837, is_type=False, itype='bionty.Gene', dtype='number', hash='Tirm5G8Uza4WByn0HJ69aw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:19:52 UTC)
# ✓ loaded 61420 Gene records matching ensembl_gene_id: 'ENSG00000186827', 'ENSG00000186891', 'ENSG00000160072', 'ENSG00000260179', 'ENSG00000234396', 'ENSG00000225972', 'ENSG00000224315', 'ENSG00000198744', 'ENSG00000279928', 'ENSG00000228037', 'ENSG00000142611', 'ENSG00000225630', 'ENSG00000131584', 'ENSG00000227589', 'ENSG00000237402', 'ENSG00000284616', 'ENSG00000169972', 'ENSG00000157911', 'ENSG00000269896', 'ENSG00000237973', ...
# ✓ created 7 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000252485', 'ENSG00000254978', 'ENSG00000272655', 'ENSG00000285517', 'ENSG00000286061'
# ✓ loaded 26232 Gene records matching ensembl_gene_id: 'ENSG00000121410', 'ENSG00000268895', 'ENSG00000148584', 'ENSG00000175899', 'ENSG00000245105', 'ENSG00000166535', 'ENSG00000256661', 'ENSG00000256904', 'ENSG00000184389', 'ENSG00000128274', 'ENSG00000118017', 'ENSG00000094914', 'ENSG00000081760', 'ENSG00000204518', 'ENSG00000109576', 'ENSG00000158122', 'ENSG00000103591', 'ENSG00000115977', 'ENSG00000087884', 'ENSG00000127837', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000225489'
# ✓ loaded 36956 Gene records matching ensembl_gene_id: 'ENSG00000000003', 'ENSG00000000005', 'ENSG00000000419', 'ENSG00000000457', 'ENSG00000000460', 'ENSG00000000938', 'ENSG00000000971', 'ENSG00000001036', 'ENSG00000001084', 'ENSG00000001167', 'ENSG00000001460', 'ENSG00000001461', 'ENSG00000001497', 'ENSG00000001561', 'ENSG00000001617', 'ENSG00000001626', 'ENSG00000001629', 'ENSG00000001630', 'ENSG00000001631', 'ENSG00000002016', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='kZh3eh9Jg0MMDtv1', n=36956, is_type=False, itype='bionty.Gene', dtype='number', hash='UCE1Vr27is0rGXkwGh-CxQ', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:12:52 UTC)
# ✓ loaded 33825 Gene records matching ensembl_gene_id: 'ENSG00000121410', 'ENSG00000268895', 'ENSG00000148584', 'ENSG00000175899', 'ENSG00000245105', 'ENSG00000166535', 'ENSG00000256661', 'ENSG00000184389', 'ENSG00000128274', 'ENSG00000118017', 'ENSG00000094914', 'ENSG00000081760', 'ENSG00000114771', 'ENSG00000197953', 'ENSG00000242908', 'ENSG00000188984', 'ENSG00000204518', 'ENSG00000109576', 'ENSG00000158122', 'ENSG00000103591', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000225489'
# ...
# ✓ loaded 33157 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', 'ENSG00000241180', 'ENSG00000223764', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='YL0DLqcDpZMRcUv3', n=33157, is_type=False, itype='bionty.Gene', dtype='number', hash='Mdwd9U01qvLAQ7ik8s71Uw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:10:41 UTC)
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='ExX57jVEGKYC1Cqa', n=36402, is_type=False, itype='bionty.Gene', dtype='number', hash='yJ9V1Ky61Nej0Lty9rNA9w', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:47:04 UTC)
# ✓ loaded 24138 Gene records matching ensembl_gene_id: 'ENSG00000238009', 'ENSG00000279457', 'ENSG00000228463', 'ENSG00000237094', 'ENSG00000230021', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000230699', 'ENSG00000223764', 'ENSG00000187634', 'ENSG00000188976', 'ENSG00000187961', 'ENSG00000187583', 'ENSG00000187642', 'ENSG00000272512', 'ENSG00000188290', 'ENSG00000187608', 'ENSG00000188157', ...
# ✓ created 1 Gene record from Bionty matching ensembl_gene_id: 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='7CySzmsruRL58wfl', n=21069, is_type=False, itype='bionty.Gene', dtype='number', hash='qeHGFaT8n96OWz85MQVfXw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:10:09 UTC)
# ✓ loaded 32837 Gene records matching ensembl_gene_id: 'ENSG00000279457', 'ENSG00000228463', 'ENSG00000237094', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000230699', 'ENSG00000187634', 'ENSG00000188976', 'ENSG00000187961', 'ENSG00000272512', 'ENSG00000188290', 'ENSG00000187608', 'ENSG00000188157', 'ENSG00000131591', 'ENSG00000186891', 'ENSG00000186827', 'ENSG00000078808', 'ENSG00000176022', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='D40rAYIinOnNRLDD', n=32837, is_type=False, itype='bionty.Gene', dtype='number', hash='Tirm5G8Uza4WByn0HJ69aw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:19:52 UTC)
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='ExX57jVEGKYC1Cqa', n=36402, is_type=False, itype='bionty.Gene', dtype='number', hash='yJ9V1Ky61Nej0Lty9rNA9w', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:47:04 UTC)
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='ExX57jVEGKYC1Cqa', n=36402, is_type=False, itype='bionty.Gene', dtype='number', hash='yJ9V1Ky61Nej0Lty9rNA9w', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:47:04 UTC)
# ✓ loaded 18784 Gene records matching ensembl_gene_id: 'ENSG00000227232', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000228794', 'ENSG00000230368', 'ENSG00000187634', 'ENSG00000188976', 'ENSG00000187961', 'ENSG00000187583', 'ENSG00000187642', 'ENSG00000188290', 'ENSG00000187608', 'ENSG00000188157', 'ENSG00000131591', 'ENSG00000223823', 'ENSG00000162571', 'ENSG00000186891', 'ENSG00000186827', 'ENSG00000078808', 'ENSG00000176022', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000254978', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='D7vTcrTABI9E3Ymg', n=18784, is_type=False, itype='bionty.Gene', dtype='number', hash='0l_vjKyvUcxiZgZq5XfO2A', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:51:36 UTC)
# → returning existing schema with same hash: Schema(uid='Cds2b5U31sQwJkjN', n=17984, is_type=False, itype='bionty.Gene', dtype='number', hash='qXOYwfTVJ-7IRPSUdws8yw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 11:03:27 UTC)
# ✓ loaded 36402 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241860', 'ENSG00000241599', 'ENSG00000286448', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000228794', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 4 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='ExX57jVEGKYC1Cqa', n=36402, is_type=False, itype='bionty.Gene', dtype='number', hash='yJ9V1Ky61Nej0Lty9rNA9w', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:47:04 UTC)
# ✓ loaded 33157 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000236601', 'ENSG00000284733', 'ENSG00000235146', 'ENSG00000284662', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', 'ENSG00000230699', 'ENSG00000241180', 'ENSG00000223764', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='YL0DLqcDpZMRcUv3', n=33157, is_type=False, itype='bionty.Gene', dtype='number', hash='Mdwd9U01qvLAQ7ik8s71Uw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:10:41 UTC)
# ✓ loaded 59230 Gene records matching ensembl_gene_id: 'ENSG00000158423', 'ENSG00000205853', 'ENSG00000261713', 'ENSG00000111241', 'ENSG00000253537', 'ENSG00000171631', 'ENSG00000146285', 'ENSG00000225630', 'ENSG00000287400', 'ENSG00000272002', 'ENSG00000133110', 'ENSG00000271824', 'ENSG00000237787', 'ENSG00000238755', 'ENSG00000168685', 'ENSG00000287231', 'ENSG00000226846', 'ENSG00000162745', 'ENSG00000203756', 'ENSG00000150361', ...
# ✓ created 6 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489', 'ENSG00000252485', 'ENSG00000254978', 'ENSG00000285517', 'ENSG00000286061'
# → returning existing schema with same hash: Schema(uid='l91tOomQUXFdof4j', n=59230, is_type=False, itype='bionty.Gene', dtype='number', hash='vlL0r40ekWvwkv-RGBR8vQ', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 09:49:13 UTC)
# ✓ loaded 32837 Gene records matching ensembl_gene_id: 'ENSG00000243485', 'ENSG00000237613', 'ENSG00000186092', 'ENSG00000238009', 'ENSG00000239945', 'ENSG00000239906', 'ENSG00000241599', 'ENSG00000279928', 'ENSG00000279457', 'ENSG00000228463', 'ENSG00000236601', 'ENSG00000237094', 'ENSG00000230021', 'ENSG00000235146', 'ENSG00000229905', 'ENSG00000237491', 'ENSG00000177757', 'ENSG00000225880', 'ENSG00000230368', 'ENSG00000272438', ...
# ✓ created 2 Gene records from Bionty matching ensembl_gene_id: 'ENSG00000224516', 'ENSG00000225489'
# → returning existing schema with same hash: Schema(uid='D40rAYIinOnNRLDD', n=32837, is_type=False, itype='bionty.Gene', dtype='number', hash='Tirm5G8Uza4WByn0HJ69aw', minimal_set=True, ordered_set=False, maximal_set=False, branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 10:19:52 UTC)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 6
#       3 if idx % 100 == 0:
#       4     print(f"annotating dataset {idx} of {len(artifacts)}")
# ----> 6 adata = artifact.open()
#       7 var_names = adata.var_names
#       8 organism_record = artifact.organisms.first()
#
# File ~/code/lamindb/lamindb/models/artifact.py:2368, in open(self, mode, engine, is_run_input, **kwargs)
#    2364 if isinstance(e, (ImportError, ValueError)) or isinstance(
#    2365     filepath, LocalPathClasses
#    2366 ):
#    2367     raise e
# -> 2368 logger.warning(
#    2369     f"The cache might be corrupted: {e}. Trying to open directly."
#    2370 )
#    2371 access = backed_access(
#    2372     filepath, mode, engine, using_key=using_key, **kwargs
#    2373 )
#    2374 # happens only if backed_access has been successful
#    2375 # delete the corrupted cache
#
# File ~/code/lamindb/lamindb/core/storage/_backed_access.py:128, in backed_access(artifact_or_filepath, mode, engine, using_key, **kwargs)
#     126     if mode != "r":
#     127         raise ValueError("Can only access `AnnData` with mode='r'.")
# --> 128     return AnnDataAccessor(conn, storage, name)
#     129 else:
#     130     return BackedAccessor(conn, storage)
#
# File ~/code/lamindb/lamindb/core/storage/_anndata_accessor.py:694, in AnnDataAccessor.__init__(self, connection, storage, filename)
#     691 self._conn = connection
#     692 self.storage = storage
# --> 694 self._attrs_keys = registry.keys(self.storage)
#     696 self._name = filename
#     698 self._obs_names = _safer_read_index(self.storage["obs"])  # type: ignore
#
# File ~/code/lamindb/lamindb/core/storage/_anndata_accessor.py:145, in AccessRegistry.__getattr__.<locals>.wrapper(*args, **kwargs)
#     143     arg_module = get_module_name(arg)
#     144     if arg_module in func_registry:
# --> 145         return func_registry[arg_module](*args, **kwargs)
#     146 raise ValueError(f"{func_name} is not registered for this module.")
#
# File ~/code/lamindb/lamindb/core/storage/_anndata_accessor.py:265, in keys(storage)
#     263 if attr == "X":
#     264     continue
# --> 265 attr_obj = storage[attr]
#     266 if attr in ("obs", "var") and isinstance(attr_obj, h5py.Dataset):
#     267     keys = list(attr_obj.dtype.fields.keys())
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File ~/miniforge3/envs/lamindb/lib/python3.12/site-packages/h5py/_hl/group.py:360, in Group.__getitem__(self, name)
#     358         raise ValueError("Invalid HDF5 object reference")
#     359 elif isinstance(name, (bytes, str)):
# --> 360     oid = h5o.open(self.id, self._e(name), lapl=self._lapl)
#     361 else:
#     362     raise TypeError("Accessing a group is done with bytes or str, "
#     363                     "not {}".format(type(name)))
#
# File h5py/_objects.pyx:56, in h5py._objects.with_phil.wrapper()
#
# File h5py/_objects.pyx:57, in h5py._objects.with_phil.wrapper()
#
# File h5py/h5o.pyx:257, in h5py.h5o.open()
#
# File h5py/h5fd.pyx:162, in h5py.h5fd.H5FD_fileobj_read()
#
# File ~/miniforge3/envs/lamindb/lib/python3.12/site-packages/fsspec/spec.py:2101, in AbstractBufferedFile.readinto(self, b)
#    2096 """mirrors builtin file's readinto method
#    2097
#    2098 https://docs.python.org/3/library/io.html#io.RawIOBase.readinto
#    2099 """
#    2100 out = memoryview(b).cast("B")
# -> 2101 data = self.read(out.nbytes)
#    2102 out[: len(data)] = data
#    2103 return len(data)
#
# File ~/miniforge3/envs/lamindb/lib/python3.12/site-packages/fsspec/spec.py:2083, in AbstractBufferedFile.read(self, length)
#    2080 if length == 0:
#    2081     # don't even bother calling fetch
#    2082     return b""
# -> 2083 out = self.cache._fetch(self.loc, self.loc + length)
#    2085 logger.debug(
#    2086     "%s read: %i - %i %s",
#    2087     self,
#    (...)   2090     self.cache._log_stats(),
#    2091 )
#    2092 self.loc += len(out)
#
# File ~/miniforge3/envs/lamindb/lib/python3.12/site-packages/fsspec/caching.py:288, in ReadAheadCache._fetch(self, start, end)
#     286 end = min(self.size, end + self.blocksize)
#     287 self.total_requested_bytes += end - start
# --> 288 self.cache = self.fetcher(start, end)  # new block replaces old
#     289 self.start = start
#     290 self.end = self.start + len(self.cache)
#
# File ~/miniforge3/envs/lamindb/lib/python3.12/site-packages/s3fs/core.py:2380, in S3File._fetch_range(self, start, end)
#    2378 def _fetch_range(self, start, end):
#    2379     try:
# -> 2380         return _fetch_range(
#    2381             self.fs,
#    2382             self.bucket,
#    2383             self.key,
#    2384             self.version_id,
#    2385             start,
#    2386             end,
#    2387             req_kw=self.req_kw,
#    2388         )
#    2390     except OSError as ex:
#    2391         if ex.args[0] == errno.EINVAL and "pre-conditions" in ex.args[1]:
#
# File ~/miniforge3/envs/lamindb/lib/python3.12/site-packages/s3fs/core.py:2552, in _fetch_range(fs, bucket, key, version_id, start, end, req_kw)
#    2550     return b""
#    2551 logger.debug("Fetch: %s/%s, %s-%s", bucket, key, start, end)
# -> 2552 return sync(fs.loop, _inner_fetch, fs, bucket, key, version_id, start, end, req_kw)
#
# File ~/miniforge3/envs/lamindb/lib/python3.12/site-packages/fsspec/asyn.py:91, in sync(loop, func, timeout, *args, **kwargs)
#      88 asyncio.run_coroutine_threadsafe(_runner(event, coro, result, timeout), loop)
#      89 while True:
#      90     # this loops allows thread to get interrupted
# ---> 91     if event.wait(1):
#      92         break
#      93     if timeout is not None:
#
# File ~/miniforge3/envs/lamindb/lib/python3.12/threading.py:655, in Event.wait(self, timeout)
#     653 signaled = self._flag
#     654 if not signaled:
# --> 655     signaled = self._cond.wait(timeout)
#     656 return signaled
#
# File ~/miniforge3/envs/lamindb/lib/python3.12/threading.py:359, in Condition.wait(self, timeout)
#     357 else:
#     358     if timeout > 0:
# --> 359         gotit = waiter.acquire(True, timeout)
#     360     else:
#     361         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:

# %%
artifact.describe()
# Out:
# Artifact .h5ad · AnnData
# ├── General
# │   ├── key: cell-census/2025-01-30/h5ads/2104fbb8-8ce3-4740-8b6a-bcbb46a13c0f.h5ad
# │   ├── description: Visium spatial - HCAHeartST10238252 (OCT)
# │   ├── uid: qsj12UDM6qYq4bN60000          hash: xX9Blm7gJgiq8KfRbG2LXw
# │   ├── size: 323.0 MB                     transform: cencus-release-2025-01-30-LTS.ipynb
# │   ├── space: all                         branch: all
# │   ├── created_by: zethson                created_at: 2025-07-23 11:26:00
# │   ├── n_observations: 4992               version: 2025-01-30
# │   └── storage path:
# │       s3://cellxgene-data-public/cell-census/2025-01-30/h5ads/2104fbb8-8ce3-4740-8b6a-bcbb46a13c0f.h5ad
# ├── Dataset features
# │   └── obs • 11                        [Feature]
# │       organism                        cat[bionty.Organism]
# │       assay                           cat[bionty.ExperimentalFactor]
# │       cell_type                       cat[bionty.CellType]
# │       development_stage               cat[bionty.DevelopmentalStage]
# │       disease                         cat[bionty.Disease]
# │       self_reported_ethnicity         cat[bionty.Ethnicity]
# │       sex                             cat[bionty.Phenotype]
# │       tissue                          cat[bionty.Tissue]
# │       suspension_type                 cat[ULabel]
# │       donor_id                        cat[ULabel]
# │       tissue_type                     cat[ULabel]
# └── Labels
#     └── .organisms                      bionty.Organism                    human
#         .tissues                        bionty.Tissue                      left cardiac atrium
#         .cell_types                     bionty.CellType                    vein endothelial cell, CD16-positive, C…
#         .phenotypes                     bionty.Phenotype                   male
#         .experimental_factors           bionty.ExperimentalFactor          Visium Spatial Gene Expression V1
#         .developmental_stages           bionty.DevelopmentalStage          fifth decade stage
#         .ethnicities                    bionty.Ethnicity                   European
#         .ulabels                        ULabel                             D8, na

# %% [markdown]
# ## Annotate tissue_type

# %%
register_ulabels(cxg_datasets, "tissue_type")
# Out:
# ! you are trying to create a record with name='tissue' but a record with similar name exists: 'is_tissue_type'. Did you mean to load it?
# ! you are trying to create a record with name='organoid' but records with similar names exist: 'Chan_NatCommun_2022_bronchial_organoids', 'Lim_CellStemCell_2023_Lung_organoid_epithelium', 'Wesley_NatCellBio_2022_Hepatoblast_organoids_treated_with_hepatozyme'. Did you mean to load one of them?

# %% [markdown]
# ## Register collections

# %%
collection = ln.Collection(
    artifacts,
    key="cellxgene-census",
    version=census_version,
    is_new_version_of=ln.Collection.filter(
        key="cellxgene-census", version=previous_release
    ).one(),
)
collection.save()
# Out:
# Collection(uid='1eshvBBOwC0IdzGZ0000', version='2025-01-30', is_latest=True, key='cellxgene-census', hash='NjqvY0g6hlzgyVXTYer0Ng', branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 13:29:50 UTC)

# %%
cxg_collections = get_collections_from_cxg()

# %%
artifacts.first().key
# Out:
# 'cell-census/2025-01-30/h5ads/00099d5e-154f-4a7a-aa8d-fa30c8c0c43c.h5ad'

# %%
ln.settings.creation.search_names = False
for collection_meta in cxg_collections:
    keys = [
        f"cell-census/{census_version}/h5ads/{dataset['dataset_id']}.h5ad"
        for dataset in collection_meta["datasets"]
    ]
    collection_artifacts = artifacts.filter(key__in=keys).all()
    if collection_artifacts.count() > 0:
        kwargs = {
            "key": collection_meta["name"],
            "description": collection_meta["doi"],
            "reference": collection_meta["collection_id"],
            "reference_type": "CELLxGENE Collection ID",
            "version": census_version,
        }
        collection_record = ln.Collection(
            collection_artifacts,
            **kwargs,
        )
        # if is needed here as .save() errors if collection is already saved
        if collection_record._state.adding:
            collection_record.save()
ln.settings.creation.search_names = True

# %% [markdown]
# Add existing collections to their corresponding version families:

# %%
collections = ln.Collection.filter(version=census_version).all()
collections.count()
# Out:
# 248

# %%
collections_previous = ln.Collection.filter(version=previous_release).all()
collections_previous.count()
# Out:
# 0

# %%
for collection in collections:
    collection_previous = collections_previous.filter(
        reference=collection.reference
    ).one_or_none()
    if collection_previous is not None:
        collection.add_to_version_family(collection_previous, version=census_version)

# %% [markdown]
# ## Link metadata to collection

# %%
collection = ln.Collection.filter(key="cellxgene-census", version=census_version).one()
collection
# Out:
# Collection(uid='1eshvBBOwC0IdzGZ0000', version='2025-01-30', is_latest=True, key='cellxgene-census', hash='NjqvY0g6hlzgyVXTYer0Ng', branch_id=1, space_id=1, created_by_id=1, run_id=1, created_at=2025-07-23 13:29:50 UTC)

# %% [markdown]
# feature sets:

# %%
collection.describe()
# Out:
# ''

# %% [markdown]
# ## Register the soma store

# %%
soma_path = f"s3://cellxgene-data-public/cell-census/{census_version}/soma"
ln.UPath(soma_path).view_tree()
# Out:
# 19 sub-directories & 7 files with suffixes '', '.tdb'
# s3://cellxgene-data-public/cell-census/2025-01-30/soma
# ├── __tiledb_group.tdb
# ├── __group/
# │   └── __1738275389572_1738275389572_13353233232d51777852409560eaff8d_2
# ├── __meta/
# │   ├── __1738275389508_1738275389508_4e0e75839417b5b157905a31316816e6
# │   └── __1738275389572_1738275389572_2639dfe80b470afbf96934cfd352226e
# ├── census_data/
# │   ├── __tiledb_group.tdb
# │   ├── __group/
# │   ├── __meta/
# │   ├── homo_sapiens/
# │   └── mus_musculus/
# ├── census_info/
# │   ├── __tiledb_group.tdb
# │   ├── __group/
# │   ├── __meta/
# │   ├── datasets/
# │   ├── organisms/
# │   ├── summary/
# │   └── summary_cell_counts/
# └── census_spatial_sequencing/
#     ├── __tiledb_group.tdb
#     ├── __group/
#     ├── __meta/
#     ├── homo_sapiens/
#     └── mus_musculus/

# %%
soma_artifact = ln.Artifact(soma_path, description=f"Census {census_version}").save()
soma_artifact
# Out:
# • path in storage 's3://cellxgene-data-public' with key 'cell-census/2025-01-30/soma'
# Artifact(uid='DstoXzgJPW2PrnYr0000', is_latest=True, key='cell-census/2025-01-30/soma', description='Census 2025-01-30', suffix='', size=1128639499732, hash='uq_4QzGnaveTq5XinBJiCA', n_files=14217, branch_id=1, space_id=1, storage_id=2, run_id=1, created_by_id=1, created_at=2025-07-23 13:32:09 UTC)

# %%
ln.finish()
# Out:
# • please hit CTRL + s to save the notebook in your editor . ✓
# ! cells [(35, None), (None, 37), (37, 39)] were not run consecutively
# → finished Run('xkjTYBy2') after 4h at 2025-07-23 13:32:12 UTC
