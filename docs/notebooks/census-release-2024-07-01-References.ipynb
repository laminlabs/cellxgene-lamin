# %% [markdown]
# # Populate findrefs

# %% [markdown]
# Backfilling References of the 2024-07-01-LTS census release

# %%
# !lamin load laminlabs/cellxgene
# Out:
# → connected lamindb: laminlabs/cellxgene

# %%
import lamindb as ln
import findrefs as fr
import cellxgene_lamin as cxg

ln.track("qDPEGjwgZcQB0000")
# Out:
# → connected lamindb: laminlabs/cellxgene
# /home/zeth/miniconda3/envs/lamindb/lib/python3.11/site-packages/anndata/_io/__init__.py:12: FutureWarning: Importing read_zarr from `anndata._io` is deprecated. Please use anndata.io instead.
#   warnings.warn(

# %%
census_collections = cxg.dev.get_collections_from_cxg()

# %%
census_collections[0]
# Out:
# [{'collection_id': 'db70986c-7d91-49fe-a399-a4730be394ac',
#   'collection_url': 'https://cellxgene.cziscience.com/collections/db70986c-7d91-49fe-a399-a4730be394ac',
#   'collection_version_id': '261b9ea2-7c86-4fb8-a561-f23a2b06420d',
#   'consortia': [],
#   'contact_email': 'korbinian.traeuble@helmholtz-munich.de',
#   'contact_name': 'Korbinian Träuble',
#   'created_at': '2024-10-05T11:27:07+00:00',
#   'curator_name': 'James Chaffer',
#   'datasets': [{'assay': [{'label': "10x 3' v2",
#       'ontology_term_id': 'EFO:0009899'},
#      {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': '72955cdb-bd92-4135-aa52-21f33f9640db',
#     'dataset_version_id': '999a6b92-46ca-498e-b1ee-5fc43b6988ef',
#     'disease': [{'label': 'atherosclerosis',
#       'ontology_term_id': 'MONDO:0005311'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'carotid artery segment',
#       'ontology_term_id': 'UBERON:0005396',
#       'tissue_type': 'tissue'},
#      {'label': 'coronary artery',
#       'ontology_term_id': 'UBERON:0001621',
#       'tissue_type': 'tissue'},
#      {'label': 'femoral artery',
#       'ontology_term_id': 'UBERON:0002060',
#       'tissue_type': 'tissue'}]}],
#   'description': 'A curation of publicly available atherosclerotic plaque scRNAseq datasets including annotation and validation.',
#   'doi': '10.1101/2024.09.11.612431',
#   'links': [],
#   'name': 'Plaque Atlas',
#   'published_at': '2024-09-24T15:53:59+00:00',
#   'publisher_metadata': {'authors': [{'family': 'Traeuble', 'given': 'K.'},
#     {'family': 'Munz', 'given': 'M.'},
#     {'family': 'Pauli', 'given': 'J.'},
#     {'family': 'Sachs', 'given': 'N.'},
#     {'family': 'Vafadarnejad', 'given': 'E.'},
#     {'family': 'Carrillo-Roa', 'given': 'T.'},
#     {'family': 'Maegdefessel', 'given': 'L.'},
#     {'family': 'Kastner', 'given': 'P.'},
#     {'family': 'Heinig', 'given': 'M.'}],
#    'is_preprint': True,
#    'journal': 'bioRxiv',
#    'published_at': 1726099200.0,
#    'published_day': 12,
#    'published_month': 9,
#    'published_year': 2024},
#   'revised_at': '2024-10-10T20:20:32+00:00',
#   'revising_in': None,
#   'revision_of': None,
#   'visibility': 'PUBLIC'},
#  {'collection_id': '2902f08c-f83c-470e-a541-e463e25e5058',
#   'collection_url': 'https://cellxgene.cziscience.com/collections/2902f08c-f83c-470e-a541-e463e25e5058',
#   'collection_version_id': 'f6bb8e5a-d4b5-45b2-b2f5-b84480f84eb3',
#   'consortia': [],
#   'contact_email': 'lopes@lumc.nl',
#   'contact_name': 'S. M. Chuva de Sousa Lopes',
#   'created_at': '2024-10-07T16:40:15+00:00',
#   'curator_name': 'Jennifer Yu-Sheng Chien',
#   'datasets': [{'assay': [{'label': "10x 3' v2",
#       'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': '1f1c5c14-5949-4c81-b28e-b272e271b672',
#     'dataset_version_id': '2afef4bd-99af-41f4-b507-f80718b6a8ef',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'ovary',
#       'ontology_term_id': 'UBERON:0000992',
#       'tissue_type': 'tissue'}]}],
#   'description': 'The ovary is perhaps the most dynamic organ in the human body, only rivaled by the uterus. The molecular mechanisms that regulate follicular growth and regression, ensuring ovarian tissue homeostasis, remain elusive. We have performed single-cell RNA-sequencing using human adult ovaries to provide a map of the molecular signature of growing and regressing follicular populations. We have identified different types of granulosa and theca cells and detected local production of components of the complement system by (atretic) theca cells and stromal cells. We also have detected a mixture of adaptive and innate immune cells, as well as several types of endothelial and smooth muscle cells to aid the remodeling process. Our results highlight the relevance of mapping whole adult organs at the single-cell level and reflect ongoing efforts to map the human body. The association between complement system and follicular remodeling may provide key insights in reproductive biology and (in)fertility.',
#   'doi': '10.1038/s41467-019-11036-9',
#   'links': [{'link_name': '',
#     'link_type': 'OTHER',
#     'link_url': 'http://cells.ucsc.edu/?ds=ovarian-follicle-recon'},
#    {'link_name': '',
#     'link_type': 'RAW_DATA',
#     'link_url': 'https://explore.data.humancellatlas.org/projects/faeedcb0-e046-4be7-b1ad-80a3eeabb066'},
#    {'link_name': 'Github',
#     'link_type': 'OTHER',
#     'link_url': 'https://github.com/johnmous/singleCell'},
#    {'link_name': 'GSE118127',
#     'link_type': 'RAW_DATA',
#     'link_url': 'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE118127'}],
#   'name': 'Single-cell reconstruction of follicular remodeling in the human adult ovary',
#   'published_at': '2022-06-20T09:32:24+00:00',
#   'publisher_metadata': {'authors': [{'family': 'Fan', 'given': 'X.'},
#     {'family': 'Bialecka', 'given': 'M.'},
#     {'family': 'Moustakas', 'given': 'I.'},
#     {'family': 'Lam', 'given': 'E.'},
#     {'family': 'Torrens-Juaneda', 'given': 'V.'},
#     {'family': 'Borggreven', 'given': 'N. V.'},
#     {'family': 'Trouw', 'given': 'L.'},
#     {'family': 'Louwe', 'given': 'L. A.'},
#     {'family': 'Pilgram', 'given': 'G. S. K.'},
#     {'family': 'Mei', 'given': 'H.'},
#     {'family': 'van der Westerlaken', 'given': 'L.'},
#     {'family': 'Chuva de Sousa Lopes', 'given': 'S. M.'}],
#    'is_preprint': False,
#    'journal': 'Nat Commun',
#    'published_at': 1575158400.0,
#    'published_day': 1,
#    'published_month': 12,
#    'published_year': 2019},
#   'revised_at': '2024-10-10T20:20:32+00:00',
#   'revising_in': None,
#   'revision_of': None,
#   'visibility': 'PUBLIC'},
#  {'collection_id': '180bff9c-c8a5-4539-b13b-ddbc00d643e6',
#   'collection_url': 'https://cellxgene.cziscience.com/collections/180bff9c-c8a5-4539-b13b-ddbc00d643e6',
#   'collection_version_id': '08fe7e17-7a75-454e-b6b9-2cdf1d260541',
#   'consortia': [],
#   'contact_email': 'Martin.Kampmann@ucsf.edu',
#   'contact_name': 'Martin Kampmann',
#   'created_at': '2024-10-07T16:43:48+00:00',
#   'curator_name': 'Jennifer Yu-Sheng Chien',
#   'datasets': [{'assay': [{'label': "10x 3' v2",
#       'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': 'f9ad5649-f372-43e1-a3a8-423383e5a8a2',
#     'dataset_version_id': 'd9db936c-41c6-4398-a8c4-a9dca34a225e',
#     'disease': [{'label': 'Alzheimer disease',
#       'ontology_term_id': 'MONDO:0004975'},
#      {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'entorhinal cortex',
#       'ontology_term_id': 'UBERON:0002728',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': 'cd77258f-b08b-4c89-b93f-6e6f146b1a4d',
#     'dataset_version_id': '000198ac-27c7-4b9f-9fd4-6362a5b91596',
#     'disease': [{'label': 'Alzheimer disease',
#       'ontology_term_id': 'MONDO:0004975'},
#      {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'entorhinal cortex',
#       'ontology_term_id': 'UBERON:0002728',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': 'bdacc907-7c26-419f-8808-969eab3ca2e8',
#     'dataset_version_id': '017837df-b8be-4a4f-bc08-c5f14bd8815a',
#     'disease': [{'label': 'Alzheimer disease',
#       'ontology_term_id': 'MONDO:0004975'},
#      {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'superior frontal gyrus',
#       'ontology_term_id': 'UBERON:0002661',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': 'b94e3bdf-a385-49cc-b312-7a63cc28b77a',
#     'dataset_version_id': '3512034b-9a5c-4dba-9dfb-cead9f9840dc',
#     'disease': [{'label': 'Alzheimer disease',
#       'ontology_term_id': 'MONDO:0004975'},
#      {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'superior frontal gyrus',
#       'ontology_term_id': 'UBERON:0002661',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': '9f1049ac-f8b7-45ad-8e31-6e96c3e5058f',
#     'dataset_version_id': 'bb8f672d-593d-4820-b963-bc7ba00eae18',
#     'disease': [{'label': 'Alzheimer disease',
#       'ontology_term_id': 'MONDO:0004975'},
#      {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'entorhinal cortex',
#       'ontology_term_id': 'UBERON:0002728',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': '873ff933-4fda-4936-9a70-67df11af90ac',
#     'dataset_version_id': 'a7d3ba30-903d-44fd-a020-2d4ff8a3d49b',
#     'disease': [{'label': 'Alzheimer disease',
#       'ontology_term_id': 'MONDO:0004975'},
#      {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'superior frontal gyrus',
#       'ontology_term_id': 'UBERON:0002661',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': '75a881cf-5d88-46e2-bf9b-97e5cbc1bd56',
#     'dataset_version_id': '50d7154f-e5b9-48a6-b748-cd77b7cb6c54',
#     'disease': [{'label': 'Alzheimer disease',
#       'ontology_term_id': 'MONDO:0004975'},
#      {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'entorhinal cortex',
#       'ontology_term_id': 'UBERON:0002728',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': '6c600df6-ddca-4628-a8bb-1d6de1e3f9b4',
#     'dataset_version_id': '1f97f38b-2a9e-48ac-b4e7-ef879a34f24d',
#     'disease': [{'label': 'Alzheimer disease',
#       'ontology_term_id': 'MONDO:0004975'},
#      {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'superior frontal gyrus',
#       'ontology_term_id': 'UBERON:0002661',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': '2727d83a-0af0-443a-bff8-58dc7028289a',
#     'dataset_version_id': 'dd0627a2-4363-46e0-8185-d93a1bfce079',
#     'disease': [{'label': 'Alzheimer disease',
#       'ontology_term_id': 'MONDO:0004975'},
#      {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'entorhinal cortex',
#       'ontology_term_id': 'UBERON:0002728',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': '24066994-8183-488d-b037-ef6bb524af39',
#     'dataset_version_id': '4a5669e5-8977-4e49-94a6-b506de47b3a1',
#     'disease': [{'label': 'Alzheimer disease',
#       'ontology_term_id': 'MONDO:0004975'},
#      {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'superior frontal gyrus',
#       'ontology_term_id': 'UBERON:0002661',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': '1492eb6b-7d50-4c4d-94ac-c801a7d5555c',
#     'dataset_version_id': '419a15fc-6770-41b0-99ac-5de62558a194',
#     'disease': [{'label': 'Alzheimer disease',
#       'ontology_term_id': 'MONDO:0004975'},
#      {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'superior frontal gyrus',
#       'ontology_term_id': 'UBERON:0002661',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'}],
#     'dataset_id': '06b91002-4d3d-4d2e-8484-20c3b31e232c',
#     'dataset_version_id': '719e608c-012b-4876-bc24-f62460935d9b',
#     'disease': [{'label': 'Alzheimer disease',
#       'ontology_term_id': 'MONDO:0004975'},
#      {'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'entorhinal cortex',
#       'ontology_term_id': 'UBERON:0002728',
#       'tissue_type': 'tissue'}]}],
#   'description': 'Single-nuclei RNA sequencing of caudal entorhinal cortex and superior frontal gyrus from individuals spanning the neuropathological progression of AD',
#   'doi': '10.1038/s41593-020-00764-7',
#   'links': [{'link_name': 'GSE147528',
#     'link_type': 'RAW_DATA',
#     'link_url': 'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE147528'},
#    {'link_name': '',
#     'link_type': 'OTHER',
#     'link_url': 'https://kampmannlab.ucsf.edu/ad-brain-analysis'},
#    {'link_name': 'Synapse',
#     'link_type': 'OTHER',
#     'link_url': 'https://www.synapse.org/#!Synapse:syn21788402/wiki/601825'},
#    {'link_name': '',
#     'link_type': 'RAW_DATA',
#     'link_url': 'https://explore.data.humancellatlas.org/projects/7dcffc32-7c82-4396-9a4f-88b5579bfe8a'}],
#   'name': "Molecular characterization of selectively vulnerable neurons in Alzheimer's Disease",
#   'published_at': '2020-11-20T13:39:38+00:00',
#   'publisher_metadata': {'authors': [{'family': 'Leng', 'given': 'Kun'},
#     {'family': 'Li', 'given': 'Emmy'},
#     {'family': 'Eser', 'given': 'Rana'},
#     {'family': 'Piergies', 'given': 'Antonia'},
#     {'family': 'Sit', 'given': 'Rene'},
#     {'family': 'Tan', 'given': 'Michelle'},
#     {'family': 'Neff', 'given': 'Norma'},
#     {'family': 'Li', 'given': 'Song Hua'},
#     {'family': 'Rodriguez', 'given': 'Roberta Diehl'},
#     {'family': 'Suemoto', 'given': 'Claudia Kimie'},
#     {'family': 'Leite', 'given': 'Renata Elaine Paraizo'},
#     {'family': 'Ehrenberg', 'given': 'Alexander J.'},
#     {'family': 'Pasqualucci', 'given': 'Carlos A.'},
#     {'family': 'Seeley', 'given': 'William W.'},
#     {'family': 'Spina', 'given': 'Salvatore'},
#     {'family': 'Heinsen', 'given': 'Helmut'},
#     {'family': 'Grinberg', 'given': 'Lea T.'},
#     {'family': 'Kampmann', 'given': 'Martin'}],
#    'is_preprint': False,
#    'journal': 'Nat Neurosci',
#    'published_at': 1612137600.0,
#    'published_day': 1,
#    'published_month': 2,
#    'published_year': 2021},
#   'revised_at': '2024-10-10T20:20:33+00:00',
#   'revising_in': None,
#   'revision_of': None,
#   'visibility': 'PUBLIC'},
#  {'collection_id': '02b01703-bf1b-48de-b99a-23bef8cccc81',
#   'collection_url': 'https://cellxgene.cziscience.com/collections/02b01703-bf1b-48de-b99a-23bef8cccc81',
#   'collection_version_id': 'e82e40f6-3696-4b3b-9b62-09ad604a6727',
#   'consortia': [],
#   'contact_email': 'sophliu95@gmail.com',
#   'contact_name': 'Sophia Liu',
#   'created_at': '2024-10-07T16:45:12+00:00',
#   'curator_name': 'Jennifer Yu-Sheng Chien',
#   'datasets': [{'assay': [{'label': 'Slide-seqV2',
#       'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': 'fb5b437f-69b8-47ee-82ed-b5e784193d64',
#     'dataset_version_id': 'b0a457a6-5542-40e1-8e93-385ff98afc8d',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lymph node',
#       'ontology_term_id': 'UBERON:0000029',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': 'f339fe89-c99c-4f50-b76d-2ffe9d376500',
#     'dataset_version_id': '4a074e6d-b5b4-43d2-b5dc-d00dc37128a1',
#     'disease': [{'label': 'renal cell carcinoma',
#       'ontology_term_id': 'MONDO:0005086'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'kidney',
#       'ontology_term_id': 'UBERON:0002113',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': 'dcb7c544-bf18-4f9a-97a4-aa816910d862',
#     'dataset_version_id': '62a08d13-7ff9-46ec-a77c-5278eefc5a19',
#     'disease': [{'label': 'metastatic melanoma',
#       'ontology_term_id': 'MONDO:0005191'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lymph node',
#       'ontology_term_id': 'UBERON:0000029',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': 'd4dc4cfe-7da5-4e56-bf96-83f01082f5df',
#     'dataset_version_id': '566c77da-caac-4cd0-a74a-3b23cf7d1323',
#     'disease': [{'label': 'metastatic melanoma',
#       'ontology_term_id': 'MONDO:0005191'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lymph node',
#       'ontology_term_id': 'UBERON:0000029',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': 'cc43509e-8729-4cbc-ace9-f0f7d654ee53',
#     'dataset_version_id': '52e48e6c-a0d2-4a3d-ad16-1570c397929c',
#     'disease': [{'label': 'renal cell carcinoma',
#       'ontology_term_id': 'MONDO:0005086'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lung',
#       'ontology_term_id': 'UBERON:0002048',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': 'c62ac8e5-72d1-48d1-8bb5-9e66fd2b1e19',
#     'dataset_version_id': '6a01686c-f4d6-4fa0-b255-da0dcfcd1804',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Mus musculus',
#       'ontology_term_id': 'NCBITaxon:10090'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'spleen',
#       'ontology_term_id': 'UBERON:0002106',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': 'b3052902-613c-4b04-a0f5-bafd397bb125',
#     'dataset_version_id': '2a9beab1-7feb-4b07-811b-f8e429f0d6b1',
#     'disease': [{'label': 'metastatic melanoma',
#       'ontology_term_id': 'MONDO:0005191'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lymph node',
#       'ontology_term_id': 'UBERON:0000029',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': 'ae4552dc-e2ea-4d67-b375-03ec7480f780',
#     'dataset_version_id': 'bd7a9706-e537-43bf-ab25-754550df3aa5',
#     'disease': [{'label': 'metastatic melanoma',
#       'ontology_term_id': 'MONDO:0005191'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lymph node',
#       'ontology_term_id': 'UBERON:0000029',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': '9b1437bb-42fe-47d8-8962-835d95581763',
#     'dataset_version_id': '9b84d002-a939-406e-99ed-ed35979aef1c',
#     'disease': [{'label': 'renal cell carcinoma',
#       'ontology_term_id': 'MONDO:0005086'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lung',
#       'ontology_term_id': 'UBERON:0002048',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': '89972213-8510-49c3-a55a-01cd248ef88a',
#     'dataset_version_id': '19a9b03d-5534-42e8-8b89-c508935c661c',
#     'disease': [{'label': 'metastatic melanoma',
#       'ontology_term_id': 'MONDO:0005191'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lymph node',
#       'ontology_term_id': 'UBERON:0000029',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': '76bb43ff-e2f5-4513-a0f0-1059c860c3b7',
#     'dataset_version_id': '23faf7da-1792-4069-b20c-a035fd301698',
#     'disease': [{'label': 'metastatic melanoma',
#       'ontology_term_id': 'MONDO:0005191'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lymph node',
#       'ontology_term_id': 'UBERON:0000029',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': '6d243918-f3f6-4a9e-b72e-39d96de73095',
#     'dataset_version_id': '70899125-f279-449b-8a80-c2ce52f518e4',
#     'disease': [{'label': 'renal cell carcinoma',
#       'ontology_term_id': 'MONDO:0005086'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lung',
#       'ontology_term_id': 'UBERON:0002048',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': '50c4a6d6-940b-4c6a-a376-aea2ae2d3168',
#     'dataset_version_id': '34494d50-70cc-4514-af9d-546a4e6d5236',
#     'disease': [{'label': 'metastatic melanoma',
#       'ontology_term_id': 'MONDO:0005191'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lymph node',
#       'ontology_term_id': 'UBERON:0000029',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': '4aefec71-da4e-48ec-a910-c542b5807c7d',
#     'dataset_version_id': '20a80421-84f6-410f-b4c8-96aa2515fa64',
#     'disease': [{'label': 'renal cell carcinoma',
#       'ontology_term_id': 'MONDO:0005086'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lung',
#       'ontology_term_id': 'UBERON:0002048',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': '32ffc3a7-c88d-49e1-894f-8e09d0184ee9',
#     'dataset_version_id': '428cddbd-6041-491c-bcb2-e10169ac61cb',
#     'disease': [{'label': 'renal cell carcinoma',
#       'ontology_term_id': 'MONDO:0005086'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lung',
#       'ontology_term_id': 'UBERON:0002048',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': '18fd0190-229d-4d2b-8f28-1e40c49c750d',
#     'dataset_version_id': 'd5262dad-641f-4152-ace8-158966134b01',
#     'disease': [{'label': 'renal cell carcinoma',
#       'ontology_term_id': 'MONDO:0005086'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lung',
#       'ontology_term_id': 'UBERON:0002048',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': '16101789-b95d-4b05-bd76-75ae837a557b',
#     'dataset_version_id': '9a9e7428-9397-409c-a699-7eb6f95923ab',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'tonsil',
#       'ontology_term_id': 'UBERON:0002372',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': '07efa1c3-7649-43d8-b798-e26a0145ee65',
#     'dataset_version_id': '20bb0094-2b6b-4459-995a-0766b5510bd6',
#     'disease': [{'label': 'renal cell carcinoma',
#       'ontology_term_id': 'MONDO:0005086'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'lung',
#       'ontology_term_id': 'UBERON:0002048',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': 'Slide-seqV2', 'ontology_term_id': 'EFO:0030062'}],
#     'dataset_id': '02faf712-92d4-4589-bec7-13105059cf86',
#     'dataset_version_id': 'be671006-d1c3-43e0-8c75-899824a6f0e2',
#     'disease': [{'label': 'renal cell carcinoma',
#       'ontology_term_id': 'MONDO:0005086'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['na'],
#     'tissue': [{'label': 'kidney',
#       'ontology_term_id': 'UBERON:0002113',
#       'tissue_type': 'tissue'}]}],
#   'description': 'This repository contains data from our manuscript, Spatially mapping T cell receptors and transcriptomes. T cells mediate antigen-specific immune responses to disease through the specificity and diversity of their T-cell receptors (TCRs). Determining the spatial distributions of T cell clonotypes in tissues is essential to understanding T cell maturation and behavior, but spatial sequencing methods remain unable to profile the TCR repertoire. Here, we develop Slide-TCR-seq, a 10-µm-resolution method to sequence whole transcriptomes and TCRs within intact tissues. We confirm the ability of Slide-TCR-seq to map the characteristic architecture of T cells and their receptors in mouse spleen. In human lymph nodes and tonsil, we identified spatially distinct TCR repertoires. Spatial profiling of T cell clonotypes and their infiltration in renal cell carcinoma and melanoma specimens identified inter- and intra-clonotype transcriptional heterogeneity. Our method facilitates the dissection of the immune microenvironment, yielding insights into the complex spatial relationships between T cell clonotypes, neighboring cell types, and gene expression that drive T cell responses across diseases.',
#   'doi': '10.1016/j.immuni.2022.09.002',
#   'links': [{'link_name': '',
#     'link_type': 'OTHER',
#     'link_url': 'https://singlecell.broadinstitute.org/single_cell/study/SCP1348/slide-tcr-seq-data'},
#    {'link_name': '',
#     'link_type': 'OTHER',
#     'link_url': 'https://github.com/soph-liu/Slide-TCR-seq'}],
#   'name': 'Spatially mapping T cell receptors and transcriptomes',
#   'published_at': '2023-09-29T19:16:15+00:00',
#   'publisher_metadata': {'authors': [{'family': 'Liu', 'given': 'Sophia'},
#     {'family': 'Iorgulescu', 'given': 'J. Bryan'},
#     {'family': 'Li', 'given': 'Shuqiang'},
#     {'family': 'Borji', 'given': 'Mehdi'},
#     {'family': 'Barrera-Lopez', 'given': 'Irving A.'},
#     {'family': 'Shanmugam', 'given': 'Vignesh'},
#     {'family': 'Lyu', 'given': 'Haoxiang'},
#     {'family': 'Morriss', 'given': 'Julia W.'},
#     {'family': 'Garcia', 'given': 'Zoe N.'},
#     {'family': 'Murray', 'given': 'Evan'},
#     {'family': 'Reardon', 'given': 'David A.'},
#     {'family': 'Yoon', 'given': 'Charles H.'},
#     {'family': 'Braun', 'given': 'David A.'},
#     {'family': 'Livak', 'given': 'Kenneth J.'},
#     {'family': 'Wu', 'given': 'Catherine J.'},
#     {'family': 'Chen', 'given': 'Fei'}],
#    'is_preprint': False,
#    'journal': 'Immunity',
#    'published_at': 1664582400.0,
#    'published_day': 1,
#    'published_month': 10,
#    'published_year': 2022},
#   'revised_at': '2024-10-10T20:20:34+00:00',
#   'revising_in': None,
#   'revision_of': None,
#   'visibility': 'PUBLIC'},
#  {'collection_id': '4d8fed08-2d6d-4692-b5ea-464f1d072077',
#   'collection_url': 'https://cellxgene.cziscience.com/collections/4d8fed08-2d6d-4692-b5ea-464f1d072077',
#   'collection_version_id': '2280eac2-a84b-4b9a-9023-684f099659f8',
#   'consortia': [],
#   'contact_email': 'sten.linnarsson@ki.se',
#   'contact_name': 'Sten Linnarsson',
#   'created_at': '2024-10-05T11:29:42+00:00',
#   'curator_name': 'James Chaffer',
#   'datasets': [{'assay': [{'label': "10x 3' v2",
#       'ontology_term_id': 'EFO:0009899'},
#      {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': 'ea7b95cf-1967-4431-9ee8-ec85ff793360',
#     'dataset_version_id': 'd7a55d23-ca07-446a-9c48-267fe490d1fc',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'basal forebrain',
#       'ontology_term_id': 'UBERON:0002743',
#       'tissue_type': 'tissue'},
#      {'label': 'brain',
#       'ontology_term_id': 'UBERON:0000955',
#       'tissue_type': 'tissue'},
#      {'label': 'caudate-putamen',
#       'ontology_term_id': 'UBERON:0005383',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebellar peduncular complex',
#       'ontology_term_id': 'UBERON:0002474',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebellum',
#       'ontology_term_id': 'UBERON:0002037',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebral subcortex',
#       'ontology_term_id': 'UBERON:0000454',
#       'tissue_type': 'tissue'},
#      {'label': 'choroid plexus epithelium',
#       'ontology_term_id': 'UBERON:0003911',
#       'tissue_type': 'tissue'},
#      {'label': 'cortex',
#       'ontology_term_id': 'UBERON:0001851',
#       'tissue_type': 'tissue'},
#      {'label': 'diencephalon',
#       'ontology_term_id': 'UBERON:0001894',
#       'tissue_type': 'tissue'},
#      {'label': 'dorsal plus ventral thalamus',
#       'ontology_term_id': 'UBERON:0001897',
#       'tissue_type': 'tissue'},
#      {'label': 'entorhinal cortex',
#       'ontology_term_id': 'UBERON:0002728',
#       'tissue_type': 'tissue'},
#      {'label': 'forebrain',
#       'ontology_term_id': 'UBERON:0001890',
#       'tissue_type': 'tissue'},
#      {'label': 'frontal cortex',
#       'ontology_term_id': 'UBERON:0001870',
#       'tissue_type': 'tissue'},
#      {'label': 'head',
#       'ontology_term_id': 'UBERON:0000033',
#       'tissue_type': 'tissue'},
#      {'label': 'hindbrain',
#       'ontology_term_id': 'UBERON:0002028',
#       'tissue_type': 'tissue'},
#      {'label': 'hippocampal formation',
#       'ontology_term_id': 'UBERON:0002421',
#       'tissue_type': 'tissue'},
#      {'label': 'hypothalamus',
#       'ontology_term_id': 'UBERON:0001898',
#       'tissue_type': 'tissue'},
#      {'label': 'lower layers of the cortex',
#       'ontology_term_id': 'UBERON:8440051',
#       'tissue_type': 'tissue'},
#      {'label': 'medulla oblongata',
#       'ontology_term_id': 'UBERON:0001896',
#       'tissue_type': 'tissue'},
#      {'label': 'metencephalon',
#       'ontology_term_id': 'UBERON:0001895',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain',
#       'ontology_term_id': 'UBERON:0001891',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain tectum',
#       'ontology_term_id': 'UBERON:0002314',
#       'tissue_type': 'tissue'},
#      {'label': 'occipital cortex',
#       'ontology_term_id': 'UBERON:0016540',
#       'tissue_type': 'tissue'},
#      {'label': 'pons',
#       'ontology_term_id': 'UBERON:0000988',
#       'tissue_type': 'tissue'},
#      {'label': 'striatum',
#       'ontology_term_id': 'UBERON:0002435',
#       'tissue_type': 'tissue'},
#      {'label': 'telencephalon',
#       'ontology_term_id': 'UBERON:0001893',
#       'tissue_type': 'tissue'},
#      {'label': 'upper layers of the cortex',
#       'ontology_term_id': 'UBERON:8440044',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'},
#      {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': 'ea251de5-c764-4f7c-add0-8141b1061faf',
#     'dataset_version_id': 'a6827613-dd1f-4811-a823-d920b972fc86',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'basal forebrain',
#       'ontology_term_id': 'UBERON:0002743',
#       'tissue_type': 'tissue'},
#      {'label': 'brain',
#       'ontology_term_id': 'UBERON:0000955',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebellar peduncular complex',
#       'ontology_term_id': 'UBERON:0002474',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebellum',
#       'ontology_term_id': 'UBERON:0002037',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebral subcortex',
#       'ontology_term_id': 'UBERON:0000454',
#       'tissue_type': 'tissue'},
#      {'label': 'cortex',
#       'ontology_term_id': 'UBERON:0001851',
#       'tissue_type': 'tissue'},
#      {'label': 'dorsal plus ventral thalamus',
#       'ontology_term_id': 'UBERON:0001897',
#       'tissue_type': 'tissue'},
#      {'label': 'forebrain',
#       'ontology_term_id': 'UBERON:0001890',
#       'tissue_type': 'tissue'},
#      {'label': 'head',
#       'ontology_term_id': 'UBERON:0000033',
#       'tissue_type': 'tissue'},
#      {'label': 'hindbrain',
#       'ontology_term_id': 'UBERON:0002028',
#       'tissue_type': 'tissue'},
#      {'label': 'hippocampal formation',
#       'ontology_term_id': 'UBERON:0002421',
#       'tissue_type': 'tissue'},
#      {'label': 'hypothalamus',
#       'ontology_term_id': 'UBERON:0001898',
#       'tissue_type': 'tissue'},
#      {'label': 'lower layers of the cortex',
#       'ontology_term_id': 'UBERON:8440051',
#       'tissue_type': 'tissue'},
#      {'label': 'medulla oblongata',
#       'ontology_term_id': 'UBERON:0001896',
#       'tissue_type': 'tissue'},
#      {'label': 'metencephalon',
#       'ontology_term_id': 'UBERON:0001895',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain',
#       'ontology_term_id': 'UBERON:0001891',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain tectum',
#       'ontology_term_id': 'UBERON:0002314',
#       'tissue_type': 'tissue'},
#      {'label': 'occipital cortex',
#       'ontology_term_id': 'UBERON:0016540',
#       'tissue_type': 'tissue'},
#      {'label': 'pons',
#       'ontology_term_id': 'UBERON:0000988',
#       'tissue_type': 'tissue'},
#      {'label': 'upper layers of the cortex',
#       'ontology_term_id': 'UBERON:8440044',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'},
#      {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': 'e59a4394-80db-42e4-85e6-8f0e59b81f42',
#     'dataset_version_id': '9bdeb1c1-37a9-48c9-8334-a6efebb2eed9',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'basal forebrain',
#       'ontology_term_id': 'UBERON:0002743',
#       'tissue_type': 'tissue'},
#      {'label': 'brain',
#       'ontology_term_id': 'UBERON:0000955',
#       'tissue_type': 'tissue'},
#      {'label': 'caudate-putamen',
#       'ontology_term_id': 'UBERON:0005383',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebellar peduncular complex',
#       'ontology_term_id': 'UBERON:0002474',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebellum',
#       'ontology_term_id': 'UBERON:0002037',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebral subcortex',
#       'ontology_term_id': 'UBERON:0000454',
#       'tissue_type': 'tissue'},
#      {'label': 'choroid plexus epithelium',
#       'ontology_term_id': 'UBERON:0003911',
#       'tissue_type': 'tissue'},
#      {'label': 'cortex',
#       'ontology_term_id': 'UBERON:0001851',
#       'tissue_type': 'tissue'},
#      {'label': 'diencephalon',
#       'ontology_term_id': 'UBERON:0001894',
#       'tissue_type': 'tissue'},
#      {'label': 'dorsal plus ventral thalamus',
#       'ontology_term_id': 'UBERON:0001897',
#       'tissue_type': 'tissue'},
#      {'label': 'entorhinal cortex',
#       'ontology_term_id': 'UBERON:0002728',
#       'tissue_type': 'tissue'},
#      {'label': 'forebrain',
#       'ontology_term_id': 'UBERON:0001890',
#       'tissue_type': 'tissue'},
#      {'label': 'frontal cortex',
#       'ontology_term_id': 'UBERON:0001870',
#       'tissue_type': 'tissue'},
#      {'label': 'head',
#       'ontology_term_id': 'UBERON:0000033',
#       'tissue_type': 'tissue'},
#      {'label': 'hindbrain',
#       'ontology_term_id': 'UBERON:0002028',
#       'tissue_type': 'tissue'},
#      {'label': 'hippocampal formation',
#       'ontology_term_id': 'UBERON:0002421',
#       'tissue_type': 'tissue'},
#      {'label': 'hypothalamus',
#       'ontology_term_id': 'UBERON:0001898',
#       'tissue_type': 'tissue'},
#      {'label': 'lower layers of the cortex',
#       'ontology_term_id': 'UBERON:8440051',
#       'tissue_type': 'tissue'},
#      {'label': 'medulla oblongata',
#       'ontology_term_id': 'UBERON:0001896',
#       'tissue_type': 'tissue'},
#      {'label': 'metencephalon',
#       'ontology_term_id': 'UBERON:0001895',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain',
#       'ontology_term_id': 'UBERON:0001891',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain tectum',
#       'ontology_term_id': 'UBERON:0002314',
#       'tissue_type': 'tissue'},
#      {'label': 'occipital cortex',
#       'ontology_term_id': 'UBERON:0016540',
#       'tissue_type': 'tissue'},
#      {'label': 'pons',
#       'ontology_term_id': 'UBERON:0000988',
#       'tissue_type': 'tissue'},
#      {'label': 'striatum',
#       'ontology_term_id': 'UBERON:0002435',
#       'tissue_type': 'tissue'},
#      {'label': 'telencephalon',
#       'ontology_term_id': 'UBERON:0001893',
#       'tissue_type': 'tissue'},
#      {'label': 'upper layers of the cortex',
#       'ontology_term_id': 'UBERON:8440044',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'},
#      {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': 'e47a4c13-22ba-4c77-99bc-13f7d60af799',
#     'dataset_version_id': '0cc4c43c-6e7b-4f91-a240-7bf35c45b97b',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'cerebellum',
#       'ontology_term_id': 'UBERON:0002037',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'},
#      {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': 'bfbd9097-65a2-4019-aff3-f875aca51952',
#     'dataset_version_id': '2f25319f-12ee-4bd5-a587-08157da300c6',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'cerebellar peduncular complex',
#       'ontology_term_id': 'UBERON:0002474',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain',
#       'ontology_term_id': 'UBERON:0001891',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain tectum',
#       'ontology_term_id': 'UBERON:0002314',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'},
#      {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': 'b15ec84b-46e9-4678-b511-a0f81f9b545b',
#     'dataset_version_id': 'a517ac77-a03f-4fbe-9c7c-74487fdf75c6',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'basal forebrain',
#       'ontology_term_id': 'UBERON:0002743',
#       'tissue_type': 'tissue'},
#      {'label': 'brain',
#       'ontology_term_id': 'UBERON:0000955',
#       'tissue_type': 'tissue'},
#      {'label': 'caudate-putamen',
#       'ontology_term_id': 'UBERON:0005383',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebellar peduncular complex',
#       'ontology_term_id': 'UBERON:0002474',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebellum',
#       'ontology_term_id': 'UBERON:0002037',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebral subcortex',
#       'ontology_term_id': 'UBERON:0000454',
#       'tissue_type': 'tissue'},
#      {'label': 'cortex',
#       'ontology_term_id': 'UBERON:0001851',
#       'tissue_type': 'tissue'},
#      {'label': 'diencephalon',
#       'ontology_term_id': 'UBERON:0001894',
#       'tissue_type': 'tissue'},
#      {'label': 'dorsal plus ventral thalamus',
#       'ontology_term_id': 'UBERON:0001897',
#       'tissue_type': 'tissue'},
#      {'label': 'entorhinal cortex',
#       'ontology_term_id': 'UBERON:0002728',
#       'tissue_type': 'tissue'},
#      {'label': 'forebrain',
#       'ontology_term_id': 'UBERON:0001890',
#       'tissue_type': 'tissue'},
#      {'label': 'frontal cortex',
#       'ontology_term_id': 'UBERON:0001870',
#       'tissue_type': 'tissue'},
#      {'label': 'hindbrain',
#       'ontology_term_id': 'UBERON:0002028',
#       'tissue_type': 'tissue'},
#      {'label': 'hippocampal formation',
#       'ontology_term_id': 'UBERON:0002421',
#       'tissue_type': 'tissue'},
#      {'label': 'hypothalamus',
#       'ontology_term_id': 'UBERON:0001898',
#       'tissue_type': 'tissue'},
#      {'label': 'lower layers of the cortex',
#       'ontology_term_id': 'UBERON:8440051',
#       'tissue_type': 'tissue'},
#      {'label': 'medulla oblongata',
#       'ontology_term_id': 'UBERON:0001896',
#       'tissue_type': 'tissue'},
#      {'label': 'metencephalon',
#       'ontology_term_id': 'UBERON:0001895',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain',
#       'ontology_term_id': 'UBERON:0001891',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain tectum',
#       'ontology_term_id': 'UBERON:0002314',
#       'tissue_type': 'tissue'},
#      {'label': 'occipital cortex',
#       'ontology_term_id': 'UBERON:0016540',
#       'tissue_type': 'tissue'},
#      {'label': 'pons',
#       'ontology_term_id': 'UBERON:0000988',
#       'tissue_type': 'tissue'},
#      {'label': 'striatum',
#       'ontology_term_id': 'UBERON:0002435',
#       'tissue_type': 'tissue'},
#      {'label': 'telencephalon',
#       'ontology_term_id': 'UBERON:0001893',
#       'tissue_type': 'tissue'},
#      {'label': 'upper layers of the cortex',
#       'ontology_term_id': 'UBERON:8440044',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'},
#      {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': 'a24ecf77-c059-4dc5-8ca4-3b89d667b7f8',
#     'dataset_version_id': '79a6b1ee-309a-4ca6-a8fb-39d2da0e1eb3',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'cerebellum',
#       'ontology_term_id': 'UBERON:0002037',
#       'tissue_type': 'tissue'},
#      {'label': 'forebrain',
#       'ontology_term_id': 'UBERON:0001890',
#       'tissue_type': 'tissue'},
#      {'label': 'head',
#       'ontology_term_id': 'UBERON:0000033',
#       'tissue_type': 'tissue'},
#      {'label': 'hindbrain',
#       'ontology_term_id': 'UBERON:0002028',
#       'tissue_type': 'tissue'},
#      {'label': 'medulla oblongata',
#       'ontology_term_id': 'UBERON:0001896',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain',
#       'ontology_term_id': 'UBERON:0001891',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'},
#      {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': '9f984b44-9c72-4aa3-b8c5-65823071c3d6',
#     'dataset_version_id': '1c3b3da2-7cb7-4dc9-9a76-659d4cff395d',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'medulla oblongata',
#       'ontology_term_id': 'UBERON:0001896',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'},
#      {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': '91b2327d-e3f3-4f63-b446-20774d20fc33',
#     'dataset_version_id': '648df3ef-670e-427a-b7b0-305fe05e64c3',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'basal forebrain',
#       'ontology_term_id': 'UBERON:0002743',
#       'tissue_type': 'tissue'},
#      {'label': 'brain',
#       'ontology_term_id': 'UBERON:0000955',
#       'tissue_type': 'tissue'},
#      {'label': 'caudate-putamen',
#       'ontology_term_id': 'UBERON:0005383',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebellar peduncular complex',
#       'ontology_term_id': 'UBERON:0002474',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebellum',
#       'ontology_term_id': 'UBERON:0002037',
#       'tissue_type': 'tissue'},
#      {'label': 'cerebral subcortex',
#       'ontology_term_id': 'UBERON:0000454',
#       'tissue_type': 'tissue'},
#      {'label': 'cortex',
#       'ontology_term_id': 'UBERON:0001851',
#       'tissue_type': 'tissue'},
#      {'label': 'dorsal plus ventral thalamus',
#       'ontology_term_id': 'UBERON:0001897',
#       'tissue_type': 'tissue'},
#      {'label': 'entorhinal cortex',
#       'ontology_term_id': 'UBERON:0002728',
#       'tissue_type': 'tissue'},
#      {'label': 'forebrain',
#       'ontology_term_id': 'UBERON:0001890',
#       'tissue_type': 'tissue'},
#      {'label': 'frontal cortex',
#       'ontology_term_id': 'UBERON:0001870',
#       'tissue_type': 'tissue'},
#      {'label': 'hindbrain',
#       'ontology_term_id': 'UBERON:0002028',
#       'tissue_type': 'tissue'},
#      {'label': 'hippocampal formation',
#       'ontology_term_id': 'UBERON:0002421',
#       'tissue_type': 'tissue'},
#      {'label': 'hypothalamus',
#       'ontology_term_id': 'UBERON:0001898',
#       'tissue_type': 'tissue'},
#      {'label': 'lower layers of the cortex',
#       'ontology_term_id': 'UBERON:8440051',
#       'tissue_type': 'tissue'},
#      {'label': 'medulla oblongata',
#       'ontology_term_id': 'UBERON:0001896',
#       'tissue_type': 'tissue'},
#      {'label': 'metencephalon',
#       'ontology_term_id': 'UBERON:0001895',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain',
#       'ontology_term_id': 'UBERON:0001891',
#       'tissue_type': 'tissue'},
#      {'label': 'midbrain tectum',
#       'ontology_term_id': 'UBERON:0002314',
#       'tissue_type': 'tissue'},
#      {'label': 'occipital cortex',
#       'ontology_term_id': 'UBERON:0016540',
#       'tissue_type': 'tissue'},
#      {'label': 'pons',
#       'ontology_term_id': 'UBERON:0000988',
#       'tissue_type': 'tissue'},
#      {'label': 'striatum',
#       'ontology_term_id': 'UBERON:0002435',
#       'tissue_type': 'tissue'},
#      {'label': 'upper layers of the cortex',
#       'ontology_term_id': 'UBERON:8440044',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v2", 'ontology_term_id': 'EFO:0009899'},
#      {'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
# ...
#     'tissue': [{'label': 'ileum',
#       'ontology_term_id': 'UBERON:0002116',
#       'tissue_type': 'tissue'}]}],
#   'description': 'Clinical benefits of cytokine blockade in ileal Crohn’s disease (iCD) are limited to a subset of patients. Here, we applied single-cell technologies to iCD lesions to address whether cellular heterogeneity contributes to treatment resistance. We found that a subset of patients expressed a unique cellular module in inflamed tissues that consisted of IgG plasma cells, inflammatory mononuclear phagocytes, activated T cells, and stromal cells, which we named the GIMATS module. Analysis of ligand-receptor interaction pairs identified a distinct network connectivity that likely drives the GIMATS module. Strikingly, the GIMATS module was also present in a subset of patients in four independent iCD cohorts (n = 441), and its presence at diagnosis correlated with failure to achieve durable corticosteroid-free remission upon anti-TNF therapy. These results emphasize the limitations of current diagnostic assays and the potential for single-cell mapping tools to identify novel biomarkers of treatment response and tailored therapeutic opportunities.',
#   'doi': '10.1016/j.cell.2019.08.008',
#   'links': [{'link_name': '',
#     'link_type': 'RAW_DATA',
#     'link_url': 'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE134809'},
#    {'link_name': '',
#     'link_type': 'OTHER',
#     'link_url': 'https://github.com/effiken/martin_et_al_cell_2019'},
#    {'link_name': '',
#     'link_type': 'OTHER',
#     'link_url': 'https://scdissector.org/martin/'},
#    {'link_name': '',
#     'link_type': 'RAW_DATA',
#     'link_url': 'https://explore.data.humancellatlas.org/projects/504e0cee-1688-40fa-b936-361c4a831f87'},
#    {'link_name': '',
#     'link_type': 'OTHER',
#     'link_url': 'https://www.ebi.ac.uk/gxa/sc/experiments/E-CURD-46'},
#    {'link_name': '',
#     'link_type': 'OTHER',
#     'link_url': 'https://cells.ucsc.edu/?ds=human-ileum'}],
#   'name': 'Single-Cell Analysis of Crohn’s Disease Lesions Identifies a Pathogenic Cellular Module Associated with Resistance to Anti-TNF Therapy',
#   'published_at': '2022-04-26T09:35:40+00:00',
#   'publisher_metadata': {'authors': [{'family': 'Martin',
#      'given': 'Jerome C.'},
#     {'family': 'Chang', 'given': 'Christie'},
#     {'family': 'Boschetti', 'given': 'Gilles'},
#     {'family': 'Ungaro', 'given': 'Ryan'},
#     {'family': 'Giri', 'given': 'Mamta'},
#     {'family': 'Grout', 'given': 'John A.'},
#     {'family': 'Gettler', 'given': 'Kyle'},
#     {'family': 'Chuang', 'given': 'Ling-shiang'},
#     {'family': 'Nayar', 'given': 'Shikha'},
#     {'family': 'Greenstein', 'given': 'Alexander J.'},
#     {'family': 'Dubinsky', 'given': 'Marla'},
#     {'family': 'Walker', 'given': 'Laura'},
#     {'family': 'Leader', 'given': 'Andrew'},
#     {'family': 'Fine', 'given': 'Jay S.'},
#     {'family': 'Whitehurst', 'given': 'Charles E.'},
#     {'family': 'Mbow', 'given': 'M Lamine'},
#     {'family': 'Kugathasan', 'given': 'Subra'},
#     {'family': 'Denson', 'given': 'Lee A.'},
#     {'family': 'Hyams', 'given': 'Jeffrey S.'},
#     {'family': 'Friedman', 'given': 'Joshua R.'},
#     {'family': 'Desai', 'given': 'Prerak T.'},
#     {'family': 'Ko', 'given': 'Huaibin M.'},
#     {'family': 'Laface', 'given': 'Ilaria'},
#     {'family': 'Akturk', 'given': 'Guray'},
#     {'family': 'Schadt', 'given': 'Eric E.'},
#     {'family': 'Salmon', 'given': 'Helene'},
#     {'family': 'Gnjatic', 'given': 'Sacha'},
#     {'family': 'Rahman', 'given': 'Adeeb H.'},
#     {'family': 'Merad', 'given': 'Miriam'},
#     {'family': 'Cho', 'given': 'Judy H.'},
#     {'family': 'Kenigsberg', 'given': 'Ephraim'}],
#    'is_preprint': False,
#    'journal': 'Cell',
#    'published_at': 1567296000.0,
#    'published_day': 1,
#    'published_month': 9,
#    'published_year': 2019},
#   'revised_at': '2024-10-10T20:24:54+00:00',
#   'revising_in': None,
#   'revision_of': None,
#   'visibility': 'PUBLIC'},
#  {'collection_id': '3db5617e-9f12-4eb4-8416-94893a0d7c46',
#   'collection_url': 'https://cellxgene.cziscience.com/collections/3db5617e-9f12-4eb4-8416-94893a0d7c46',
#   'collection_version_id': '9967e328-7f4c-49e3-8fb7-117c3bae2ccf',
#   'consortia': [],
#   'contact_email': 'rachel.zwick@ucsf.edu',
#   'contact_name': 'Rachel Zwick',
#   'created_at': '2024-10-07T16:30:20+00:00',
#   'curator_name': 'James Chaffer',
#   'datasets': [{'assay': [{'label': "10x 3' v3",
#       'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': 'b6ee0939-b5b9-4e03-9d69-96fb6bf5d434',
#     'dataset_version_id': '7cbffa61-2731-4f23-aa12-7afe15ab2b9d',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'small intestine',
#       'ontology_term_id': 'UBERON:0002108',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': 'a5ab6cde-46d4-4667-9b32-cfce54fa7a4e',
#     'dataset_version_id': 'a79b5f8f-3d56-4543-b775-e4127a0ecf64',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Mus musculus',
#       'ontology_term_id': 'NCBITaxon:10090'}],
#     'suspension_type': ['cell'],
#     'tissue': [{'label': 'small intestine',
#       'ontology_term_id': 'UBERON:0002108',
#       'tissue_type': 'tissue'}]}],
#   'description': 'Sorted epithelial cells (CD45–, EpCAM+) and a crypt cell-enriched population (CD45–, Ep-CAM+, CD44+ and in mouse, Lgr5-DTR-GFP+) were collected from 30 equal segments across the full length of the mouse or human small intestine, barcoded using MULTIseq technology, pooled, and sequenced. For detailed methods, see Zwick et al., 2023.',
#   'doi': '10.1038/s41556-023-01337-z',
#   'links': [{'link_name': 'GSE201859',
#     'link_type': 'RAW_DATA',
#     'link_url': 'https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE201859'}],
#   'name': 'Epithelial zonation along the mammalian small intestine defines five discrete metabolic domains',
#   'published_at': '2024-07-23T18:44:52+00:00',
#   'publisher_metadata': {'authors': [{'family': 'Zwick', 'given': 'Rachel K.'},
#     {'family': 'Kasparek', 'given': 'Petr'},
#     {'family': 'Palikuqi', 'given': 'Brisa'},
#     {'family': 'Viragova', 'given': 'Sara'},
#     {'family': 'Weichselbaum', 'given': 'Laura'},
#     {'family': 'McGinnis', 'given': 'Christopher S.'},
#     {'family': 'McKinley', 'given': 'Kara L.'},
#     {'family': 'Rathnayake', 'given': 'Asoka'},
#     {'family': 'Vaka', 'given': 'Dedeepya'},
#     {'family': 'Nguyen', 'given': 'Vinh'},
#     {'family': 'Trentesaux', 'given': 'Coralie'},
#     {'family': 'Reyes', 'given': 'Efren'},
#     {'family': 'Gupta', 'given': 'Alexander R.'},
#     {'family': 'Gartner', 'given': 'Zev J.'},
#     {'family': 'Locksley', 'given': 'Richard M.'},
#     {'family': 'Gardner', 'given': 'James M.'},
#     {'family': 'Itzkovitz', 'given': 'Shalev'},
#     {'family': 'Boffelli', 'given': 'Dario'},
#     {'family': 'Klein', 'given': 'Ophir D.'}],
#    'is_preprint': False,
#    'journal': 'Nat Cell Biol',
#    'published_at': 1706745600.0,
#    'published_day': 1,
#    'published_month': 2,
#    'published_year': 2024},
#   'revised_at': '2024-10-10T20:24:54+00:00',
#   'revising_in': None,
#   'revision_of': None,
#   'visibility': 'PUBLIC'},
#  {'collection_id': '9d63fcf1-5ca0-4006-8d8f-872f3327dbe9',
#   'collection_url': 'https://cellxgene.cziscience.com/collections/9d63fcf1-5ca0-4006-8d8f-872f3327dbe9',
#   'collection_version_id': '6088eca1-6768-4c40-8eca-0f9b1530caf9',
#   'consortia': ['CZI Cell Science'],
#   'contact_email': 'anna.williams@ed.ac.uk',
#   'contact_name': 'Anna Williams',
#   'created_at': '2024-10-07T16:34:57+00:00',
#   'curator_name': 'Jennifer Yu-Sheng Chien',
#   'datasets': [{'assay': [{'label': "10x 3' v3",
#       'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': 'c8f83821-a242-4ed7-86e9-7da077f5d348',
#     'dataset_version_id': 'e84faa2f-4634-4d99-825e-66d15c08471e',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'Brodmann (1909) area 4',
#       'ontology_term_id': 'UBERON:0013535',
#       'tissue_type': 'tissue'},
#      {'label': 'cervical spinal cord white matter',
#       'ontology_term_id': 'UBERON:0014614',
#       'tissue_type': 'tissue'},
#      {'label': 'white matter of cerebellum',
#       'ontology_term_id': 'UBERON:0002317',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': 'c05e6940-729c-47bd-a2a6-6ce3730c4919',
#     'dataset_version_id': '4bb40321-d632-474d-805d-6b665b70a7cf',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'Brodmann (1909) area 4',
#       'ontology_term_id': 'UBERON:0013535',
#       'tissue_type': 'tissue'},
#      {'label': 'cervical spinal cord white matter',
#       'ontology_term_id': 'UBERON:0014614',
#       'tissue_type': 'tissue'},
#      {'label': 'white matter of cerebellum',
#       'ontology_term_id': 'UBERON:0002317',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': '894573ad-498f-47ee-9bec-ad0880147eea',
#     'dataset_version_id': '6541645b-ae7c-4b12-beb9-2968fd833800',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'Brodmann (1909) area 4',
#       'ontology_term_id': 'UBERON:0013535',
#       'tissue_type': 'tissue'},
#      {'label': 'cervical spinal cord white matter',
#       'ontology_term_id': 'UBERON:0014614',
#       'tissue_type': 'tissue'},
#      {'label': 'white matter of cerebellum',
#       'ontology_term_id': 'UBERON:0002317',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': '84242d25-f656-4ca6-8e8d-f3d2beeba11f',
#     'dataset_version_id': 'e1c58b0c-59a2-432a-874b-3cdc433489db',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'Brodmann (1909) area 4',
#       'ontology_term_id': 'UBERON:0013535',
#       'tissue_type': 'tissue'},
#      {'label': 'cervical spinal cord white matter',
#       'ontology_term_id': 'UBERON:0014614',
#       'tissue_type': 'tissue'},
#      {'label': 'white matter of cerebellum',
#       'ontology_term_id': 'UBERON:0002317',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': '3d044b52-140a-4528-bf0d-a2dbef9e1f40',
#     'dataset_version_id': 'c073e947-24b2-4c10-b540-86aed211c169',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'Brodmann (1909) area 4',
#       'ontology_term_id': 'UBERON:0013535',
#       'tissue_type': 'tissue'},
#      {'label': 'cervical spinal cord white matter',
#       'ontology_term_id': 'UBERON:0014614',
#       'tissue_type': 'tissue'},
#      {'label': 'white matter of cerebellum',
#       'ontology_term_id': 'UBERON:0002317',
#       'tissue_type': 'tissue'}]},
#    {'assay': [{'label': "10x 3' v3", 'ontology_term_id': 'EFO:0009922'}],
#     'dataset_id': '12194ced-8086-458e-84a8-e2ab935d8db1',
#     'dataset_version_id': '9a34ed7d-7f82-463b-8e5b-75cc575b0203',
#     'disease': [{'label': 'normal', 'ontology_term_id': 'PATO:0000461'}],
#     'organism': [{'label': 'Homo sapiens',
#       'ontology_term_id': 'NCBITaxon:9606'}],
#     'suspension_type': ['nucleus'],
#     'tissue': [{'label': 'Brodmann (1909) area 4',
#       'ontology_term_id': 'UBERON:0013535',
#       'tissue_type': 'tissue'},
#      {'label': 'cervical spinal cord white matter',
#       'ontology_term_id': 'UBERON:0014614',
#       'tissue_type': 'tissue'},
#      {'label': 'white matter of cerebellum',
#       'ontology_term_id': 'UBERON:0002317',
#       'tissue_type': 'tissue'}]}],
#   'description': 'The myelinated white matter tracts of the central nervous system (CNS) are essential for fast transmission of electrical impulses and are often differentially affected in human neurodegenerative diseases across CNS region, age and sex. We hypothesize that this selective vulnerability is underpinned by physiological variation in white matter glia. Using single nucleus RNA sequencing of human post-mortem white matter samples from the brain, cerebellum and spinal cord and subsequent tissue-based validation we found substantial glial heterogeneity with tissue region: we identified region-specific oligodendrocyte precursor cells (OPCs) that retain developmental origin markers into adulthood, distinguishing them from mouse OPCs. Region-specific OPCs give rise to similar oligodendrocyte populations, however spinal cord oligodendrocytes exhibit markers such as SKAP2 which are associated with increased myelin production and we found a spinal cord selective population particularly equipped for producing long and thick myelin sheaths based on the expression of genes/proteins such as HCN2. Spinal cord microglia exhibit a more activated phenotype compared to brain microglia, suggesting that the spinal cord is a more pro-inflammatory environment, a difference that intensifies with age. Astrocyte gene expression correlates strongly with CNS region, however, astrocytes do not show a more activated state with region or age. Across all glia, sex differences are subtle but the consistent increased expression of protein-folding genes in male donors hints at pathways that may contribute to sex differences in disease susceptibility. These findings are essential to consider for understanding selective CNS pathologies and developing tailored therapeutic strategies.',
#   'doi': '10.1186/s40478-023-01568-z',
#   'links': [{'link_name': '',
#     'link_type': 'OTHER',
#     'link_url': 'https://seeker-science.shinyapps.io/shiny_app_multi/'},
#    {'link_name': '',
#     'link_type': 'OTHER',
#     'link_url': 'https://github.com/Anna-Williams/Luise_Seeker_Human_WM_Glia'},
#    {'link_name': '',
#     'link_type': 'RAW_DATA',
#     'link_url': 'https://explore.data.humancellatlas.org/projects/73011a86-4755-48ac-9f70-a28903b4ad77'}],
#   'name': 'Brain matters: Unveiling the Distinct Contributions of Region, Age, and Sex to Glia diversity and CNS Function',
#   'published_at': '2023-06-14T17:42:10+00:00',
#   'publisher_metadata': {'authors': [{'family': 'Seeker', 'given': 'Luise A.'},
#     {'family': 'Bestard-Cuche', 'given': 'Nadine'},
#     {'family': 'Jäkel', 'given': 'Sarah'},
#     {'family': 'Kazakou', 'given': 'Nina-Lydia'},
#     {'family': 'Bøstrand', 'given': 'Sunniva M. K.'},
#     {'family': 'Wagstaff', 'given': 'Laura J.'},
#     {'family': 'Cholewa-Waclaw', 'given': 'Justyna'},
#     {'family': 'Kilpatrick', 'given': 'Alastair M.'},
#     {'family': 'Van Bruggen', 'given': 'David'},
#     {'family': 'Kabbe', 'given': 'Mukund'},
#     {'family': 'Baldivia Pohl', 'given': 'Fabio'},
#     {'family': 'Moslehi', 'given': 'Zahra'},
#     {'family': 'Henderson', 'given': 'Neil C.'},
#     {'family': 'Vallejos', 'given': 'Catalina A.'},
#     {'family': 'La Manno', 'given': 'Gioele'},
#     {'family': 'Castelo-Branco', 'given': 'Goncalo'},
#     {'family': 'Williams', 'given': 'Anna'}],
#    'is_preprint': False,
#    'journal': 'acta neuropathol commun',
#    'published_at': 1684713600.0,
#    'published_day': 22,
#    'published_month': 5,
#    'published_year': 2023},
#   'revised_at': '2024-10-10T20:24:55+00:00',
#   'revising_in': None,
#   'revision_of': None,
#   'visibility': 'PUBLIC'}]

# %%
from datetime import datetime

for census_collection in census_collections:
    if not census_collection:
        continue
    
    # Use the top-level published_at if publisher_metadata is None
    published_at = None
    if census_collection.get('published_at'):
        try:
            published_at = datetime.fromisoformat(census_collection['published_at'].replace('Z', '+00:00'))
        except (ValueError, TypeError):
            pass
    elif census_collection.get('publisher_metadata') and census_collection['publisher_metadata'].get('published_at'):
        try:
            published_at = datetime.fromtimestamp(census_collection['publisher_metadata']['published_at'])
        except (ValueError, TypeError):
            pass
    
    authors = None
    if census_collection.get('publisher_metadata') and census_collection['publisher_metadata'].get('authors'):
        authors = [
            f"{author.get('given', '')} {author.get('family', '')}".strip()
            for author in census_collection['publisher_metadata']['authors']
        ]
    
    reference = fr.Reference(
        name=census_collection.get('name'),
        url=census_collection.get('collection_url'),
        doi=census_collection.get('doi'),
        description=census_collection.get('description'),
        authors=authors,
        published_at=published_at
    ).save()
    
    id = census_collection.get('collection_id')
    registered_collection = ln.Collection.filter(reference=id, is_latest=True).one_or_none()
    if registered_collection:
        registered_collection.references.set(reference)

# %%
ln.finish()
