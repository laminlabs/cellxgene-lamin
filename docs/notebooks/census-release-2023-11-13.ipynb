# %% [markdown]
# # Register files from Census release 2023-11-13

# %%
import lamindb as ln
import lnschema_bionty as lb
# Out:
# 2023-11-22 14:45:12,929:INFO - NumExpr defaulting to 2 threads.
# 💡 lamindb instance: theislab/nicheformer

# %%
census_version = "2023-11-13"

# %%
s3path = f"s3://cellxgene-data-public/cell-census/{census_version}/h5ads"
ln.UPath(s3path).view_tree()
# Out:
# h5ads (0 sub-directories & 1122 files with suffixes '.h5ad'):
# ├── 00099d5e-154f-4a7a-aa8d-fa30c8c0c43c.h5ad
# ├── 0041b9c3-6a49-4bf7-8514-9bc7190067a7.h5ad
# ├── 00476f9f-ebc1-4b72-b541-32f912ce36ea.h5ad
# ├── 00e5dedd-b9b7-43be-8c28-b0e5c6414a62.h5ad
# ├── 00ff600e-6e2e-4d76-846f-0eec4f0ae417.h5ad
# ├── 01209dce-3575-4bed-b1df-129f57fbc031.h5ad
# ...

# %%
ln.context.track()
# Out:
# 💡 notebook imports: lamindb==0.61.0 lnschema_bionty==0.34.0 requests==2.31.0
# 💡 loaded: Transform(uid='4hbVFAINneXCz8', name='Register files from Census release 2023-11-13', short_name='census-release-2023-11', version='0', type='notebook', updated_at=2023-11-20 21:25:20 UTC, created_by_id=1)
# 💡 loaded: Run(uid='6ZcVntFiofyv226ywRDL', run_at=2023-11-21 20:58:33 UTC, transform_id=18, created_by_id=1)

# %% [markdown]
# ## Register files

# %%
files = ln.File.from_dir(s3path)
ln.save(files)
# Out:
# ✅ created 1122 files from directory using storage s3://cellxgene-data-public and key = cell-census/2023-11-13/h5ads/

# %%
dataset = ln.Dataset(files, name="cellxgene-census", version=census_version)
dataset.save()
# Out:
# 💡 initializing versioning for this dataset! create future versions of it using ln.Dataset(..., is_new_version_of=old_dataset)

# %% [markdown]
# ## Register metadata

# %% [markdown]
# Get all datasets and associated metadata using cellxgene REST API:

# %%
import requests


def get_datasets_df_from_cxg():
    api_url_base = "https://api.cellxgene.cziscience.com"
    datasets_path = "/curation/v1/datasets"
    datasets_url = f"{api_url_base}{datasets_path}"
    headers = {"Content-Type": "application/json"}
    res = requests.get(url=datasets_url, headers=headers)
    res.raise_for_status()
    res_content = res.json()
    return res_content

# %%
res_content = get_datasets_df_from_cxg()
len(res_content)
# Out:
# 1130

# %%
res_content[0].keys()
# Out:
# dict_keys(['assay', 'assets', 'cell_count', 'cell_type', 'collection_doi', 'collection_id', 'collection_name', 'collection_version_id', 'dataset_id', 'dataset_version_id', 'development_stage', 'disease', 'donor_id', 'explorer_url', 'is_primary_data', 'mean_genes_per_cell', 'organism', 'primary_cell_count', 'processing_status', 'published_at', 'revised_at', 'schema_version', 'self_reported_ethnicity', 'sex', 'suspension_type', 'tissue', 'title', 'tombstone', 'x_approximate_distribution'])

# %%
features = ln.Feature.lookup()
files = ln.File.filter(key__contains=census_version).all()

# %% [markdown]
# ### collections, organisms

# %%
is_collection = ln.ULabel.filter(name="is_collection").one()
collections = is_collection.children.all()
organisms = lb.Organism.filter().all()

for dataset_meta in res_content:
    file = files.filter(key__contains=dataset_meta["dataset_id"]).one_or_none()
    if file is None:
        continue
    # register collection
    collection = collections.filter(
        reference=dataset_meta["collection_id"]
    ).one_or_none()
    if collection is None:
        collection = ln.ULabel(
            name=dataset_meta["collection_name"],
            description=dataset_meta["collection_doi"],
            reference=dataset_meta["collection_id"],
            reference_type="collection_id",
        )
        collection.save()
        collection.parents.add(is_collection)
    file.labels.add(collection, feature=features.collection)

    # annotate with organism
    organism_ontology_ids = [i["ontology_term_id"] for i in dataset_meta["organism"]]
    organism_records = organisms.filter(ontology_id__in=organism_ontology_ids).list()
    # register new organisms
    if len(organism_records) == 0:
        bionty_source = lb.BiontySource.filter(entity="Organism", organism="all").one()
        for i in organism_ontology_ids:
            record = lb.Organism.from_bionty(ontology_id=i, bionty_source=bionty_source)
            record.save(parents=False)
            print(f"registered organism: {record}")
        organism_records = organisms.filter(
            ontology_id__in=organism_ontology_ids
        ).list()
    file.labels.add(organism_records, feature=features.organism)
# Out:
# ❗ loading non-default source inside a LaminDB instance
# registered organism: Organism(uid='sMq3BQz0', name='rhesus macaque', ontology_id='NCBITaxon:9544', scientific_name='Macaca mulatta', updated_at=2023-11-21 12:30:09 UTC, bionty_source_id=50, created_by_id=1)
# ❗ loading non-default source inside a LaminDB instance
# registered organism: Organism(uid='aYpsHRNc', name='white-tufted-ear marmoset', ontology_id='NCBITaxon:9483', scientific_name='Callithrix jacchus', updated_at=2023-11-21 12:30:18 UTC, bionty_source_id=50, created_by_id=1)
# ❗ loading non-default source inside a LaminDB instance
# registered organism: Organism(uid='Ihbc7tQx', name='chimpanzee', ontology_id='NCBITaxon:9598', scientific_name='Pan troglodytes', updated_at=2023-11-21 12:30:26 UTC, bionty_source_id=50, created_by_id=1)
# ❗ loading non-default source inside a LaminDB instance
# registered organism: Organism(uid='Z0wGZNxo', name='domestic pig', ontology_id='NCBITaxon:9825', scientific_name='Sus scrofa domesticus', updated_at=2023-11-21 12:34:31 UTC, bionty_source_id=50, created_by_id=1)

# %% [markdown]
# ### obs ontologies

# %%
feature_names = [
    "self_reported_ethnicity",
    "development_stage",
    "cell_type",
    "assay",
    "tissue",
    "disease",
    "sex",
    "donor_id",
    "suspension_type",
]

from lamindb.dev._feature_manager import get_accessor_by_orm

ACCESSORS = get_accessor_by_orm(ln.File)
FEATURE_TO_ACCESSOR = {}
for name in feature_names:
    feature = getattr(features, name)
    accessor = ACCESSORS.get(feature.registries)
    orm = getattr(ln.File, accessor).field.model
    # TODO: ulabels are defined in the File model, improve this in LaminDB
    if orm == ln.File:
        orm = getattr(ln.File, accessor).field.related_model
    FEATURE_TO_ACCESSOR[name] = (accessor, orm)

# %%
obs_featureset = ln.FeatureSet(features=[getattr(features, i) for i in feature_names])
obs_featureset.save()

obs_featureset.files.set(files, through_defaults={"slot": "obs"})

# %%
# extra step to register uberon ontologies as developmental stages
def create_dv_record_from_uberon(ontology_id: str):
    tissue_record = lb.Tissue.from_bionty(ontology_id=ontology_id)
    dvs_record = lb.DevelopmentalStage(
        name=tissue_record.name,
        description=tissue_record.description,
        ontology_id=tissue_record.ontology_id,
        bionty_source_id=tissue_record.bionty_source_id,
    )
    dvs_record.save()


for id in [
    "UBERON:0018241",
    "UBERON:0034919",
    "UBERON:0007222",
    "UBERON:0000113",
    "UBERON:0007220",
    "UBERON:0007222",
]:
    create_dv_record_from_uberon(id)

# %%
ontology_ids = {}
for name in feature_names:
    if name in ["donor_id", "suspension_type"]:
        continue
    allids = set()
    for i in res_content:
        if name in i:
            allids.update([(j["label"], j["ontology_term_id"]) for j in i[name]])

    ontology_ids[name] = allids

# register all ontology ids
for name, terms in ontology_ids.items():
    accessor, orm = FEATURE_TO_ACCESSOR.get(name)
    terms_ids = [i[1] for i in terms]
    records = orm.from_values(terms_ids, field="ontology_id")
    if len(records) > 0:
        ln.save(records)
# Out:
# ❗ now recursing through parents: this only happens once, but is much slower than bulk saving
# ❗ did not create DevelopmentalStage records for 19 non-validated ontology_ids: 'MmusDv:0000057', 'MmusDv:0000058', 'MmusDv:0000059', 'MmusDv:0000065', 'MmusDv:0000066', 'MmusDv:0000067', 'MmusDv:0000068', 'MmusDv:0000070', 'MmusDv:0000071', 'MmusDv:0000072', 'MmusDv:0000073', 'MmusDv:0000074', 'MmusDv:0000079', 'MmusDv:0000098', 'MmusDv:0000099', 'MmusDv:0000102', 'UBERON:0000113', 'UBERON:0007220', 'UBERON:0007222'
# ❗ now recursing through parents: this only happens once, but is much slower than bulk saving
# ❗ now recursing through parents: this only happens once, but is much slower than bulk saving
# ❗ did not create Tissue records for 18 non-validated ontology_ids: 'CL:0000010 (cell culture)', 'CL:0000082 (cell culture)', 'CL:0000084 (cell culture)', 'CL:0000115 (cell culture)', 'CL:0000351 (cell culture)', 'CL:0002322 (cell culture)', 'CL:0002327 (cell culture)', 'CL:0002328 (cell culture)', 'CL:0002334 (cell culture)', 'CL:0002335 (cell culture)', 'CL:0002633 (cell culture)', 'CL:0010003 (cell culture)', 'UBERON:0000088 (organoid)', 'UBERON:0000310 (organoid)', 'UBERON:0000966 (organoid)', 'UBERON:0001295 (organoid)', 'UBERON:0002048 (organoid)', 'UBERON:0002370 (organoid)'
# ❗ now recursing through parents: this only happens once, but is much slower than bulk saving
# ❗ now recursing through parents: this only happens once, but is much slower than bulk saving

# %%
# register the non-validated terms
bionty_source_ds_mouse = lb.BiontySource.filter(
    entity="DevelopmentalStage", organism="mouse"
).one()

for name, terms in ontology_ids.items():
    accessor, orm = FEATURE_TO_ACCESSOR.get(name)
    terms_ids = [i[1] for i in terms]
    result = orm.inspect(terms_ids, field="ontology_id")
    if len(result.non_validated) > 0:
        if name == "development_stage":
            dv_records = orm.from_values(
                result.non_validated,
                field="ontology_id",
                bionty_source=bionty_source_ds_mouse,
            )
        elif name == "tissue":
            ts_records = [
                orm(name=term[0], ontology_id=term[1])
                for term in terms
                if term[1] in result.non_validated
            ]

ln.save(dv_records)
ln.save(ts_records)
# Out:
# ❗ 16 terms (7.00%) are not validated for ontology_id: MmusDv:0000066, MmusDv:0000057, MmusDv:0000072, MmusDv:0000067, MmusDv:0000099, MmusDv:0000070, MmusDv:0000065, MmusDv:0000071, MmusDv:0000058, MmusDv:0000102, MmusDv:0000098, MmusDv:0000068, MmusDv:0000079, MmusDv:0000059, MmusDv:0000073, MmusDv:0000074
#    couldn't validate 16 terms: 'MmusDv:0000059', 'MmusDv:0000068', 'MmusDv:0000058', 'MmusDv:0000066', 'MmusDv:0000057', 'MmusDv:0000102', 'MmusDv:0000098', 'MmusDv:0000071', 'MmusDv:0000074', 'MmusDv:0000065', 'MmusDv:0000067', 'MmusDv:0000073', 'MmusDv:0000070', 'MmusDv:0000072', 'MmusDv:0000079', 'MmusDv:0000099'
# →  if you are sure, create new records via ln.DevelopmentalStage() and save to your registry
# ❗ 18 terms (4.80%) are not validated for ontology_id: UBERON:0001295 (organoid), UBERON:0002370 (organoid), CL:0002327 (cell culture), CL:0000115 (cell culture), CL:0000082 (cell culture), CL:0002334 (cell culture), CL:0002335 (cell culture), CL:0000010 (cell culture), CL:0002328 (cell culture), CL:0000084 (cell culture), CL:0010003 (cell culture), CL:0000351 (cell culture), CL:0002633 (cell culture), UBERON:0000310 (organoid), UBERON:0000088 (organoid), UBERON:0002048 (organoid), CL:0002322 (cell culture), UBERON:0000966 (organoid)
#    couldn't validate 18 terms: 'CL:0000115 (cell culture)', 'UBERON:0001295 (organoid)', 'UBERON:0002370 (organoid)', 'CL:0002327 (cell culture)', 'CL:0000082 (cell culture)', 'UBERON:0000310 (organoid)', 'UBERON:0000088 (organoid)', 'CL:0000084 (cell culture)', 'CL:0002334 (cell culture)', 'CL:0000010 (cell culture)', 'UBERON:0000966 (organoid)', 'CL:0000351 (cell culture)', 'CL:0002328 (cell culture)', 'CL:0002335 (cell culture)', 'CL:0002633 (cell culture)', 'UBERON:0002048 (organoid)', 'CL:0002322 (cell culture)', 'CL:0010003 (cell culture)'
# →  if you are sure, create new records via ln.Tissue() and save to your registry

# %% [markdown]
# ### donors and suspension types

# %%
donor_ids = set()
suspension_types = set()

for i in res_content:
    if "donor_id" in i:
        donor_ids.update(i["donor_id"])
    if "suspension_type" in i:
        suspension_types.update(i["suspension_type"])

# %%
donors = ln.ULabel.filter(name="is_donor").one().children.all()
result = donors.inspect(donor_ids)
new_donors = [ln.ULabel(name=name) for name in result.non_validated]
ln.save(new_donors)
is_donor = ln.ULabel.filter(name="is_donor").one()
is_donor.children.add(*new_donors)
# Out:
# ❗ 1216 terms (16.60%) are not validated for name: mouse_YUYDJ, COVID19_Participant12, COVID19_Participant3, 328806, 364368, Human-BRCA1-B, RL2105, COVID19_Participant6, 1864, mouse_LVGJZ, Control_Participant14, 424707, 291740, 377001, mouse_VBJMY, G19.32.002, mouse_EUEJJ, mouse_RZFCS, mouse003, HTA4_11, ...
#    couldn't validate 1216 terms: 'Control_Participant16', 'C19.32.004', 'mouse_YUYDJ', '14104', 'Williams_GSE164241_GSM5177040', '5976', 'H18.29.134', 'COVID19_Participant12', 'mouse_VTQGY', 'ac45', 'HTA11_99999974143_84620', '779', 'AH2', 'Kydar05', 'GW20-12-7-18', 'Human-WT-C', 'Q19.26.003', 'SPECTRUM-OV-031', '380739', '514', ...
# →  if you are sure, create new records via ln.ULabel() and save to your registry

# %%
stypes = ln.ULabel.filter(name="is_suspension_type").one().children.all()
result = stypes.inspect(suspension_types)
new_stypes = [ln.ULabel(name=name) for name in result.non_validated]
ln.save(new_stypes)
is_suspension_type = ln.ULabel.filter(name="is_suspension_type").one()
is_suspension_type.children.add(*new_stypes)
# Out:
# ❗ 1 term (33.30%) is not validated for name: na
#    couldn't validate 1 term: 'na'
# →  if you are sure, create new record via ln.ULabel() and save to your registry
# ❗ records with similar names exist! did you mean to load one of them?
#                   uid  score
# name
# nan          etXMfuAG   90.0
# mouse_NASMM  H1NNCpCh   90.0

# %% [markdown]
# ## Annotate files

# %%
for idx, dataset_meta in enumerate(res_content):
    if idx % 50 == 0:
        print(f"annotating dataset {idx} of {len(res_content)}")
    file = files.filter(key__contains=dataset_meta["dataset_id"]).one_or_none()
    if file is None:
        continue
    for field, terms in dataset_meta.items():
        if field not in FEATURE_TO_ACCESSOR:
            continue
        accessor, orm = FEATURE_TO_ACCESSOR.get(field)
        if field in ["donor_id", "suspension_type"]:
            records = orm.from_values(terms, field="name")
        else:
            records = orm.from_values(
                [i["ontology_term_id"] for i in terms], field="ontology_id"
            )
        if len(records) > 0:
            getattr(file, accessor).add(*records)
# Out:
# annotating dataset 0 of 1130
# annotating dataset 50 of 1130
# annotating dataset 100 of 1130
# annotating dataset 150 of 1130
# annotating dataset 200 of 1130
# annotating dataset 250 of 1130
# annotating dataset 300 of 1130
# annotating dataset 350 of 1130
# annotating dataset 400 of 1130
# annotating dataset 450 of 1130
# annotating dataset 500 of 1130
# annotating dataset 550 of 1130
# annotating dataset 600 of 1130
# annotating dataset 650 of 1130
# annotating dataset 700 of 1130
# annotating dataset 750 of 1130
# annotating dataset 800 of 1130
# annotating dataset 850 of 1130
# annotating dataset 900 of 1130
# annotating dataset 950 of 1130
# annotating dataset 1000 of 1130
# annotating dataset 1050 of 1130
# annotating dataset 1100 of 1130

# %%
files.last().describe()
# Out:
# File(uid='aEKsguSJF6kAoeXcICKt', key='cell-census/2023-11-13/h5ads/ff7d15fa-f4b6-4a0e-992e-fd0c9d088ded.h5ad', suffix='.h5ad', accessor='AnnData', size=339098252, hash='wk4aVyHI7iZWNq2n99_s4w-41', hash_type='md5-n', visibility=0, key_is_virtual=False, updated_at=2023-11-20 21:45:35 UTC)
#
# Provenance:
#   🗃️ storage: Storage(uid='oIYGbD74', root='s3://cellxgene-data-public', type='s3', region='us-west-2', updated_at=2023-10-16 15:04:08 UTC, created_by_id=1)
#   📔 transform: Transform(uid='4hbVFAINneXCz8', name='Register files from Census release 2023-11-13', short_name='census-release-2023-11', version='0', type='notebook', updated_at=2023-11-20 21:25:20 UTC, created_by_id=1)
#   👣 run: Run(uid='6ZcVntFiofyv226ywRDL', run_at=2023-11-21 19:43:44 UTC, transform_id=18, created_by_id=1)
#   👤 created_by: User(uid='kmvZDIX9', handle='sunnyosun', name='Sunny Sun', updated_at=2023-11-21 09:23:50 UTC)
# Features:
#   external: FeatureSet(uid='qgAXuV6LwRitejVy0ZY9', n=2, registry='core.Feature', hash='NspE1QMvOo8aoOOrotmH', updated_at=2023-11-21 14:17:10 UTC, created_by_id=1)
#     🔗 collection (1, core.ULabel): 'Transcriptomic diversity of cell types across the adult human brain'
#     🔗 organism (1, bionty.Organism): 'human'
#   obs: FeatureSet(uid='vcl397zxUZfT8HO0H8WW', n=9, registry='core.Feature', hash='VgsTm88KGwJjDoC7cCJP', updated_at=2023-11-21 14:32:26 UTC, created_by_id=1)
#     🔗 donor_id (0, core.ULabel):
#     🔗 development_stage (3, bionty.DevelopmentalStage): '42-year-old human stage', '50-year-old human stage', '29-year-old human stage'
#     🔗 disease (1, bionty.Disease): 'normal'
#     🔗 cell_type (10, bionty.CellType): 'endothelial cell', 'astrocyte', 'vascular associated smooth muscle cell', 'oligodendrocyte precursor cell', 'central nervous system macrophage', 'neuron', 'leukocyte', 'fibroblast', 'oligodendrocyte', 'pericyte'
#     🔗 sex (1, bionty.Phenotype): 'male'
#     🔗 suspension_type (0, core.ULabel):
#     🔗 assay (1, bionty.ExperimentalFactor): '10x 3' v3'
#     🔗 tissue (1, bionty.Tissue): 'cerebral cortex'
#     🔗 self_reported_ethnicity (1, bionty.Ethnicity): 'European'
# Labels:
#   🏷️ organism (1, bionty.Organism): 'human'
#   🏷️ tissues (1, bionty.Tissue): 'cerebral cortex'
#   🏷️ cell_types (10, bionty.CellType): 'endothelial cell', 'astrocyte', 'vascular associated smooth muscle cell', 'oligodendrocyte precursor cell', 'central nervous system macrophage', 'neuron', 'leukocyte', 'fibroblast', 'oligodendrocyte', 'pericyte'
#   🏷️ diseases (1, bionty.Disease): 'normal'
#   🏷️ phenotypes (1, bionty.Phenotype): 'male'
#   🏷️ experimental_factors (1, bionty.ExperimentalFactor): '10x 3' v3'
#   🏷️ developmental_stages (3, bionty.DevelopmentalStage): '42-year-old human stage', '50-year-old human stage', '29-year-old human stage'
#   🏷️ ethnicities (1, bionty.Ethnicity): 'European'
#   🏷️ ulabels (5, core.ULabel): 'Transcriptomic diversity of cell types across the adult human brain', 'nucleus', 'H19.30.001', 'H19.30.002', 'H18.30.002'

# %% [markdown]
# ## Register genes

# %%
ln.settings.track_run_inputs = False
ln.settings.verbosity = "hint"

for idx, file in enumerate(files):
    if idx % 50 == 0:
        print(f"annotating file {idx} of {len(files)}")
    adata_backed = file.backed()
    genes = adata_backed.var_names
    organism = file.organism.first()
    featureset = ln.FeatureSet.from_values(
        genes, field=lb.Gene.ensembl_gene_id, organism=organism
    )
    # skips non-human datasets
    if featureset is None:
        continue
    if featureset._state.adding:
        featureset.save()
    # not sure why some feature sets are not linked with any genes
    if featureset.genes.count() == 0:
        records = lb.Gene.from_values(
            genes, field=lb.Gene.ensembl_gene_id, organism=organism
        )
        featureset.genes.set(records)
    file.feature_sets.add(featureset, through_defaults={"slot": "var"})
# Out:
# ❗ 19149 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000162063, ENSG00000162062, ENSG00000198951, ENSG00000163121, ENSG00000105829, ENSG00000081237, ENSG00000134153, ENSG00000134152, ENSG00000173728, ENSG00000035687, ENSG00000166961, ENSG00000172689, ENSG00000110104, ENSG00000179397, ENSG00000149506, ENSG00000125384, ENSG00000168229, ENSG00000183579, ENSG00000166548, ENSG00000181234, ...
# ❗ no validated features, skip creating feature set
# ✅ 22266 terms (100.00%) are validated for ensembl_gene_id
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 33178 terms (100.00%) are validated for ensembl_gene_id
# ✅ 32922 terms (100.00%) are validated for ensembl_gene_id
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 60452 terms (100.00%) are validated for ensembl_gene_id
# ✅ 24955 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='xpgLEUSLwoBGeHZTm3CL', n=24955, type='number', registry='bionty.Gene', hash='1TdsTtZ2WdJ7ryn4WE-G', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# ✅ 14490 terms (100.00%) are validated for ensembl_gene_id
# ✅ 21069 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='h5zXy3sgNPhC4e5XnGn7', n=21069, type='number', registry='bionty.Gene', hash='_QtYgk-zv9vjZLYdBK0L', updated_at=2023-11-21 21:56:18 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 28024 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='kjilFgEj51Um0eGhUkH3', n=28024, type='number', registry='bionty.Gene', hash='tGAam8xHur6MbQMO_2k7', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# ✅ 32826 terms (100.00%) are validated for ensembl_gene_id
# ✅ 25307 terms (100.00%) are validated for ensembl_gene_id
# ✅ 23665 terms (100.00%) are validated for ensembl_gene_id
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 34088 terms (100.00%) are validated for ensembl_gene_id
# ✅ 33178 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OlWHGbkWHKc8jXUHwVyh', n=33178, type='number', registry='bionty.Gene', hash='-hMSKsSk7e6TWgbcRxOk', updated_at=2023-11-21 22:10:16 UTC, created_by_id=1)
# ✅ 29466 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 30246 terms (100.00%) are validated for ensembl_gene_id
# annotating file 50 of 1122
# ✅ 27381 terms (100.00%) are validated for ensembl_gene_id
# ✅ 32922 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='FHatdv1Q2B7z46VpkDWo', n=32922, type='number', registry='bionty.Gene', hash='fHMWMViqV_PilN1PWrgF', updated_at=2023-11-21 22:11:11 UTC, created_by_id=1)
# ✅ 33452 terms (100.00%) are validated for ensembl_gene_id
# ✅ 15585 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ❗ 13155 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000121410, ENSG00000175899, ENSG00000166535, ENSG00000184389, ENSG00000128274, ENSG00000081760, ENSG00000188984, ENSG00000109576, ENSG00000103591, ENSG00000115977, ENSG00000087884, ENSG00000127837, ENSG00000129673, ENSG00000131043, ENSG00000090861, ENSG00000124608, ENSG00000157426, ENSG00000149313, ENSG00000008311, ENSG00000275700, ...
# ❗ no validated features, skip creating feature set
# ✅ 20984 terms (100.00%) are validated for ensembl_gene_id
# ✅ 32922 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='FHatdv1Q2B7z46VpkDWo', n=32922, type='number', registry='bionty.Gene', hash='fHMWMViqV_PilN1PWrgF', updated_at=2023-11-21 22:11:11 UTC, created_by_id=1)
# ❗ 13623 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000121410, ENSG00000148584, ENSG00000175899, ENSG00000166535, ENSG00000184389, ENSG00000128274, ENSG00000118017, ENSG00000081760, ENSG00000188984, ENSG00000109576, ENSG00000103591, ENSG00000115977, ENSG00000087884, ENSG00000127837, ENSG00000129673, ENSG00000131043, ENSG00000205002, ENSG00000090861, ENSG00000124608, ENSG00000157426, ...
# ❗ no validated features, skip creating feature set
# ❗ 12591 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000121410, ENSG00000148584, ENSG00000175899, ENSG00000166535, ENSG00000184389, ENSG00000128274, ENSG00000081760, ENSG00000188984, ENSG00000109576, ENSG00000103591, ENSG00000115977, ENSG00000087884, ENSG00000127837, ENSG00000129673, ENSG00000131043, ENSG00000205002, ENSG00000090861, ENSG00000124608, ENSG00000157426, ENSG00000149313, ...
# ❗ no validated features, skip creating feature set
# ✅ 26208 terms (100.00%) are validated for ensembl_gene_id
# ✅ 37073 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Mu48sCr7VgAThln5ANk8', n=37073, type='number', registry='bionty.Gene', hash='ECYkXOpgXsv1QPfumHl0', updated_at=2023-11-21 21:57:07 UTC, created_by_id=1)
# ✅ 33920 terms (100.00%) are validated for ensembl_gene_id
# ✅ 20014 terms (100.00%) are validated for ensembl_gene_id
# ✅ 34535 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='wh4GSTGSqxyNRxEEWjU8', n=34535, type='number', registry='bionty.Gene', hash='CiI1ztvUmMadsLol_xT0', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# ✅ 17985 terms (100.00%) are validated for ensembl_gene_id
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 19802 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Gt1rRaIq2DHjaSaqDFEh', n=19802, type='number', registry='bionty.Gene', hash='qxRBOg1jtdUlQtvEOCEv', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# ✅ 58604 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Ty21QMRd4NK3ne5H4GQ6', n=58604, type='number', registry='bionty.Gene', hash='PYHHJaMHHiM5sl5vPQbu', updated_at=2023-11-21 21:37:13 UTC, created_by_id=1)
# ✅ 26442 terms (100.00%) are validated for ensembl_gene_id
# ✅ 58604 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Ty21QMRd4NK3ne5H4GQ6', n=58604, type='number', registry='bionty.Gene', hash='PYHHJaMHHiM5sl5vPQbu', updated_at=2023-11-21 21:37:13 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 27574 terms (100.00%) are validated for ensembl_gene_id
# ✅ 22708 terms (100.00%) are validated for ensembl_gene_id
# ✅ 17985 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='0DyJDQnabVBMdor4EG8H', n=17985, type='number', registry='bionty.Gene', hash='lJvSNmM20SeKltfyz_sD', updated_at=2023-11-21 22:26:34 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 16443 terms (100.00%) are validated for ensembl_gene_id
# ✅ 33178 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OlWHGbkWHKc8jXUHwVyh', n=33178, type='number', registry='bionty.Gene', hash='-hMSKsSk7e6TWgbcRxOk', updated_at=2023-11-21 22:10:16 UTC, created_by_id=1)
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 13471 terms (100.00%) are validated for ensembl_gene_id
# ✅ 32828 terms (100.00%) are validated for ensembl_gene_id
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 20165 terms (100.00%) are validated for ensembl_gene_id
# ✅ 55773 terms (100.00%) are validated for ensembl_gene_id
# ✅ 19318 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 60602 terms (100.00%) are validated for ensembl_gene_id
# ✅ 30933 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='02yFLZrZUigjExQu7uAf', n=30933, type='number', registry='bionty.Gene', hash='F0VA6nHNwej3Jpr6lr9x', updated_at=2023-11-21 21:39:33 UTC, created_by_id=1)
# ✅ 32922 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='FHatdv1Q2B7z46VpkDWo', n=32922, type='number', registry='bionty.Gene', hash='fHMWMViqV_PilN1PWrgF', updated_at=2023-11-21 22:11:11 UTC, created_by_id=1)
# ✅ 33784 terms (100.00%) are validated for ensembl_gene_id
# ✅ 30933 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='02yFLZrZUigjExQu7uAf', n=30933, type='number', registry='bionty.Gene', hash='F0VA6nHNwej3Jpr6lr9x', updated_at=2023-11-21 21:39:33 UTC, created_by_id=1)
# ✅ 6445 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='bqvOF6Epw4yVmtWtjRUl', n=6445, type='number', registry='bionty.Gene', hash='iAy-yxGMelXoOVhjGiKq', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# annotating file 100 of 1122
# ✅ 25701 terms (100.00%) are validated for ensembl_gene_id
# ✅ 35393 terms (100.00%) are validated for ensembl_gene_id
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 19537 terms (100.00%) are validated for ensembl_gene_id
# ✅ 32551 terms (100.00%) are validated for ensembl_gene_id
# ✅ 24314 terms (100.00%) are validated for ensembl_gene_id
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 32826 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Kt0Oveac9j2LMf4CYokT', n=32826, type='number', registry='bionty.Gene', hash='fT_U_wCR9F0pmCRqJYQH', updated_at=2023-11-21 22:14:54 UTC, created_by_id=1)
# ✅ 52126 terms (99.90%) are validated for ensembl_gene_id
# ❗ 43 terms (0.10%) are not validated for ensembl_gene_id: ENSMUSG00000064742, ENSMUSG00000105705, ENSMUSG00000117357, ENSMUSG00000110033, ENSMUSG00000086513, ENSMUSG00000118410, ENSMUSG00000103863, ENSMUSG00000110856, ENSMUSG00000117102, ENSMUSG00000098137, ENSMUSG00000101890, ENSMUSG00000080542, ENSMUSG00000081849, ENSMUSG00000118106, ENSMUSG00000094162, ENSMUSG00000103759, ENSMUSG00000118364, ENSMUSG00000111212, ENSMUSG00000083237, ENSMUSG00000115233, ...
# ✅ 23252 terms (100.00%) are validated for ensembl_gene_id
# ✅ 21069 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='h5zXy3sgNPhC4e5XnGn7', n=21069, type='number', registry='bionty.Gene', hash='_QtYgk-zv9vjZLYdBK0L', updated_at=2023-11-21 21:56:18 UTC, created_by_id=1)
# ✅ 36503 terms (100.00%) are validated for ensembl_gene_id
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 20285 terms (100.00%) are validated for ensembl_gene_id
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 28590 terms (100.00%) are validated for ensembl_gene_id
# ✅ 58604 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Ty21QMRd4NK3ne5H4GQ6', n=58604, type='number', registry='bionty.Gene', hash='PYHHJaMHHiM5sl5vPQbu', updated_at=2023-11-21 21:37:13 UTC, created_by_id=1)
# ✅ 31174 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ❗ 10782 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000148584, ENSG00000081760, ENSG00000188984, ENSG00000109576, ENSG00000103591, ENSG00000115977, ENSG00000087884, ENSG00000127837, ENSG00000131043, ENSG00000090861, ENSG00000124608, ENSG00000157426, ENSG00000149313, ENSG00000008311, ENSG00000275700, ENSG00000181409, ENSG00000183044, ENSG00000165029, ENSG00000144452, ENSG00000179869, ...
# ❗ no validated features, skip creating feature set
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 17985 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='0DyJDQnabVBMdor4EG8H', n=17985, type='number', registry='bionty.Gene', hash='lJvSNmM20SeKltfyz_sD', updated_at=2023-11-21 22:26:34 UTC, created_by_id=1)
# ✅ 15489 terms (100.00%) are validated for ensembl_gene_id
# ✅ 32922 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='FHatdv1Q2B7z46VpkDWo', n=32922, type='number', registry='bionty.Gene', hash='fHMWMViqV_PilN1PWrgF', updated_at=2023-11-21 22:11:11 UTC, created_by_id=1)
# ✅ 17663 terms (100.00%) are validated for ensembl_gene_id
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 36503 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='PMLQI5ey4MAAq7lquUri', n=36503, type='number', registry='bionty.Gene', hash='Qz3WvFmAl6z37baVC_39', updated_at=2023-11-21 22:43:12 UTC, created_by_id=1)
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 18284 terms (100.00%) are validated for ensembl_gene_id
# ✅ 14594 terms (100.00%) are validated for ensembl_gene_id
# ✅ 29046 terms (100.00%) are validated for ensembl_gene_id
# ✅ 58604 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Ty21QMRd4NK3ne5H4GQ6', n=58604, type='number', registry='bionty.Gene', hash='PYHHJaMHHiM5sl5vPQbu', updated_at=2023-11-21 21:37:13 UTC, created_by_id=1)
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 21069 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='h5zXy3sgNPhC4e5XnGn7', n=21069, type='number', registry='bionty.Gene', hash='_QtYgk-zv9vjZLYdBK0L', updated_at=2023-11-21 21:56:18 UTC, created_by_id=1)
# ✅ 19492 terms (100.00%) are validated for ensembl_gene_id
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 24185 terms (100.00%) are validated for ensembl_gene_id
# ✅ 17811 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='VUlC5DJigUHR7rtxL8ct', n=17811, type='number', registry='bionty.Gene', hash='qg-qLesP7GehOz8-bzuh', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# ✅ 21069 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='h5zXy3sgNPhC4e5XnGn7', n=21069, type='number', registry='bionty.Gene', hash='_QtYgk-zv9vjZLYdBK0L', updated_at=2023-11-21 21:56:18 UTC, created_by_id=1)
# ✅ 32922 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='FHatdv1Q2B7z46VpkDWo', n=32922, type='number', registry='bionty.Gene', hash='fHMWMViqV_PilN1PWrgF', updated_at=2023-11-21 22:11:11 UTC, created_by_id=1)
# ✅ 15257 terms (100.00%) are validated for ensembl_gene_id
# ✅ 17985 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='0DyJDQnabVBMdor4EG8H', n=17985, type='number', registry='bionty.Gene', hash='lJvSNmM20SeKltfyz_sD', updated_at=2023-11-21 22:26:34 UTC, created_by_id=1)
# ✅ 21084 terms (100.00%) are validated for ensembl_gene_id
# annotating file 150 of 1122
# ✅ 19492 terms (100.00%) are validated for ensembl_gene_id
# ❗ 13494 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000121410, ENSG00000148584, ENSG00000175899, ENSG00000166535, ENSG00000184389, ENSG00000128274, ENSG00000081760, ENSG00000188984, ENSG00000109576, ENSG00000103591, ENSG00000115977, ENSG00000087884, ENSG00000127837, ENSG00000129673, ENSG00000131043, ENSG00000090861, ENSG00000124608, ENSG00000157426, ENSG00000149313, ENSG00000008311, ...
# ❗ no validated features, skip creating feature set
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 32922 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='FHatdv1Q2B7z46VpkDWo', n=32922, type='number', registry='bionty.Gene', hash='fHMWMViqV_PilN1PWrgF', updated_at=2023-11-21 22:11:11 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ❗ 13293 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000121410, ENSG00000148584, ENSG00000175899, ENSG00000166535, ENSG00000184389, ENSG00000128274, ENSG00000081760, ENSG00000188984, ENSG00000109576, ENSG00000103591, ENSG00000115977, ENSG00000087884, ENSG00000127837, ENSG00000129673, ENSG00000131043, ENSG00000205002, ENSG00000090861, ENSG00000124608, ENSG00000157426, ENSG00000149313, ...
# ❗ no validated features, skip creating feature set
# ✅ 24185 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='JUOWgSxgtdPZYBjXdwzf', n=24185, type='number', registry='bionty.Gene', hash='iz83So9yidyTQAHISu_1', updated_at=2023-11-21 22:53:36 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 30933 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='02yFLZrZUigjExQu7uAf', n=30933, type='number', registry='bionty.Gene', hash='F0VA6nHNwej3Jpr6lr9x', updated_at=2023-11-21 21:39:33 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 30761 terms (100.00%) are validated for ensembl_gene_id
# ✅ 21562 terms (100.00%) are validated for ensembl_gene_id
# ✅ 13700 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ❗ 19149 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000162063, ENSG00000162062, ENSG00000198951, ENSG00000163121, ENSG00000105829, ENSG00000081237, ENSG00000134153, ENSG00000134152, ENSG00000173728, ENSG00000035687, ENSG00000166961, ENSG00000172689, ENSG00000110104, ENSG00000179397, ENSG00000149506, ENSG00000125384, ENSG00000168229, ENSG00000183579, ENSG00000166548, ENSG00000181234, ...
# ❗ no validated features, skip creating feature set
# ❗ 13996 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000121410, ENSG00000148584, ENSG00000175899, ENSG00000166535, ENSG00000184389, ENSG00000128274, ENSG00000118017, ENSG00000081760, ENSG00000188984, ENSG00000109576, ENSG00000103591, ENSG00000115977, ENSG00000087884, ENSG00000127837, ENSG00000129673, ENSG00000131043, ENSG00000205002, ENSG00000090861, ENSG00000124608, ENSG00000157426, ...
# ❗ no validated features, skip creating feature set
# ✅ 20727 terms (100.00%) are validated for ensembl_gene_id
# ✅ 17811 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='VUlC5DJigUHR7rtxL8ct', n=17811, type='number', registry='bionty.Gene', hash='qg-qLesP7GehOz8-bzuh', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 32826 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Kt0Oveac9j2LMf4CYokT', n=32826, type='number', registry='bionty.Gene', hash='fT_U_wCR9F0pmCRqJYQH', updated_at=2023-11-21 22:14:54 UTC, created_by_id=1)
# ✅ 58604 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Ty21QMRd4NK3ne5H4GQ6', n=58604, type='number', registry='bionty.Gene', hash='PYHHJaMHHiM5sl5vPQbu', updated_at=2023-11-21 21:37:13 UTC, created_by_id=1)
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 16819 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='r2170cGkSPafy1BsUlwU', n=16819, type='number', registry='bionty.Gene', hash='YyGUfvU0idw0AUGV18JT', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# ✅ 21069 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='h5zXy3sgNPhC4e5XnGn7', n=21069, type='number', registry='bionty.Gene', hash='_QtYgk-zv9vjZLYdBK0L', updated_at=2023-11-21 21:56:18 UTC, created_by_id=1)
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 34608 terms (100.00%) are validated for ensembl_gene_id
# ✅ 34088 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mflZCQvwWIOiTHvsxZTq', n=34088, type='number', registry='bionty.Gene', hash='te0yljuR-SFYFefIkU7a', updated_at=2023-11-21 22:17:16 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 254 terms (100.00%) are validated for ensembl_gene_id
# ✅ 24817 terms (100.00%) are validated for ensembl_gene_id
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 14872 terms (100.00%) are validated for ensembl_gene_id
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 32826 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Kt0Oveac9j2LMf4CYokT', n=32826, type='number', registry='bionty.Gene', hash='fT_U_wCR9F0pmCRqJYQH', updated_at=2023-11-21 22:14:54 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 34088 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mflZCQvwWIOiTHvsxZTq', n=34088, type='number', registry='bionty.Gene', hash='te0yljuR-SFYFefIkU7a', updated_at=2023-11-21 22:17:16 UTC, created_by_id=1)
# ✅ 20260 terms (100.00%) are validated for ensembl_gene_id
# ✅ 18835 terms (100.00%) are validated for ensembl_gene_id
# ✅ 25377 terms (100.00%) are validated for ensembl_gene_id
# ✅ 35308 terms (100.00%) are validated for ensembl_gene_id
# ✅ 28590 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='AouCJ8S0ZDePaDu3e315', n=28590, type='number', registry='bionty.Gene', hash='sMa8DZ7TI3Ar1mSAYKBj', updated_at=2023-11-21 22:45:32 UTC, created_by_id=1)
# ✅ 21693 terms (100.00%) are validated for ensembl_gene_id
# ✅ 20807 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='S7rkSBRjawW6uINMZjhC', n=20807, type='number', registry='bionty.Gene', hash='VeyDZnHCsAMTSEQyCdWh', updated_at=2023-11-21 21:56:53 UTC, created_by_id=1)
# ✅ 33193 terms (100.00%) are validated for ensembl_gene_id
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 26468 terms (100.00%) are validated for ensembl_gene_id
# ✅ 19492 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='wiXGIvAUwc5qRkhLMU8A', n=19492, type='number', registry='bionty.Gene', hash='wj29M0d2uJZsv0Lq4HkH', updated_at=2023-11-21 22:55:54 UTC, created_by_id=1)
# annotating file 200 of 1122
# ✅ 58604 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Ty21QMRd4NK3ne5H4GQ6', n=58604, type='number', registry='bionty.Gene', hash='PYHHJaMHHiM5sl5vPQbu', updated_at=2023-11-21 21:37:13 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 29813 terms (100.00%) are validated for ensembl_gene_id
# ✅ 32922 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='FHatdv1Q2B7z46VpkDWo', n=32922, type='number', registry='bionty.Gene', hash='fHMWMViqV_PilN1PWrgF', updated_at=2023-11-21 22:11:11 UTC, created_by_id=1)
# ✅ 36503 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='PMLQI5ey4MAAq7lquUri', n=36503, type='number', registry='bionty.Gene', hash='Qz3WvFmAl6z37baVC_39', updated_at=2023-11-21 22:43:12 UTC, created_by_id=1)
# ✅ 26555 terms (100.00%) are validated for ensembl_gene_id
# ✅ 16396 terms (100.00%) are validated for ensembl_gene_id
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 22118 terms (100.00%) are validated for ensembl_gene_id
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ❗ 15186 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000000005, ENSG00000000419, ENSG00000000457, ENSG00000000460, ENSG00000000938, ENSG00000001036, ENSG00000001084, ENSG00000001167, ENSG00000001461, ENSG00000001497, ENSG00000001561, ENSG00000001617, ENSG00000001626, ENSG00000001629, ENSG00000001631, ENSG00000002016, ENSG00000002549, ENSG00000002586, ENSG00000002587, ENSG00000002726, ...
# ❗ no validated features, skip creating feature set
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 30849 terms (100.00%) are validated for ensembl_gene_id
# ✅ 32870 terms (100.00%) are validated for ensembl_gene_id
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 19443 terms (100.00%) are validated for ensembl_gene_id
# ✅ 32922 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='FHatdv1Q2B7z46VpkDWo', n=32922, type='number', registry='bionty.Gene', hash='fHMWMViqV_PilN1PWrgF', updated_at=2023-11-21 22:11:11 UTC, created_by_id=1)
# ✅ 30761 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='pgqXdxZSvyVQIi5etfR7', n=30761, type='number', registry='bionty.Gene', hash='RqZPhK15GlUuaonOFEvz', updated_at=2023-11-21 23:00:28 UTC, created_by_id=1)
# ✅ 19826 terms (100.00%) are validated for ensembl_gene_id
# ✅ 36503 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='PMLQI5ey4MAAq7lquUri', n=36503, type='number', registry='bionty.Gene', hash='Qz3WvFmAl6z37baVC_39', updated_at=2023-11-21 22:43:12 UTC, created_by_id=1)
# ✅ 36503 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='PMLQI5ey4MAAq7lquUri', n=36503, type='number', registry='bionty.Gene', hash='Qz3WvFmAl6z37baVC_39', updated_at=2023-11-21 22:43:12 UTC, created_by_id=1)
# ❗ 11653 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000148584, ENSG00000166535, ENSG00000184389, ENSG00000128274, ENSG00000081760, ENSG00000188984, ENSG00000109576, ENSG00000103591, ENSG00000115977, ENSG00000087884, ENSG00000127837, ENSG00000129673, ENSG00000131043, ENSG00000090861, ENSG00000124608, ENSG00000157426, ENSG00000149313, ENSG00000008311, ENSG00000275700, ENSG00000181409, ...
# ❗ no validated features, skip creating feature set
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 21757 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 36484 terms (100.00%) are validated for ensembl_gene_id
# ✅ 17667 terms (100.00%) are validated for ensembl_gene_id
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 30933 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='02yFLZrZUigjExQu7uAf', n=30933, type='number', registry='bionty.Gene', hash='F0VA6nHNwej3Jpr6lr9x', updated_at=2023-11-21 21:39:33 UTC, created_by_id=1)
# ✅ 27305 terms (100.00%) are validated for ensembl_gene_id
# ✅ 29731 terms (100.00%) are validated for ensembl_gene_id
# ✅ 32922 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='FHatdv1Q2B7z46VpkDWo', n=32922, type='number', registry='bionty.Gene', hash='fHMWMViqV_PilN1PWrgF', updated_at=2023-11-21 22:11:11 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 60452 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='4tuMVGKEnnqIPYOSfAJR', n=60452, type='number', registry='bionty.Gene', hash='pj84bNMZGKWj4OjbUSMi', updated_at=2023-11-21 22:12:24 UTC, created_by_id=1)
# ✅ 40942 terms (99.70%) are validated for ensembl_gene_id
# ❗ 138 terms (0.30%) are not validated for ensembl_gene_id: ERCC-00170, ERCC-00092, ERCC-00042, ERCC-00062, ENSMUSG00000110856, ERCC-00130, ERCC-00044, ERCC-00136, ENSMUSG00000118570, ERCC-00164, ERCC-00079, ENSMUSG00000118535, ENSMUSG00000101890, ENSMUSG00000118534, ERCC-00054, ERCC-00076, ERCC-00137, ENSMUSG00000110849, ERCC-00168, ERCC-00163, ...
# ✅ 36503 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='PMLQI5ey4MAAq7lquUri', n=36503, type='number', registry='bionty.Gene', hash='Qz3WvFmAl6z37baVC_39', updated_at=2023-11-21 22:43:12 UTC, created_by_id=1)
# ✅ 52127 terms (99.90%) are validated for ensembl_gene_id
# ❗ 43 terms (0.10%) are not validated for ensembl_gene_id: ENSMUSG00000064742, ENSMUSG00000105705, ENSMUSG00000117357, ENSMUSG00000110033, ENSMUSG00000086513, ENSMUSG00000118410, ENSMUSG00000103863, ENSMUSG00000110856, ENSMUSG00000117102, ENSMUSG00000098137, ENSMUSG00000101890, ENSMUSG00000080542, ENSMUSG00000081849, ENSMUSG00000118106, ENSMUSG00000094162, ENSMUSG00000103759, ENSMUSG00000118364, ENSMUSG00000111212, ENSMUSG00000083237, ENSMUSG00000115233, ...
# ✅ 60452 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='4tuMVGKEnnqIPYOSfAJR', n=60452, type='number', registry='bionty.Gene', hash='pj84bNMZGKWj4OjbUSMi', updated_at=2023-11-21 22:12:24 UTC, created_by_id=1)
# ✅ 18841 terms (100.00%) are validated for ensembl_gene_id
# ✅ 21284 terms (100.00%) are validated for ensembl_gene_id
# ✅ 26376 terms (100.00%) are validated for ensembl_gene_id
# ✅ 20233 terms (100.00%) are validated for ensembl_gene_id
# ✅ 25090 terms (100.00%) are validated for ensembl_gene_id
# ✅ 22356 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 21475 terms (100.00%) are validated for ensembl_gene_id
# ✅ 30933 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='02yFLZrZUigjExQu7uAf', n=30933, type='number', registry='bionty.Gene', hash='F0VA6nHNwej3Jpr6lr9x', updated_at=2023-11-21 21:39:33 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ❗ 19149 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000162063, ENSG00000162062, ENSG00000198951, ENSG00000163121, ENSG00000105829, ENSG00000081237, ENSG00000134153, ENSG00000134152, ENSG00000173728, ENSG00000035687, ENSG00000166961, ENSG00000172689, ENSG00000110104, ENSG00000179397, ENSG00000149506, ENSG00000125384, ENSG00000168229, ENSG00000183579, ENSG00000166548, ENSG00000181234, ...
# ❗ no validated features, skip creating feature set
# annotating file 250 of 1122
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 23186 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 22068 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='lFvvvF3FR5Fmi5q3BU70', n=22068, type='number', registry='bionty.Gene', hash='RiIpuOEFaiJuyv8srNVI', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# ✅ 26163 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 57717 terms (100.00%) are validated for ensembl_gene_id
# ✅ 55773 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='1GHMcQugWEb9WTJGEFAM', n=55773, type='number', registry='bionty.Gene', hash='62CZ9Ptg_WBp92rkpc9I', updated_at=2023-11-21 22:34:18 UTC, created_by_id=1)
# ✅ 60452 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='4tuMVGKEnnqIPYOSfAJR', n=60452, type='number', registry='bionty.Gene', hash='pj84bNMZGKWj4OjbUSMi', updated_at=2023-11-21 22:12:24 UTC, created_by_id=1)
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 19604 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='gv5oPE16qB0hGXADbMSL', n=19604, type='number', registry='bionty.Gene', hash='dEm0IMiObKZSu-LE1A7f', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# ✅ 19298 terms (100.00%) are validated for ensembl_gene_id
# ✅ 21932 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 17912 terms (100.00%) are validated for ensembl_gene_id
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 33452 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='9bzCdt5D9wGH8a5ff3qi', n=33452, type='number', registry='bionty.Gene', hash='dTGkttqjqwUtRU49rx8B', updated_at=2023-11-21 22:20:36 UTC, created_by_id=1)
# ✅ 20993 terms (100.00%) are validated for ensembl_gene_id
# ✅ 22269 terms (100.00%) are validated for ensembl_gene_id
# ✅ 21271 terms (100.00%) are validated for ensembl_gene_id
# ❗ 19149 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000162063, ENSG00000162062, ENSG00000198951, ENSG00000163121, ENSG00000105829, ENSG00000081237, ENSG00000134153, ENSG00000134152, ENSG00000173728, ENSG00000035687, ENSG00000166961, ENSG00000172689, ENSG00000110104, ENSG00000179397, ENSG00000149506, ENSG00000125384, ENSG00000168229, ENSG00000183579, ENSG00000166548, ENSG00000181234, ...
# ❗ no validated features, skip creating feature set
# ✅ 33784 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='2VimIJarM0QwbTTFrsCd', n=33784, type='number', registry='bionty.Gene', hash='gz8fKgOJ5DqX22nDDgYO', updated_at=2023-11-21 22:37:12 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 26354 terms (100.00%) are validated for ensembl_gene_id
# ❗ 19149 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000162063, ENSG00000162062, ENSG00000198951, ENSG00000163121, ENSG00000105829, ENSG00000081237, ENSG00000134153, ENSG00000134152, ENSG00000173728, ENSG00000035687, ENSG00000166961, ENSG00000172689, ENSG00000110104, ENSG00000179397, ENSG00000149506, ENSG00000125384, ENSG00000168229, ENSG00000183579, ENSG00000166548, ENSG00000181234, ...
# ❗ no validated features, skip creating feature set
# ✅ 20929 terms (100.00%) are validated for ensembl_gene_id
# ✅ 26329 terms (100.00%) are validated for ensembl_gene_id
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 60452 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='4tuMVGKEnnqIPYOSfAJR', n=60452, type='number', registry='bionty.Gene', hash='pj84bNMZGKWj4OjbUSMi', updated_at=2023-11-21 22:12:24 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 21069 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='h5zXy3sgNPhC4e5XnGn7', n=21069, type='number', registry='bionty.Gene', hash='_QtYgk-zv9vjZLYdBK0L', updated_at=2023-11-21 21:56:18 UTC, created_by_id=1)
# ...
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 17985 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='0DyJDQnabVBMdor4EG8H', n=17985, type='number', registry='bionty.Gene', hash='lJvSNmM20SeKltfyz_sD', updated_at=2023-11-21 22:26:34 UTC, created_by_id=1)
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 58604 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Ty21QMRd4NK3ne5H4GQ6', n=58604, type='number', registry='bionty.Gene', hash='PYHHJaMHHiM5sl5vPQbu', updated_at=2023-11-21 21:37:13 UTC, created_by_id=1)
# ✅ 60452 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='4tuMVGKEnnqIPYOSfAJR', n=60452, type='number', registry='bionty.Gene', hash='pj84bNMZGKWj4OjbUSMi', updated_at=2023-11-21 22:12:24 UTC, created_by_id=1)
# annotating file 1050 of 1122
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 20726 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='GoeZ3MH0mj6kEyFQh6nM', n=20726, type='number', registry='bionty.Gene', hash='n203tQOl550Gg5P09ZPc', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# ✅ 18025 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 28821 terms (100.00%) are validated for ensembl_gene_id
# ✅ 30933 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='02yFLZrZUigjExQu7uAf', n=30933, type='number', registry='bionty.Gene', hash='F0VA6nHNwej3Jpr6lr9x', updated_at=2023-11-21 21:39:33 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 23962 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 21213 terms (100.00%) are validated for ensembl_gene_id
# ✅ 25290 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 19605 terms (100.00%) are validated for ensembl_gene_id
# ✅ 19782 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='u2x6V7t565GjKAB7nkHq', n=19782, type='number', registry='bionty.Gene', hash='qJiwLqrt0Bq0GokJe1WZ', updated_at=2023-11-21 21:47:10 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 20981 terms (100.00%) are validated for ensembl_gene_id
# ✅ 34088 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mflZCQvwWIOiTHvsxZTq', n=34088, type='number', registry='bionty.Gene', hash='te0yljuR-SFYFefIkU7a', updated_at=2023-11-21 22:17:16 UTC, created_by_id=1)
# ❗ 19149 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000162063, ENSG00000162062, ENSG00000198951, ENSG00000163121, ENSG00000105829, ENSG00000081237, ENSG00000134153, ENSG00000134152, ENSG00000173728, ENSG00000035687, ENSG00000166961, ENSG00000172689, ENSG00000110104, ENSG00000179397, ENSG00000149506, ENSG00000125384, ENSG00000168229, ENSG00000183579, ENSG00000166548, ENSG00000181234, ...
# ❗ no validated features, skip creating feature set
# ✅ 25090 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='PzlspXXb4arl8g0IP3VV', n=25090, type='number', registry='bionty.Gene', hash='xNA2rYqSqmGbBl52fyOi', updated_at=2023-11-21 23:27:23 UTC, created_by_id=1)
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 21519 terms (100.00%) are validated for ensembl_gene_id
# ❗ 33138 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000121410, ENSG00000268895, ENSG00000148584, ENSG00000175899, ENSG00000245105, ENSG00000166535, ENSG00000256661, ENSG00000256904, ENSG00000256069, ENSG00000184389, ENSG00000128274, ENSG00000118017, ENSG00000265544, ENSG00000081760, ENSG00000250420, ENSG00000114771, ENSG00000188984, ENSG00000204518, ENSG00000240602, ENSG00000109576, ...
# ❗ no validated features, skip creating feature set
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 30666 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='9UVUf3E3wzmlymgQmJ2C', n=30666, type='number', registry='bionty.Gene', hash='fo9t7LfV6g-Z4CkV0QSl', updated_at=2023-11-22 00:06:49 UTC, created_by_id=1)
# ✅ 28024 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='kjilFgEj51Um0eGhUkH3', n=28024, type='number', registry='bionty.Gene', hash='tGAam8xHur6MbQMO_2k7', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# ✅ 33178 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OlWHGbkWHKc8jXUHwVyh', n=33178, type='number', registry='bionty.Gene', hash='-hMSKsSk7e6TWgbcRxOk', updated_at=2023-11-21 22:10:16 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 14736 terms (100.00%) are validated for ensembl_gene_id
# ✅ 46483 terms (100.00%) are validated for ensembl_gene_id
# ✅ 14078 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 32922 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='FHatdv1Q2B7z46VpkDWo', n=32922, type='number', registry='bionty.Gene', hash='fHMWMViqV_PilN1PWrgF', updated_at=2023-11-21 22:11:11 UTC, created_by_id=1)
# ✅ 32922 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='FHatdv1Q2B7z46VpkDWo', n=32922, type='number', registry='bionty.Gene', hash='fHMWMViqV_PilN1PWrgF', updated_at=2023-11-21 22:11:11 UTC, created_by_id=1)
# ✅ 57717 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='NuoTeNqUqOKihBakfWGX', n=57717, type='number', registry='bionty.Gene', hash='cy2F04y1GiVHFJQB9wLq', updated_at=2023-11-21 23:31:56 UTC, created_by_id=1)
# ✅ 34088 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mflZCQvwWIOiTHvsxZTq', n=34088, type='number', registry='bionty.Gene', hash='te0yljuR-SFYFefIkU7a', updated_at=2023-11-21 22:17:16 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 23747 terms (100.00%) are validated for ensembl_gene_id
# ❗ 12004 terms (100.00%) are not validated for ensembl_gene_id: ENSG00000166535, ENSG00000184389, ENSG00000128274, ENSG00000081760, ENSG00000188984, ENSG00000109576, ENSG00000103591, ENSG00000115977, ENSG00000087884, ENSG00000127837, ENSG00000129673, ENSG00000131043, ENSG00000090861, ENSG00000124608, ENSG00000157426, ENSG00000149313, ENSG00000008311, ENSG00000275700, ENSG00000181409, ENSG00000183044, ...
# ❗ no validated features, skip creating feature set
# ✅ 32826 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Kt0Oveac9j2LMf4CYokT', n=32826, type='number', registry='bionty.Gene', hash='fT_U_wCR9F0pmCRqJYQH', updated_at=2023-11-21 22:14:54 UTC, created_by_id=1)
# ✅ 19416 terms (100.00%) are validated for ensembl_gene_id
# ✅ 46483 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='8VOws0Y4MEqriVfP7hwC', n=46483, type='number', registry='bionty.Gene', hash='6wY58mLY56N2Xpq6E-JS', updated_at=2023-11-22 03:52:49 UTC, created_by_id=1)
# ✅ 40145 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='XJmfJjz5kPS4t3CHj9Av', n=40145, type='number', registry='bionty.Gene', hash='xLIzpUkK2Ilyrb7dnFrf', updated_at=2023-11-22 00:25:13 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 24004 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='xeMClF2adTtmhzq9wKb2', n=24004, type='number', registry='bionty.Gene', hash='6KhLSFI76_k47P0Xt_9H', updated_at=2023-10-16 15:04:09 UTC, created_by_id=1)
# annotating file 1100 of 1122
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 36503 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='PMLQI5ey4MAAq7lquUri', n=36503, type='number', registry='bionty.Gene', hash='Qz3WvFmAl6z37baVC_39', updated_at=2023-11-21 22:43:12 UTC, created_by_id=1)
# ✅ 20877 terms (100.00%) are validated for ensembl_gene_id
# ✅ 23887 terms (100.00%) are validated for ensembl_gene_id
# ✅ 18063 terms (100.00%) are validated for ensembl_gene_id
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 36517 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='vPiNCZcoKL01FgTSDe3P', n=36517, type='number', registry='bionty.Gene', hash='mGB6NJr_6EapeBdeuhGX', updated_at=2023-11-21 21:54:54 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 14918 terms (100.00%) are validated for ensembl_gene_id
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 33178 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OlWHGbkWHKc8jXUHwVyh', n=33178, type='number', registry='bionty.Gene', hash='-hMSKsSk7e6TWgbcRxOk', updated_at=2023-11-21 22:10:16 UTC, created_by_id=1)
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)
# ✅ 55773 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='1GHMcQugWEb9WTJGEFAM', n=55773, type='number', registry='bionty.Gene', hash='62CZ9Ptg_WBp92rkpc9I', updated_at=2023-11-21 22:34:18 UTC, created_by_id=1)
# ✅ 27574 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='JkYVEVGkeoxrlPFImQjW', n=27574, type='number', registry='bionty.Gene', hash='KtmJfeODox5h3OCrtogF', updated_at=2023-11-21 22:29:35 UTC, created_by_id=1)
# ✅ 36503 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='PMLQI5ey4MAAq7lquUri', n=36503, type='number', registry='bionty.Gene', hash='Qz3WvFmAl6z37baVC_39', updated_at=2023-11-21 22:43:12 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 27647 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='OkZda7t3F71aMGrM8QJQ', n=27647, type='number', registry='bionty.Gene', hash='o5V4YzFAEcBgZgPnNXPw', updated_at=2023-11-21 21:51:57 UTC, created_by_id=1)
# ✅ 33234 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='scbiqEmIlbbqMbh8rVkX', n=33234, type='number', registry='bionty.Gene', hash='gR384waDKLteDyGkj59I', updated_at=2023-11-21 21:51:08 UTC, created_by_id=1)
# ✅ 58604 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='Ty21QMRd4NK3ne5H4GQ6', n=58604, type='number', registry='bionty.Gene', hash='PYHHJaMHHiM5sl5vPQbu', updated_at=2023-11-21 21:37:13 UTC, created_by_id=1)
# ✅ 26702 terms (100.00%) are validated for ensembl_gene_id
# ✅ 59357 terms (100.00%) are validated for ensembl_gene_id
# ✅ loaded: FeatureSet(uid='mlOKhhqJyDLl8mkOhZsb', n=59357, type='number', registry='bionty.Gene', hash='pUpMpu0zd84pS0uKAhOq', updated_at=2023-11-21 21:38:28 UTC, created_by_id=1)

# %% [markdown]
# ### Datasets with human or mouse genes but annotated as other organisms
#
# These files don't have a 'var' featureset:

# %%
from django.db.models import Count

novar_files = files.annotate(c=Count("feature_sets")).filter(c=2).all()
len(novar_files)
# Out:
# 43

# %%
for idx, file in enumerate(novar_files):
    if idx % 5 == 0:
        print(f"annotating file {idx} of {len(novar_files)}")
    adata_backed = file.backed()
    genes = lb.Gene.from_values(
        adata_backed.var_names, field=lb.Gene.ensembl_gene_id, organism="human"
    )
    if len(genes) == 0:
        genes = lb.Gene.from_values(
            adata_backed.var_names, field=lb.Gene.ensembl_gene_id, organism="mouse"
        )
    if len(genes) == len(adata_backed.var_names):
        feature_set = ln.FeatureSet(genes, type="number")
        file.feature_sets.add(featureset, through_defaults={"slot": "var"})
# Out:
# annotating file 0 of 43
# annotating file 5 of 43
# annotating file 10 of 43
# annotating file 15 of 43
# annotating file 20 of 43
# annotating file 25 of 43
# annotating file 30 of 43
# annotating file 35 of 43
# annotating file 40 of 43

# %% [markdown]
# ### Datasets with unregistered genes

# %%
n = 52126
file = ln.FeatureSet.filter(n=n).one().files.all().one()
adata_backed = file.backed()
genes = lb.Gene.from_values(
    adata_backed.var_names, field=lb.Gene.ensembl_gene_id, organism="mouse"
)
ln.save(genes)

feature_set = ln.FeatureSet(genes, type="number")
file.feature_sets.add(featureset, through_defaults={"slot": "var"})

ln.FeatureSet.filter(n=n).one().delete()
# Out:
# ✅ loaded 52126 Gene records matching ensembl_gene_id: 'ENSMUSG00000050732', 'ENSMUSG00000101535', 'ENSMUSG00000101517', 'ENSMUSG00000103873', 'ENSMUSG00000099414', 'ENSMUSG00000101362', 'ENSMUSG00000065433', 'ENSMUSG00000117183', 'ENSMUSG00000077799', 'ENSMUSG00000092514', 'ENSMUSG00000116818', 'ENSMUSG00000021548', 'ENSMUSG00000074037', 'ENSMUSG00000079505', 'ENSMUSG00000064653', 'ENSMUSG00000001472', 'ENSMUSG00000111435', 'ENSMUSG00000117082', 'ENSMUSG00000104205', 'ENSMUSG00000079602', ...
# ✅ created 43 Gene records from Bionty matching ensembl_gene_id: 'ENSMUSG00000061852', 'ENSMUSG00000064400', 'ENSMUSG00000064742', 'ENSMUSG00000080465', 'ENSMUSG00000080542', 'ENSMUSG00000081849', 'ENSMUSG00000083237', 'ENSMUSG00000086513', 'ENSMUSG00000087239', 'ENSMUSG00000090186', 'ENSMUSG00000094162', 'ENSMUSG00000098137', 'ENSMUSG00000098212', 'ENSMUSG00000101890', 'ENSMUSG00000103759', 'ENSMUSG00000103863', 'ENSMUSG00000105705', 'ENSMUSG00000106759', 'ENSMUSG00000107399', 'ENSMUSG00000107898', ...

# %%
n = 52127
file = ln.FeatureSet.filter(n=n).one().files.all().one()
adata_backed = file.backed()
genes = lb.Gene.from_values(
    adata_backed.var_names, field=lb.Gene.ensembl_gene_id, organism="mouse"
)
ln.save(genes)
feature_set = ln.FeatureSet(genes, type="number")
file.feature_sets.add(featureset, through_defaults={"slot": "var"})

ln.FeatureSet.filter(n=n).one().delete()

# %%
n = 39091
for file in ln.FeatureSet.filter(n=n).one().files.all():
    adata_backed = file.backed()
    genes = lb.Gene.from_values(
        adata_backed.var_names, field=lb.Gene.ensembl_gene_id, organism="mouse"
    )
    ln.save(genes)
    feature_set = ln.FeatureSet(genes, type="number")
    file.feature_sets.add(featureset, through_defaults={"slot": "var"})

ln.FeatureSet.filter(n=n).one().delete()
# Out:
# (39094,
#  {'lnschema_core.FileFeatureSet': 2,
#   'lnschema_bionty.Gene_feature_sets': 39091,
#   'lnschema_core.FeatureSet': 1})

# %%
n = 35412
file = ln.FeatureSet.filter(n=n).one().files.all().one()
adata_backed = file.backed()
genes = lb.Gene.from_values(
    adata_backed.var_names, field=lb.Gene.ensembl_gene_id, organism="mouse"
)
ln.save(genes)
feature_set = ln.FeatureSet(genes, type="number")
file.feature_sets.add(featureset, through_defaults={"slot": "var"})

ln.FeatureSet.filter(n=n).one().delete()
# Out:
# ✅ loaded 35419 Gene records matching ensembl_gene_id: 'ENSMUSG00000109644', 'ENSMUSG00000108652', 'ENSMUSG00000021252', 'ENSMUSG00000007777', 'ENSMUSG00000086714', 'ENSMUSG00000043644', 'ENSMUSG00000024442', 'ENSMUSG00000078886', 'ENSMUSG00000042208', 'ENSMUSG00000020831', 'ENSMUSG00000025731', 'ENSMUSG00000107002', 'ENSMUSG00000046683', 'ENSMUSG00000058706', 'ENSMUSG00000099146', 'ENSMUSG00000028608', 'ENSMUSG00000097882', 'ENSMUSG00000058812', 'ENSMUSG00000089889', 'ENSMUSG00000087341', ...
# ✅ created 18 Gene records from Bionty matching ensembl_gene_id: 'ENSMUSG00002074853', 'ENSMUSG00002074875', 'ENSMUSG00002074955', 'ENSMUSG00002075146', 'ENSMUSG00002075525', 'ENSMUSG00002075746', 'ENSMUSG00002075931', 'ENSMUSG00002075991', 'ENSMUSG00002076083', 'ENSMUSG00002076155', 'ENSMUSG00002076161', 'ENSMUSG00002076250', 'ENSMUSG00002076288', 'ENSMUSG00002076601', 'ENSMUSG00002076650', 'ENSMUSG00002076766', 'ENSMUSG00002076818', 'ENSMUSG00002076971'
# (35414,
#  {'lnschema_core.FileFeatureSet': 1,
#   'lnschema_bionty.Gene_feature_sets': 35412,
#   'lnschema_core.FeatureSet': 1})

# %% [markdown]
# ### Register ERCC genes

# %% [markdown]
# Register the organism:

# %%
organism_ercc = lb.Organism.from_bionty(
    ontology_id="NCBITaxon:32630",
    bionty_source=ncbitaxon_bs,  # noqa: F821
)
organism_ercc.save(parents=False)
organism_ercc
# Out:
# Organism(uid='pwt0w3kH', name='synthetic construct', ontology_id='NCBITaxon:32630', scientific_name='synthetic construct', updated_at=2023-11-22 14:44:47 UTC, bionty_source_id=50, created_by_id=1)

# %% [markdown]
# Get the gene table from cellxgene:

# %%
import pandas as pd

df_ercc = pd.read_csv(
    "https://github.com/chanzuckerberg/single-cell-curation/raw/main/cellxgene_schema_cli/cellxgene_schema/ontology_files/genes_ercc.csv.gz",
    header=None,
)

# %%
df_ercc
# Out:
#              0                              1  2     3
# 0   ERCC-00002  ERCC-00002 (spike-in control)  1  1061
# 1   ERCC-00003  ERCC-00003 (spike-in control)  1  1023
# 2   ERCC-00004  ERCC-00004 (spike-in control)  1   523
# 3   ERCC-00009  ERCC-00009 (spike-in control)  1   984
# 4   ERCC-00012  ERCC-00012 (spike-in control)  1   994
# ..         ...                            ... ..   ...
# 87  ERCC-00164  ERCC-00164 (spike-in control)  1  1022
# 88  ERCC-00165  ERCC-00165 (spike-in control)  1   872
# 89  ERCC-00168  ERCC-00168 (spike-in control)  1  1024
# 90  ERCC-00170  ERCC-00170 (spike-in control)  1  1023
# 91  ERCC-00171  ERCC-00171 (spike-in control)  1   505
#
# [92 rows x 4 columns]

# %%
ercc_genes = []

for _, row in df_ercc.iterrows():
    ercc_genes.append(
        lb.Gene(
            symbol=row[0], stable_id=row[0], description=row[1], organism=organism_ercc
        )
    )

# %%
ln.save(ercc_genes)

# %% [markdown]
# ### Datasets with multi-organism genes
#
# 5 files have ERCC genes

# %%
for file in files.all():
    adata_backed = file.backed()
    var_names = adata_backed.var_names
    if len(var_names[var_names.str.startswith("ERCC")]) > 0:
        print(file)
# Out:
# File(uid='KuIP3MrldEjc7dPantpo', key='cell-census/2023-11-13/h5ads/341a0702-9d26-4d8a-b047-ab475f3b492e.h5ad', suffix='.h5ad', accessor='AnnData', size=23851451, hash='BVEUkS6Wd19ZHZgoSu0wgQ-3', hash_type='md5-n', visibility=0, key_is_virtual=False, updated_at=2023-11-20 21:45:24 UTC, storage_id=2, transform_id=18, run_id=18, created_by_id=1)
# File(uid='MeByXegdYg3sdk9vueHh', key='cell-census/2023-11-13/h5ads/66d15835-5dc8-4e96-b0eb-f48971cb65e8.h5ad', suffix='.h5ad', accessor='AnnData', size=29517127, hash='WF8sHBv3hCki9bAf_f3uPw-4', hash_type='md5-n', visibility=0, key_is_virtual=False, updated_at=2023-11-20 21:45:27 UTC, storage_id=2, transform_id=18, run_id=18, created_by_id=1)
# File(uid='m0OxWMCH24t2qmZHjUu8', key='cell-census/2023-11-13/h5ads/8f98c236-43f0-4dc4-985b-c304499f7b44.h5ad', suffix='.h5ad', accessor='AnnData', size=23760963, hash='8N-PX25XG5w0AAdMC2SzyQ-3', hash_type='md5-n', visibility=0, key_is_virtual=False, updated_at=2023-11-20 21:45:29 UTC, storage_id=2, transform_id=18, run_id=18, created_by_id=1)
# File(uid='rmrJahYS2l4lUuHyK1hh', key='cell-census/2023-11-13/h5ads/b07e5164-baf6-43d2-bdba-5a249d0da879.h5ad', suffix='.h5ad', accessor='AnnData', size=41494181, hash='2ghddwTagONe1cfHAjqXLg-5', hash_type='md5-n', visibility=0, key_is_virtual=False, updated_at=2023-11-20 21:45:30 UTC, storage_id=2, transform_id=18, run_id=18, created_by_id=1)
# File(uid='5e0KFuZGuR4YMMOePdOT', key='cell-census/2023-11-13/h5ads/bf6a5c78-5a2e-4e34-93f3-7be5d127d879.h5ad', suffix='.h5ad', accessor='AnnData', size=41782864, hash='rKD1K5dtkGcShQFsR1W6ug-5', hash_type='md5-n', visibility=0, key_is_virtual=False, updated_at=2023-11-20 21:45:31 UTC, storage_id=2, transform_id=18, run_id=18, created_by_id=1)

# %%
for uid in [
    "KuIP3MrldEjc7dPantpo",
    "MeByXegdYg3sdk9vueHh",
    "m0OxWMCH24t2qmZHjUu8",
    "rmrJahYS2l4lUuHyK1hh",
    "5e0KFuZGuR4YMMOePdOT",
]:
    file = files.get(uid=uid)
    adata_backed = file.backed()
    genes_ercc = lb.Gene.filter(organism=organism_ercc).all()
    genes = [i for i in genes_ercc if i.symbol in adata_backed.var_names]
    feature_set_ercc = ln.FeatureSet(genes, type="number")
    feature_set_ercc.save()
    file.feature_sets.add(feature_set_ercc, through_defaults={"slot": "var-ercc"})

# %%
files.annotate(c=Count("feature_sets")).filter(c=4).to_dataframe()
# Out:
#                        uid  storage_id  \
# id
# 2243  KuIP3MrldEjc7dPantpo           2
# 2775  rmrJahYS2l4lUuHyK1hh           2
# 2470  MeByXegdYg3sdk9vueHh           2
# 2625  m0OxWMCH24t2qmZHjUu8           2
# 2832  5e0KFuZGuR4YMMOePdOT           2
#
#                                                     key suffix accessor  \
# id
# 2243  cell-census/2023-11-13/h5ads/341a0702-9d26-4d8...  .h5ad  AnnData
# 2775  cell-census/2023-11-13/h5ads/b07e5164-baf6-43d...  .h5ad  AnnData
# 2470  cell-census/2023-11-13/h5ads/66d15835-5dc8-4e9...  .h5ad  AnnData
# 2625  cell-census/2023-11-13/h5ads/8f98c236-43f0-4dc...  .h5ad  AnnData
# 2832  cell-census/2023-11-13/h5ads/bf6a5c78-5a2e-4e3...  .h5ad  AnnData
#
#      description version      size                      hash hash_type  \
# id
# 2243        None    None  23851451  BVEUkS6Wd19ZHZgoSu0wgQ-3     md5-n
# 2775        None    None  41494181  2ghddwTagONe1cfHAjqXLg-5     md5-n
# 2470        None    None  29517127  WF8sHBv3hCki9bAf_f3uPw-4     md5-n
# 2625        None    None  23760963  8N-PX25XG5w0AAdMC2SzyQ-3     md5-n
# 2832        None    None  41782864  rKD1K5dtkGcShQFsR1W6ug-5     md5-n
#
#       transform_id  run_id initial_version_id  visibility  key_is_virtual  \
# id
# 2243            18      18               None           0           False
# 2775            18      18               None           0           False
# 2470            18      18               None           0           False
# 2625            18      18               None           0           False
# 2832            18      18               None           0           False
#
#                            updated_at  created_by_id  c
# id
# 2243 2023-11-20 21:45:24.572279+00:00              1  4
# 2775 2023-11-20 21:45:30.991571+00:00              1  4
# 2470 2023-11-20 21:45:27.285195+00:00              1  4
# 2625 2023-11-20 21:45:29.147256+00:00              1  4
# 2832 2023-11-20 21:45:31.653346+00:00              1  4
